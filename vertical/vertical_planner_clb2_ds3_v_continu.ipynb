# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Problem Inputs

# %%
import casadi as ca
import numpy as np
import matplotlib.pyplot as plt
from openap import prop

# -------------------------
# 0. Load aircraft and engine data
# -------------------------
fiche_ac = prop.aircraft("A320")
fiche_engine = prop.engine("CFM56-5-A1")
# Ensure all engine parameters are valid
for key in fiche_engine:
    if isinstance(fiche_engine[key], (int, float)):
        if np.isnan(fiche_engine[key]) or fiche_engine[key] <= 0:
            print(f"Warning: Invalid engine parameter: {key}")
print('Check these warnings carefully since they may cause NaNs in the optimization.')

fiche_engine['cruise_sfc'] = 16.9 / 1000 # kg/(N.s), from Wikipedia 

fiche_control = {
    'k_gamma': 0.45  # P controller gain for flight path angle
}

# Problem Inputs ----------
FL_CRZ = 37000
S_MAX = 684 * 1852
# -------------------------

# 1. Conversion factors and target values
# -------------------------
knots_to_ms = 0.514444
ft_to_m     = 0.3048

# Speeds (m/s)
v_250    = 250 * knots_to_ms       # ~128.61 m/s
v_300    = 300 * knots_to_ms       # ~154.33 m/s
v_mach78 = 0.78 * 340              # ~265.2 m/s (approx.)
v_180    = 180 * knots_to_ms 


# Altitudes (m)
h_takeoff_end  = 1000  * ft_to_m    # 1,000 ft
h_climb1_end   = 10000 * ft_to_m    # 10,000 ft (~3048 m)
h_climb2_end   = FL_CRZ * ft_to_m    # 35,000 ft (~10668 m) transition altitude
h_cruise       = FL_CRZ * ft_to_m    # 35,000 ft (~10668 m)
h_descent1_end = 10000 * ft_to_m    # 10,000 ft (~3048 m)
h_descent2_end = 3000 * ft_to_m    # 3,000 ft (~914.4 m)
h_landing_end  = 0.0               # ground
# Out:
# Warning: Invalid engine parameter: cruise_thrust
# Warning: Invalid engine parameter: cruise_sfc
# Warning: Invalid engine parameter: cruise_mach
# Warning: Invalid engine parameter: cruise_alt
# Check these warnings carefully since they may cause NaNs in the optimization.

# %% [markdown]
# # Aircraft Dynamics

# %%
# -------------------------
# 2. Define the aircraft dynamics function (same as before)
# -------------------------
def aircraft_dynamics(x, u, wind_s, phi, phase, fiche_engine, fiche_ac, fiche_control, num_engines = 2):
    """
    Computes the state derivative for the vertical dynamics.
    x = [v, gamma, h, s, m] # speed, flight path angle, altitude, along-path distance, mass
    u = [T, gamma_ref, beta] # thrust, reference flight path angle, speedbrake parameter
    """
    g = 9.81  # gravitational acceleration (m/s^2)

    # Unpack control parameters
    k_gamma = fiche_control['k_gamma']
    
    # Unpack state and control
    v, gamma, h, s, m = x[0], x[1], x[2], x[3], x[4]  # speed, flight path angle, altitude, along-path distance, mass
    T, gamma_ref, beta = u[0], u[1], u[2]  # thrust, controlled flight path angle, speedbrake parameter
    
    # --- Drag Model ---
    rho0 = 1.225  # sea-level density [kg/m^3]
    H    = 8500.0 # scale height [m]
    rho  = rho0 * ca.exp(-h/H) # air density [kg/m^3]

    # --- Load factor calculation ---
    nz = (-v * k_gamma * (gamma - gamma_ref) + g * ca.cos(gamma))/(g * ca.cos(phi))

    # --- Lift/Drag Calculations ---
    L = nz * m * g  # Required lift force
    epsilon = 1e-6  # small number to avoid division by zero
    v_sq = v**2 + epsilon

    S_area = fiche_ac['wing']['area']  # wing area [m^2]
    Cl = L / (0.5 * rho * v_sq * S_area)
    
    k = fiche_ac['drag']['k']
    Cd = fiche_ac['drag']['cd0'] + beta + k * Cl**2  # parabolic drag model
    D = 0.5 * rho * v**2 * S_area * Cd  # Drag force [N]

    # Fuel flow model (different for each phase)
    if phase in ['cruise', 'descent1', 'descent2', 'landing']:
        cruise_sfc = fiche_engine['cruise_sfc'] / 3600.0  # [kg/(N·s)]
        fuel_coef = fiche_ac['fuel']['fuel_coef']
        fuel_flow = fuel_coef * cruise_sfc * T
    elif phase == 'takeoff':
        fuel_flow = fiche_engine['ff_to'] * num_engines
    elif phase in ['climb1', 'climb2', 'climb3']:
        fuel_flow = fiche_engine['ff_co'] * num_engines
    # elif phase in ['descent1', 'descent2']:
    #     fuel_flow = fiche_engine['ff_app'] * num_engines
    # elif phase == 'landing':
    #     fuel_flow = fiche_engine['ff_idl'] * num_engines
    
    # Dynamics equations
    v_dot     = (T - D) / m - g * ca.sin(gamma)
    gamma_dot = k_gamma * (gamma_ref - gamma)
    h_dot     = v * ca.sin(gamma)
    s_dot     = v * ca.cos(gamma) + wind_s
    m_dot     = -fuel_flow
    
    return ca.vertcat(v_dot, gamma_dot, h_dot, s_dot, m_dot)

# %% [markdown]
# # Phases

# %%
# -------------------------
# 3. Phase definitions
# -------------------------
# We define three phases:
#   - climb1: from 0 ft to 10,000 ft, target speed 250 kts.
#   - climb2: from 10,000 ft to 18,000 ft, target speed 300 kts.
#   - cruise: from 18,000 ft to 35,000 ft, target speed Mach 0.78.

h_takeoff_end  = 1000  * ft_to_m    # 1,000 ft
h_climb1_end   = 10000 * ft_to_m    # 10,000 ft (~3048 m)
h_climb2_end   = FL_CRZ * ft_to_m    # 35,000 ft (~10668 m) transition altitude
h_cruise       = FL_CRZ * ft_to_m    # 35,000 ft (~10668 m)
h_descent1_end = 10000 * ft_to_m    # 10,000 ft (~3048 m)
h_descent2_end = 3000 * ft_to_m    # 3,000 ft (~914.4 m)
h_landing_end  = 0.0               # ground

phases = [
    {"name": "climb1", "N": 50, "h0": 0.0,          "hF": h_climb1_end,  "v_target": v_250},
    {"name": "climb2", "N": 50, "h0": h_climb1_end,  "hF": h_climb2_end,  "v_target": v_300},
    {"name": "cruise", "N": 150, "h0": h_climb2_end,  "hF": h_cruise,      "v_target": v_mach78},
    {"name": "descent1", "N": 100, "h0": h_cruise, "hF": h_descent1_end, "v_target": v_300},
    {"name": "descent2", "N": 50, "h0": h_descent1_end, "hF": h_descent2_end, "v_target": v_250},
    {"name": "landing", "N": 50, "h0": h_descent2_end, "hF": h_landing_end, "v_target": v_180}
]

# %%
# -------------------------
# 4. Set up the Opti problem and common parameters
# -------------------------
opti = ca.Opti()

wind_s = opti.parameter();  opti.set_value(wind_s, 0.0)
phi    = opti.parameter();  opti.set_value(phi, 0.0)
CI     = opti.parameter();  opti.set_value(CI, 10.0)

X_list = []  # states for each phase
U_list = []  # controls for each phase
T_list = []  # phase durations
N_list = []  # discretization intervals
phase_names = []

# %% [markdown]
# # Altitude, Speed Boundaries, Phase Time and State Limits

# %%
# -------------------------
# 5. Create decision variables for each phase
# -------------------------

# Slack variables for soft constraints about speed and altitude
V_slacks = []
H_slacks = []

for i, phase in enumerate(phases):
    name = phase["name"]
    phase_names.append(name)
    N_phase = phase["N"]
    N_list.append(N_phase)
    
    T_phase = opti.variable()
    opti.subject_to(T_phase >= 0)
    T_list.append(T_phase)
    if name == 'climb1':
        opti.set_initial(T_phase, 10_000 / (3000 / 60)) # climb at 3000 ft/mi
        # opti.subject_to(T_phase > 10_000 / (3000 / 60))
    elif name == 'climb2':
        opti.set_initial(T_phase, (FL_CRZ - 10_000) / (3000 / 60)) # climb at 3000 ft/min
        # opti.subject_to(T_phase > (FL_CRZ - 10_000) / (3000 / 60))
    elif name == 'descent1':
        opti.set_initial(T_phase, (FL_CRZ - 10_000) / (1500 / 60)) # descent at 1500 ft/min
        opti.subject_to(T_phase < 1.3 * (FL_CRZ - 10_000) / (1500 / 60))
    elif name == 'descent2':
        opti.set_initial(T_phase, 7_000 / (1500 / 60)) # descent at 1500 ft/min
        opti.subject_to(T_phase < 1.3 * 7_000 / (1500 / 60))
    elif name == "landing":
        opti.set_initial(T_phase, 3_000 / (1500 / 60))
        opti.subject_to(T_phase < 1.3 * 3_000 / (1500 / 60))
    elif name == "cruise":
        opti.set_initial(T_phase, 0.7 * S_MAX / v_250)
        # opti.subject_to(T_phase >= 0.5 * S_MAX / v_250)
    # if name == "descent1":
    #     opti.set_initial(T_phase, 0.15 * S_MAX / v_250)
    #     opti.subject_to(T_phase >= 0.05 * S_MAX / v_250)
    # if name == "descent2":
    #     opti.set_initial(T_phase, 0.1 * S_MAX / v_250)
    #     opti.subject_to(T_phase >= 0.05 * S_MAX / v_250)
    dt = T_phase / N_phase  # time step
    
    # State vector: [v, gamma, h, s, m] over (N_phase+1) nodes
    X = opti.variable(5, N_phase+1) # N_phase+1 time steps
    # Control vector: [T, gamma_ref, beta] over N_phase intervals
    U = opti.variable(3, N_phase)
    
    X_list.append(X)
    U_list.append(U)
    
    # Multiple shooting dynamics via explicit Euler integration
    for k in range(N_phase): # between N_phase + 1 time steps are N_phase intervals
        xk = X[:, k]
        uk = U[:, k]
        x_next = X[:, k+1]
        x_next_euler = xk + dt * aircraft_dynamics(xk, uk, wind_s, phi, name, fiche_engine, fiche_ac, fiche_control)
        opti.subject_to(x_next == x_next_euler)
    
    # Altitude boundary conditions for each phase (altitude at the beginning and end of each phase)
    # Soft constraints for initial and final altitude with slack variables
    h_slack_init = opti.variable()
    h_slack_final = opti.variable()
    opti.set_initial(h_slack_init, 0)
    opti.set_initial(h_slack_final, 0)
    
    max_alt_dev = 100.0  # Allow ±50m deviation
    opti.subject_to(h_slack_init <= max_alt_dev)
    opti.subject_to(h_slack_init >= -max_alt_dev)
    opti.subject_to(h_slack_final <= max_alt_dev) 
    opti.subject_to(h_slack_final >= -max_alt_dev)
    
    opti.subject_to(X[2, 0] == phase["h0"] + h_slack_init)
    opti.subject_to(X[2, -1] == phase["hF"] + h_slack_final)
    
    # Enforce prescribed speed if provided
    # if phase["v_target"] is not None:
    #     for k in range(N_phase+1):
    #         opti.subject_to(X[0, k] == phase["v_target"])
    
    # Soft constraints on prescribed speed and altitude
    V_slack = opti.variable(N_phase + 1)
    H_slack = opti.variable(N_phase + 1)
    opti.set_initial(V_slack, 0) # set initial guess for slack variables
    if phase["v_target"] is not None:
        max_speed_dev = 10.0  # Allow ±20 m/s deviation
        
        if phase['name'] == 'climb1':
            for k in range(N_phase + 1):
                opti.subject_to(V_slack[k] <= max_speed_dev)
                opti.subject_to(V_slack[k] >= -max_speed_dev)
                opti.subject_to(X[0, k] == phase["v_target"] + V_slack[k])

        elif phase['name'] == 'climb2':
            last_phase = phases[i-1]
            for k in range(5): # first 5 timesteps, accelerating from last phase's speed
                if k == 0:
                    opti.subject_to(V_slack[k] > 0)
                else:
                    opti.subject_to(V_slack[k] > V_slack[k-1])
                opti.subject_to(V_slack[k] <= phase["v_target"] - last_phase["v_target"])
                opti.subject_to(X[0, k] == last_phase["v_target"] + V_slack[k])
            for k in range(5, N_phase + 1): # middle timesteps
                opti.subject_to(V_slack[k] <= max_speed_dev)
                opti.subject_to(V_slack[k] >= -max_speed_dev)
                opti.subject_to(X[0, k] == phase["v_target"] + V_slack[k])

        elif phase['name'] == 'cruise':
            last_phase = phases[i-1]
            for k in range(5): # first 5 timesteps, accelerating from last phase's speed
                if k == 0:
                    opti.subject_to(V_slack[k] > 0)
                else:
                    opti.subject_to(V_slack[k] > V_slack[k-1])
                    opti.subject_to(V_slack[k] <= phase["v_target"] - last_phase["v_target"])
                opti.subject_to(X[0, k] == last_phase["v_target"] + V_slack[k])
            for k in range(5, N_phase + 1): # middle timesteps
                opti.subject_to(V_slack[k] <= max_speed_dev)
                opti.subject_to(V_slack[k] >= -max_speed_dev)
                opti.subject_to(X[0, k] == phase["v_target"] + V_slack[k])

        elif phase['name'] in ['descent1', 'descent2', 'landing']:
            last_phase = phases[i-1]
            for k in range(10): # first 5 timesteps, decelerating from last phase's speed
                if k == 0:
                    opti.subject_to(V_slack[k] < 0)
                else:
                    opti.subject_to(V_slack[k] < V_slack[k-1])
                opti.subject_to(V_slack[k] >= phase["v_target"] - last_phase["v_target"])
                opti.subject_to(X[0, k] == last_phase["v_target"] + V_slack[k])
            for k in range(10, N_phase + 1): # middle timesteps
                opti.subject_to(V_slack[k] <= max_speed_dev)
                opti.subject_to(V_slack[k] >= -max_speed_dev)
                opti.subject_to(X[0, k] == phase["v_target"] + V_slack[k])

        else:
            for k in range(N_phase + 1):
                opti.subject_to(V_slack[k] <= max_speed_dev)
            opti.subject_to(V_slack[k] >= -max_speed_dev)
            opti.subject_to(X[0, k] == phase["v_target"] + V_slack[k])
    else:
        # For phases without a prescribed speed, enforce zero slack.
        for k in range(N_phase + 1):
            opti.subject_to(V_slack[k] == 0)
    V_slacks.append(V_slack)
    
    # For cruise phase, enforce constant altitude along the entire phase
    # if name == "cruise":
    #     for k in range(N_phase + 1):
    #         opti.subject_to(X[2, k] == h_cruise)
    
    # For cruise phase, use soft constraints for altitude
    H_slack = opti.variable(N_phase + 1)
    opti.set_initial(H_slack, 0) # set initial guess for slack variables
    if name == "cruise":
        max_alt_dev = 100.0  # Allow ±100 m deviation
        for k in range(N_phase + 1):
            opti.subject_to(H_slack[k] <= max_alt_dev)
            opti.subject_to(H_slack[k] >= -max_alt_dev)
            opti.subject_to(X[2, k] == h_cruise + H_slack[k])
    elif name in ['descent1', 'descent2', 'landing']:
        last_phase = phases[i-1]
        last_phase_alt = last_phase.get("hF")
        current_phase_alt = phase.get("hF")
        
        max_alt_dev = 100.0  # Allow ±100 m deviation
        for k in range(N_phase + 1):
            # Linear interpolation between altitudes
            target_alt = last_phase_alt + (current_phase_alt - last_phase_alt) * (k / N_phase)
            
            opti.subject_to(H_slack[k] <= max_alt_dev)
            opti.subject_to(H_slack[k] >= -max_alt_dev)
            opti.subject_to(X[2, k] == target_alt + H_slack[k])
    else:
        # For phases other than cruise, enforce zero slack.
        for k in range(N_phase + 1):
            opti.subject_to(H_slack[k] == 0)
    H_slacks.append(H_slack)


    # Additional state bounds (applied at every node)
    for k in range(N_phase+1):
        opti.subject_to(X[0, k] >= 0)        # v lower bound
        opti.subject_to(X[0, k] <= 350)      # v upper bound
        opti.subject_to(X[1, k] >= -0.2)       # gamma lower bound
        opti.subject_to(X[1, k] <= 0.2)        # gamma upper bound
        opti.subject_to(X[2, k] >= 0)          # altitude lower bound
        opti.subject_to(X[2, k] <= 12000)      # altitude upper bound (sufficient for cruise)
        opti.subject_to(X[3, k] >= 0)          # along-path distance lower bound
        opti.subject_to(X[4, k] >= 30000)      # mass lower bound
        opti.subject_to(X[4, k] <= 90000)      # mass upper bound
    
    # Control bounds for each interval
    for k in range(N_phase):
        opti.subject_to(U[0, k] >= 0.1 * fiche_engine['max_thrust'])        # Thrust lower bound
        opti.subject_to(U[0, k] <= 0.5 * fiche_engine['max_thrust'])   # Thrust upper bound
        opti.subject_to(U[1, k] >= -0.5)       # gamma_ref lower bound
        opti.subject_to(U[1, k] <= 0.5)        # gamma_ref upper bound
        opti.subject_to(U[2, k] >= 0.0)        # beta lower bound
        opti.subject_to(U[2, k] <= 0.02)        # beta upper bound

# %% [markdown]
# # Phase Continuity

# %%
# -------------------------
# 6. Impose continuity between phases
# -------------------------
# Ensure that the final state of phase i equals the initial state of phase i+1.
for i in range(len(phases)-1):
    opti.subject_to(X_list[i+1][:, 0] == X_list[i][:, -1]) # skip velocity mismatch

# %% [markdown]
# # Initial and Final Conditions

# %%
# -------------------------
# 7. Impose boundary conditions on the first phase (takeoff/climb1)
# -------------------------
# Initial state: [v, gamma, h, s, m]
x0 = np.array([v_250, 0.0, 0.0, 0.0, 70000.0])
opti.set_initial(X_list[0][:, 0], x0)
opti.subject_to(X_list[0][3, 0] == 0.0)   # along-path distance

# Until traveled distance s is 200_000m - only constrain final point
# opti.subject_to(X_list[-1][3, -1] == 200_000)

# At final descent, the traveled distance (soft constraint)
S_slack = opti.variable()  # Slack variable for distance constraint
opti.subject_to(S_slack >= -5_000)  # Slack must be non-negative
opti.subject_to(S_slack <= 5_000) # 1 km
opti.subject_to(X_list[-1][3, -1] + S_slack == S_MAX)  # Soft constraint with slack

# For climb1, ensure the final speed is the prescribed v_250
# opti.subject_to(X_list[0][0, -1] == v_250)

# %% [markdown]
# # Cost Function

# %%
# -------------------------
# 8. Define the overall cost function
# -------------------------
# Here, the cost in each phase is integrated over time.
total_cost = 0
for i, phase in enumerate(phases):
    N_phase = phase["N"]
    T_phase = T_list[i]
    dt = T_phase / N_phase
    X = X_list[i]
    U = U_list[i]
    J_phase = 0
    alt_h0_hf_weight = 1e3
    speed_penalty_weight = 1e3
    alt_penalty_weight = 1e3
    distance_penalty_weight = 1e3
    control_smoothing_weight = [1e-5, 1e-3, 1e-3] # [T, gamma_ref, beta]
            
    for k in range(N_phase):
        T_k = U[0, k]
        # Example: simple cost (you can replace fuel_flow model as needed)
        # fuel_flow_k = 0.0001 * T_k  # [kg/s]
        # J_phase += (fuel_flow_k + CI) * dt
        J_phase += (CI) * dt
        speed_penalty = speed_penalty_weight * V_slacks[i][k]**2
        alt_penalty = alt_penalty_weight * H_slacks[i][k]**2
        J_phase += speed_penalty + alt_penalty

    alt_h0_hf_penalty = alt_h0_hf_weight * (h_slack_init**2 + h_slack_final**2)
    J_phase += alt_h0_hf_penalty
    J_phase += distance_penalty_weight * S_slack**2

    # --------------------------------
    # CONTROL-RATE PENALTY
    # --------------------------------
    # We add a loop from k=1..N_phase-1 to penalize changes in U
    for k in range(1, N_phase):
        # Sums of squares of changes in [T, gamma_ref, beta]
        J_phase += ca.sumsqr(control_smoothing_weight * (U[:, k] - U[:, k-1]))
    # --------------------------------
    total_cost += J_phase
    
opti.minimize(total_cost)

# %% [markdown]
# # Initial Guesses

# %%
# -------------------------
# 9. Provide initial guesses for states and controls
# -------------------------
for i, phase in enumerate(phases):
    N_phase = phase["N"]
    X = X_list[i]
    for k in range(N_phase+1):
        # Linear interpolation for altitude between phase boundaries
        h_guess = phase["h0"] + (phase["hF"] - phase["h0"]) * k / N_phase
        opti.set_initial(X[2, k], h_guess)
        
        # For speed, if v_target is enforced, it is already fixed.
        if phase["v_target"] is not None:
            if phase["name"] == "takeoff":
                v_guess = 0 + (v_250 - 0) * k / N_phase
                opti.set_initial(X[0, k], v_guess) # set initial guess, not initial condition
            elif phase["name"] == "climb1":
                opti.set_initial(X[0, k], v_250)
            elif phase["name"] == "climb2":
                last_phase_speed = v_250  # Speed from climb1
                target_speed = v_300
                if k <= N_phase/2:
                    # Linear interpolation for first half
                    v_guess = last_phase_speed + (target_speed - last_phase_speed) * (k/(N_phase/2))
                else:
                    # Constant speed for second half
                    v_guess = target_speed
                opti.set_initial(X[0, k], v_guess)
            elif phase["name"] == "cruise":
                last_phase_speed = v_300  # Speed from climb2
                target_speed = v_mach78
                if k <= N_phase/2:
                    v_guess = last_phase_speed + (target_speed - last_phase_speed) * (k/(N_phase/2))
                else:
                    v_guess = target_speed
                opti.set_initial(X[0, k], v_guess)
            elif phase["name"] == "descent1":
                last_phase_speed = v_mach78  # Speed from cruise
                target_speed = v_300
                if k <= N_phase/2:
                    v_guess = last_phase_speed + (target_speed - last_phase_speed) * (k/(N_phase/2))
                else:
                    v_guess = target_speed
                opti.set_initial(X[0, k], v_guess)
            elif phase["name"] == "descent2":
                last_phase_speed = v_300  # Speed from descent1
                target_speed = v_250
                if k <= N_phase/2:
                    v_guess = last_phase_speed + (target_speed - last_phase_speed) * (k/(N_phase/2))
                else:
                    v_guess = target_speed
                opti.set_initial(X[0, k], v_guess)
            elif phase["name"] == "landing":
                last_phase_speed = v_250  # Speed from descent2
                target_speed = v_180
                if k <= N_phase/2:
                    v_guess = last_phase_speed + (target_speed - last_phase_speed) * (k/(N_phase/2))
                else:
                    v_guess = target_speed
                opti.set_initial(X[0, k], v_guess)
        else:
            opti.set_initial(X[0, k], v_250) # other phases without v_target prescribed
        # Provide guesses for other states.
        opti.set_initial(X[1, k], 0.0)  # gamma
        opti.set_initial(X[4, k], 70000.0 - 1000*i)  # mass

# Along-path distance initial guesses
for i, phase in enumerate(phases):
    N_phase = phase["N"]
    X = X_list[i]
    for k in range(N_phase+1):
        if phase["name"] == "climb1":
            opti.set_initial(X[3, k], 0.0 + 0.05 * S_MAX * (k/float(N_phase)))  # along-path distance
        elif phase["name"] == "climb2":
            opti.set_initial(X[3, k], 0.05 * S_MAX + 0.05 * S_MAX *(k/float(N_phase)))  # along-path distance
        elif phase["name"] == "cruise":
            opti.set_initial(X[3, k], 0.1 * S_MAX + 0.8 * S_MAX *(k/float(N_phase)))  # along-path distance
        elif phase["name"] == "descent1":
            opti.set_initial(X[3, k], 0.9 * S_MAX + 0.04 * S_MAX *(k/float(N_phase)))  # along-path distance
        elif phase["name"] == "descent2":
            opti.set_initial(X[3, k], 0.94 * S_MAX + 0.03 * S_MAX *(k/float(N_phase)))  # along-path distance
        elif phase["name"] == "landing":
            opti.set_initial(X[3, k], 0.97 * S_MAX + 0.03 * S_MAX *(k/float(N_phase)))  # along-path distance
    
    # Initial guesses for controls.
    U = U_list[i]
    for k in range(N_phase):
        opti.set_initial(U[0, k], 50000.0)  # thrust
        opti.set_initial(U[1, k], 0.0)       # gamma_ref
        opti.set_initial(U[2, k], 0.0)       # beta

# %% [markdown]
# # Solve

# %%
# -------------------------
# 10. Solve the NLP
# -------------------------
p_opts = {"expand": True}
s_opts = {"max_iter": 50e3, "print_level": 5, "tol":1e-6, "acceptable_tol":1e-4}
opti.solver('ipopt', p_opts, s_opts)

try:
    sol = opti.solve()  # Solve the optimization problem
except RuntimeError as e:
    print("Solver error:", e)
    
    # Inspect values at the point where the error occurred
    print("\n--- Debugging Information ---")
    for i, phase in enumerate(phases):
        # print(f"\nPhase: {phase['name']}")
        X_debug = opti.debug.value(X_list[i])
        U_debug = opti.debug.value(U_list[i])
        T_debug = opti.debug.value(T_list[i])

        # print("  States (X) [v, fpa, h, s, m]:")
        # print(X_debug)
        # print("  Controls (U) [thrust, fpa, spdbrk]:")
        # print(U_debug)
        print(f"Phase {phase['name']}, Duration {T_debug}")

        # if "Infeasible_Problem_Detected" in str(e):
            # print("Solver detected infeasibility. Analyzing...")
            # opti.debug.show_infeasibilities()  # Show summary


        # Plot the states
        from state_plot import plot_states, plot_states_ext
        plot_states(X_debug[0], X_debug[1], X_debug[2], X_debug[3], X_debug[4], U_debug[0], U_debug[1], U_debug[2])

        X_ext = np.empty((6, phase['N']))

        # Compute the additional variables
        for k in range(phase['N']):
            xk = X_debug[:,k]
            uk = U_debug[:,k]
            dyn_func = aircraft_dynamics(xk, uk, opti.debug.value(wind_s), opti.debug.value(phi), phase['name'], fiche_engine, fiche_ac, fiche_control)
            dyn_values = opti.debug.value(dyn_func)

            #Further break down
            g = 9.81
            k_gamma = fiche_control['k_gamma']
            v, gamma, h, s, m = xk[0], xk[1], xk[2], xk[3], xk[4]
            T, gamma_ref, beta = uk[0], uk[1], uk[2]
            rho0 = 1.225
            H = 8500.0
            rho = rho0 * np.exp(-h / H)  # Use numpy for scalar calculations during debugging
            nz = (-v * k_gamma * (gamma - gamma_ref) + g * np.cos(gamma))/(g * np.cos(0))
            L = nz * m * g
            epsilon = 1e-6
            v_sq = v**2 + epsilon
            S_area = fiche_ac['wing']['area']
            Cl = L / (0.5 * rho * v_sq * S_area)
            k_drag = fiche_ac['drag']['k']
            Cd = fiche_ac['drag']['cd0'] + beta + k_drag * Cl**2
            D = 0.5 * rho * v**2 * S_area * Cd

            X_ext[:,k] = np.array([L, D, nz, Cl, Cd, rho])
            if np.isnan(X_ext[:,k]).any():
                print(f"NaN detected at index {k}")
                print(f"X_ext[:,k]: {X_ext[:,k]}")
                print(f"X_ext: {X_ext}")
                print(f"X_ext[0]: {X_ext[0]}")
                print(f"X_ext[1]: {X_ext[1]}")
            
            # Check the constraints manually
        # Manually check constraints
        print("\nChecking constraints for phase:", phase['name'])
        
        # Check altitude constraints
        h_min = phase['h0']
        h_max = phase['hF'] 
        h_violations = np.where((X_debug[2,:-1] < h_min) | (X_debug[2,:-1] > h_max))[0]
        if len(h_violations) > 0:
            print(f"Altitude constraint violations at steps: {h_violations}")
            print(f"Values: {X_debug[2,h_violations]}")
            print(f"Bounds: [{h_min}, {h_max}]")
            
        # Check speed constraints
        v_target = phase['v_target']
        v_tolerance = 10.0  # m/s tolerance
        v_violations = np.where(abs(X_debug[0,:-1] - v_target) > v_tolerance)[0]
        if len(v_violations) > 0:
            print(f"Speed constraint violations at steps: {v_violations}")
            print(f"Values: {X_debug[0,v_violations]}")
            print(f"Target: {v_target} ± {v_tolerance}")
            
        # Check load factor constraints
        nz_max = 1.3  # maximum load factor
        nz_violations = np.where(abs(X_ext[2,:]) > nz_max)[0]
        if len(nz_violations) > 0:
            print(f"Load factor constraint violations at steps: {nz_violations}")
            print(f"Values: {X_ext[2,nz_violations]}")
            print(f"Bound: ±{nz_max}")
            
        # Check thrust constraints
        T_max = fiche_engine['max_thrust'] * 2  # 2 engines
        T_violations = np.where((U_debug[0,:] < 0) | (U_debug[0,:] > T_max))[0]
        if len(T_violations) > 0:
            print(f"Thrust constraint violations at steps: {T_violations}")
            print(f"Values: {U_debug[0,T_violations]}")
            print(f"Bounds: [0, {T_max}]")
            
        # Check speedbrake constraints
        beta_max = 0.1
        beta_violations = np.where((U_debug[2,:] < 0) | (U_debug[2,:] > beta_max))[0]
        if len(beta_violations) > 0:
            print(f"Speedbrake constraint violations at steps: {beta_violations}")
            print(f"Values: {U_debug[2,beta_violations]}")
            print(f"Bounds: [0, {beta_max}]")
            
        # Check the slack variables
        # Check slack variables for NaNs
        if len(V_slacks) > 0 and len(H_slacks) > 0:
            v_slack_vals = opti.debug.value(V_slacks[-1])
            h_slack_vals = opti.debug.value(H_slacks[-1])
            
            print(f"v_slack_vals: {v_slack_vals}")
            print(f"h_slack_vals: {h_slack_vals}")
            
            if np.any(np.isnan(v_slack_vals)):
                print(f"NaN detected in velocity slack variables!")
                print(f"Indices of NaNs: {np.where(np.isnan(v_slack_vals))[0]}")
            
            if np.any(np.isnan(h_slack_vals)):
                print(f"NaN detected in altitude slack variables!")
                print(f"Indices of NaNs: {np.where(np.isnan(h_slack_vals))[0]}")
                
        plot_states_ext(X_ext[0], X_ext[1], X_ext[2], X_ext[3], X_ext[4], X_ext[5])
        
    # Let's deal with NaNs
    # Get the current values of all decision variables:
    x_val = opti.debug.value(opti.x)
    if np.any(np.isnan(x_val)):
        print("NaN detected in decision variable values!")
        print("Indices of NaNs:", np.where(np.isnan(x_val)))
    else:
        print("No NaNs in decision variables.")
    
    # Evaluate the constraint function values:
    g_val = opti.debug.value(opti.g)
    if np.any(np.isnan(g_val)):
        print("NaN detected in constraint values!")
        print("Indices of NaNs:", np.where(np.isnan(g_val)))
    else:
        print("No NaNs in constraint values.")
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:    13849
# Number of nonzeros in inequality constraint Jacobian.:     8493
# Number of nonzeros in Lagrangian Hessian.............:    14835
#
# Total number of variables............................:     4561
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     3201
# Total number of inequality constraints...............:     8458
#         inequality constraints with only lower bounds:     4451
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:     4007
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  9.1147260e+04 5.43e+03 6.13e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  9.0523563e+04 5.34e+03 8.17e-01  -1.0 2.56e+04    -  9.47e-03 1.73e-02f  1
#    2  9.0516796e+04 5.34e+03 4.37e+02  -1.0 2.40e+04    -  5.07e-02 1.91e-04f  1
#    3  9.0505028e+04 5.34e+03 7.68e+02  -1.0 2.40e+04    -  5.83e-04 3.37e-04f  1
#    4  9.0173029e+04 5.27e+03 1.36e+04  -1.0 2.40e+04    -  1.93e-03 1.28e-02f  1
#    5  9.0170858e+04 5.27e+03 4.23e+04  -1.0 2.29e+04    -  4.00e-02 1.29e-04h  1
#    6  9.0166123e+04 5.27e+03 4.27e+04  -1.0 1.10e+05    -  5.75e-04 2.87e-04h  1
#    7  9.0114507e+04 5.23e+03 4.48e+04  -1.0 1.09e+05    -  1.33e-03 6.15e-03f  1
#    8  9.0114516e+04 5.23e+03 4.46e+04  -1.0 1.03e+05    -  6.38e-03 6.40e-05h  1
#    9  9.0115101e+04 5.23e+03 4.46e+04  -1.0 9.91e+04    -  2.29e-04 2.51e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  9.0794073e+04 5.18e+03 6.21e+05  -1.0 9.88e+04    -  3.86e-02 9.97e-03h  1
#   11  9.0832678e+04 5.18e+03 8.29e+05  -1.0 1.88e+05    -  1.25e-02 3.03e-04h  1
#   12  9.1139225e+04 5.17e+03 9.72e+05  -1.0 2.27e+05    -  1.15e-02 2.22e-03h  1
#   13  9.1262669e+04 5.16e+03 9.72e+05  -1.0 2.63e+05    -  9.23e-04 8.18e-04h  1
#   14  9.1827286e+04 5.15e+03 1.29e+06  -1.0 2.66e+05    -  2.65e-02 3.23e-03h  1
#   15  9.5614026e+04 5.07e+03 1.17e+06  -1.0 3.07e+05    -  4.92e-03 1.39e-02h  1
#   16  9.5683100e+04 5.07e+03 1.20e+06  -1.0 2.78e+05    -  3.09e-03 1.88e-04h  1
#   17  9.6092722e+04 5.07e+03 1.20e+06  -1.0 2.74e+05    -  1.08e-03 1.08e-03h  1
#   18  9.7947185e+04 5.05e+03 1.94e+06  -1.0 2.71e+05    -  4.46e-02 4.44e-03h  1
#   19  9.8080444e+04 5.04e+03 2.09e+06  -1.0 2.19e+05    -  6.55e-03 2.76e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.0132110e+05 5.01e+03 2.92e+06  -1.0 2.12e+05    -  4.26e-02 6.03e-03h  1
#   21  1.0167314e+05 5.01e+03 2.92e+06  -1.0 1.74e+05    -  7.40e-04 5.78e-04h  1
#   22  1.0263384e+05 5.00e+03 2.93e+06  -1.0 1.73e+05    -  1.88e-03 1.53e-03h  1
#   23  1.1442918e+05 4.93e+03 2.97e+06  -1.0 1.71e+05    -  1.88e-02 1.52e-02h  1
#   24  1.1462216e+05 4.93e+03 3.45e+06  -1.0 1.48e+05    -  2.11e-02 2.11e-04h  1
#   25  1.1955300e+05 4.90e+03 4.45e+06  -1.0 1.37e+05    -  4.88e-02 5.11e-03h  1
#   26  1.2865303e+05 4.86e+03 4.66e+06  -1.0 1.50e+05    -  1.95e-02 8.33e-03h  1
#   27  1.2952870e+05 4.86e+03 4.69e+06  -1.0 1.45e+05    -  2.06e-03 7.51e-04h  1
#   28  1.3099036e+05 4.85e+03 4.70e+06  -1.0 1.49e+05    -  1.96e-03 1.24e-03h  1
#   29  1.3306536e+05 4.84e+03 4.70e+06  -1.0 1.54e+05    -  2.21e-03 1.73e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  1.3670951e+05 4.83e+03 5.81e+06  -1.0 1.52e+05    -  5.05e-02 2.94e-03h  1
#   31  1.4018870e+05 4.81e+03 5.89e+06  -1.0 1.62e+05    -  6.84e-03 2.75e-03h  1
#   32  1.4669076e+05 4.79e+03 6.91e+06  -1.0 1.64e+05    -  5.06e-02 4.87e-03h  1
#   33  1.5375371e+05 4.77e+03 6.99e+06  -1.0 1.72e+05    -  9.96e-03 4.94e-03h  1
#   34  1.5683713e+05 4.76e+03 7.75e+06  -1.0 2.18e+05    -  3.62e-02 2.11e-03h  1
#   35  1.7980245e+05 4.69e+03 7.41e+06  -1.0 2.27e+05    -  4.04e-03 1.41e-02h  1
#   36  1.8090309e+05 4.69e+03 7.56e+06  -1.0 2.14e+05    -  7.52e-03 6.35e-04h  1
#   37  1.9152774e+05 4.66e+03 7.39e+06  -1.0 2.13e+05    -  5.84e-05 5.93e-03h  1
#   38  1.9278884e+05 4.66e+03 7.41e+06  -1.0 2.03e+05    -  1.91e-03 6.87e-04h  1
#   39  1.9722942e+05 4.65e+03 7.41e+06  -1.0 2.03e+05    -  2.97e-03 2.38e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  2.0026856e+05 4.64e+03 7.43e+06  -1.0 2.02e+05    -  3.25e-03 1.60e-03h  1
#   41  2.0319019e+05 4.63e+03 7.42e+06  -1.0 1.98e+05    -  1.48e-03 1.51e-03h  1
#   42  2.1825197e+05 4.60e+03 7.96e+06  -1.0 1.98e+05    -  3.40e-02 7.47e-03h  1
#   43  2.2075031e+05 4.59e+03 8.17e+06  -1.0 2.00e+05    -  1.10e-02 1.19e-03h  1
#   44  2.5178436e+05 4.53e+03 8.67e+06  -1.0 2.02e+05    -  4.14e-02 1.39e-02h  1
#   45  2.5484141e+05 4.52e+03 9.40e+06  -1.0 2.12e+05    -  3.35e-02 1.29e-03h  1
#   46  2.8555218e+05 4.47e+03 1.02e+07  -1.0 2.24e+05    -  5.10e-02 1.23e-02h  1
#   47  2.9325564e+05 4.45e+03 1.01e+07  -1.0 2.41e+05    -  2.72e-03 2.92e-03h  1
#   48  3.0550730e+05 4.43e+03 1.16e+07  -1.0 2.42e+05    -  7.24e-02 4.54e-03h  1
#   49  3.1319758e+05 4.42e+03 1.18e+07  -1.0 2.53e+05    -  9.02e-03 2.77e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  3.3151751e+05 4.39e+03 1.18e+07  -1.0 2.55e+05    -  1.06e-02 6.41e-03h  1
#   51  3.3664981e+05 4.38e+03 1.17e+07  -1.0 2.54e+05    -  1.56e-03 1.75e-03h  1
#   52  3.4983046e+05 4.37e+03 1.25e+07  -1.0 2.55e+05    -  4.23e-02 4.41e-03h  1
#   53  4.1476541e+05 4.28e+03 1.20e+07  -1.0 2.64e+05    -  8.19e-03 2.01e-02h  1
#   54  4.1633899e+05 4.28e+03 1.25e+07  -1.0 2.79e+05    -  2.17e-02 4.70e-04h  1
#   55  4.3871837e+05 4.25e+03 1.24e+07  -1.0 2.92e+05    -  7.46e-03 6.57e-03h  1
#   56  4.4346876e+05 4.24e+03 1.40e+07  -1.0 2.94e+05    -  7.23e-02 1.37e-03h  1
#   57  4.8746487e+05 4.19e+03 1.37e+07  -1.0 2.99e+05    -  6.27e-03 1.21e-02h  1
#   58  5.3091796e+05 4.14e+03 1.45e+07  -1.0 3.02e+05    -  5.35e-02 1.14e-02h  1
#   59  5.3477876e+05 4.14e+03 1.46e+07  -1.0 3.31e+05    -  2.00e-03 9.98e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  5.5536746e+05 4.12e+03 1.44e+07  -1.0 3.33e+05    -  2.72e-03 5.25e-03h  1
#   61  6.1551898e+05 4.06e+03 1.50e+07  -1.0 3.41e+05    -  4.47e-02 1.48e-02h  1
#   62  6.2229493e+05 4.05e+03 1.50e+07  -1.0 3.98e+05    -  2.38e-03 1.66e-03h  1
#   63  6.2547040e+05 4.05e+03 1.58e+07  -1.0 4.01e+05    -  2.46e-02 7.74e-04h  1
#   64  6.6052743e+05 4.01e+03 1.64e+07  -1.0 4.03e+05    -  2.35e-02 8.28e-03h  1
#   65  6.6555118e+05 4.01e+03 1.64e+07  -1.0 4.39e+05    -  8.47e-04 1.18e-03h  1
#   66  6.7455618e+05 4.00e+03 1.65e+07  -1.0 4.40e+05    -  5.07e-03 2.10e-03h  1
#   67  7.3364963e+05 3.95e+03 1.62e+07  -1.0 4.33e+05    -  1.11e-02 1.31e-02h  1
#   68  7.9520109e+05 3.90e+03 1.82e+07  -1.0 4.03e+05    -  4.68e-02 1.27e-02h  1
#   69  8.0310742e+05 3.89e+03 1.91e+07  -1.0 3.20e+05    -  1.55e-02 1.53e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  8.5864257e+05 3.85e+03 2.09e+07  -1.0 2.98e+05    -  3.88e-02 1.03e-02h  1
#   71  9.6832307e+05 3.78e+03 2.24e+07  -1.0 2.57e+05    -  4.70e-02 1.87e-02h  1
#   72  1.0166088e+06 3.75e+03 2.35e+07  -1.0 2.54e+05    -  2.57e-02 7.68e-03h  1
#   73  1.0739232e+06 3.72e+03 2.45e+07  -1.0 2.44e+05    -  2.53e-02 8.77e-03h  1
#   74  1.1270342e+06 3.69e+03 3.10e+07  -1.0 2.30e+05    -  9.71e-02 7.83e-03h  1
#   75  1.2170968e+06 3.64e+03 3.05e+07  -1.0 1.87e+05    -  1.06e-02 1.26e-02h  1
#   76  1.2745714e+06 3.61e+03 3.72e+07  -1.0 1.75e+05    -  9.42e-02 7.76e-03h  1
#   77  1.4006284e+06 3.55e+03 4.08e+07  -1.0 1.64e+05    -  6.60e-02 1.61e-02h  1
#   78  1.5330302e+06 3.50e+03 4.61e+07  -1.0 1.56e+05    -  8.54e-02 1.59e-02h  1
#   79  1.5367991e+06 3.50e+03 4.62e+07  -1.0 1.48e+05    -  1.73e-03 4.42e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  1.5508549e+06 3.49e+03 4.61e+07  -1.0 2.12e+05    -  9.24e-04 1.64e-03h  1
#   81  1.8147125e+06 3.39e+03 4.46e+07  -1.0 2.15e+05    -  2.73e-02 2.90e-02h  1
#   82  1.9095624e+06 3.36e+03 4.73e+07  -1.0 2.58e+05    -  4.53e-02 9.94e-03h  1
#   83  2.0571063e+06 3.31e+03 5.02e+07  -1.0 2.56e+05    -  5.59e-02 1.49e-02h  1
#   84  2.2598161e+06 3.24e+03 4.95e+07  -1.0 2.46e+05    -  2.18e-02 1.95e-02h  1
#   85  2.5077779e+06 3.17e+03 4.85e+07  -1.0 2.27e+05    -  2.48e-02 2.28e-02h  1
#   86  2.5244408e+06 3.16e+03 5.68e+07  -1.0 2.00e+05    -  9.01e-02 1.52e-03h  1
#   87  3.0398249e+06 3.02e+03 6.08e+07  -1.0 1.70e+05    -  1.11e-01 4.37e-02h  1
#   88  3.3531165e+06 2.95e+03 6.18e+07  -1.0 1.02e+05    -  4.99e-02 2.57e-02h  1
#   89  3.3570144e+06 2.95e+03 6.31e+07  -1.0 9.64e+04    -  1.17e-02 3.21e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  3.4028551e+06 2.93e+03 6.27e+07  -1.0 1.63e+05    -  1.69e-03 3.75e-03h  1
#   91  3.8558597e+06 2.83e+03 6.06e+07  -1.0 1.65e+05    -  3.67e-02 3.56e-02h  1
#   92  4.1536276e+06 2.76e+03 6.43e+07  -1.0 1.75e+05    -  6.47e-02 2.31e-02h  1
#   93  4.3620877e+06 2.72e+03 7.05e+07  -1.0 1.70e+05    -  7.41e-02 1.60e-02h  1
#   94  4.4162870e+06 2.71e+03 7.02e+07  -1.0 1.67e+05    -  3.75e-03 4.14e-03h  1
#   95  4.7316834e+06 2.65e+03 6.56e+07  -1.0 1.64e+05    -  5.57e-05 2.36e-02h  1
#   96  5.9920861e+06 2.41e+03 5.10e+07  -1.0 1.44e+05    -  2.44e-02 9.01e-02h  1
#   97  6.5535572e+06 2.30e+03 5.47e+07  -1.0 1.16e+05    -  8.24e-02 4.53e-02h  1
#   98  7.2285612e+06 2.18e+03 6.12e+07  -1.0 9.54e+04    -  1.07e-01 5.16e-02h  1
#   99  7.2393387e+06 2.18e+03 1.43e+08  -1.0 7.80e+04    -  4.61e-01 8.01e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  7.5565949e+06 2.14e+03 1.41e+08  -1.0 6.00e+04    -  1.79e-02 1.82e-02h  1
#  101  7.5817841e+06 2.14e+03 1.41e+08  -1.0 1.29e+05    -  1.04e-02 1.45e-03h  1
#  102  7.9345173e+06 2.09e+03 1.37e+08  -1.0 1.48e+05    -  5.85e-03 1.99e-02h  1
#  103  8.1978322e+06 2.06e+03 1.37e+08  -1.0 1.44e+05    -  3.19e-02 1.48e-02h  1
#  104  8.8010923e+06 1.99e+03 1.31e+08  -1.0 1.43e+05    -  1.74e-02 3.29e-02h  1
#  105  9.8937410e+06 1.88e+03 1.25e+08  -1.0 1.34e+05    -  7.53e-02 5.77e-02h  1
#  106  1.2811678e+07 1.61e+03 1.04e+08  -1.0 1.24e+05    -  1.18e-01 1.42e-01h  1
#  107  1.3568252e+07 1.55e+03 9.97e+07  -1.0 9.53e+04    -  3.17e-02 3.78e-02h  1
#  108  1.3657740e+07 1.54e+03 9.87e+07  -1.0 3.79e+04    -  1.80e-03 4.72e-03h  1
#  109  1.3771170e+07 1.53e+03 9.89e+07  -1.0 3.78e+04    -  1.01e-02 6.01e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  1.3969494e+07 1.52e+03 9.93e+07  -1.0 3.72e+04    -  1.77e-02 1.04e-02h  1
#  111  1.3982688e+07 1.52e+03 1.03e+08  -1.0 8.39e+04    -  1.80e-02 6.92e-04h  1
#  112  1.8685879e+07 1.18e+03 4.61e+07  -1.0 1.01e+05    -  4.30e-02 2.20e-01h  1
#  113  1.8897298e+07 1.17e+03 7.99e+07  -1.0 8.78e+04    -  1.66e-01 1.04e-02h  1
#  114  1.9926561e+07 1.12e+03 6.78e+07  -1.0 1.00e+05    -  1.90e-03 4.67e-02h  1
#  115  2.0786748e+07 1.07e+03 6.00e+07  -1.0 9.63e+04    -  1.12e-02 3.91e-02h  1
#  116  2.2775675e+07 9.78e+02 3.93e+07  -1.0 9.35e+04    -  4.53e-03 8.84e-02h  1
#  117  2.2819117e+07 9.76e+02 4.09e+07  -1.0 8.44e+04    -  9.45e-03 2.05e-03h  1
#  118  2.2948425e+07 9.70e+02 4.05e+07  -1.0 9.48e+04    -  5.86e-03 6.19e-03h  1
#  119  2.3286797e+07 9.54e+02 4.05e+07  -1.0 9.53e+04    -  1.84e-02 1.61e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  2.3715975e+07 9.35e+02 3.52e+07  -1.0 9.61e+04    -  3.46e-03 2.02e-02h  1
#  121  2.3732163e+07 9.34e+02 4.27e+07  -1.0 9.54e+04    -  2.88e-02 7.66e-04h  1
#  122  2.3867317e+07 9.28e+02 4.53e+07  -1.0 9.72e+04    -  1.75e-02 6.33e-03h  1
#  123  2.4024178e+07 9.22e+02 4.69e+07  -1.0 9.77e+04    -  1.48e-02 7.30e-03h  1
#  124  2.4188057e+07 9.15e+02 4.78e+07  -1.0 9.80e+04    -  1.27e-02 7.60e-03h  1
#  125  2.4355362e+07 9.08e+02 4.99e+07  -1.0 9.81e+04    -  1.77e-02 7.73e-03h  1
#  126  2.4552231e+07 8.99e+02 5.23e+07  -1.0 9.84e+04    -  2.05e-02 9.05e-03h  1
#  127  2.4775071e+07 8.90e+02 5.34e+07  -1.0 9.86e+04    -  1.70e-02 1.02e-02h  1
#  128  2.4992459e+07 8.81e+02 5.47e+07  -1.0 9.85e+04    -  1.78e-02 9.91e-03h  1
#  129  2.5215135e+07 8.72e+02 5.71e+07  -1.0 9.84e+04    -  2.29e-02 1.01e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  2.5466724e+07 8.62e+02 6.00e+07  -1.0 9.84e+04    -  2.66e-02 1.14e-02h  1
#  131  2.5752111e+07 8.51e+02 5.72e+07  -1.0 9.83e+04    -  3.67e-03 1.29e-02h  1
#  132  2.5916684e+07 8.45e+02 5.73e+07  -1.0 9.74e+04    -  1.02e-02 7.43e-03h  1
#  133  2.6111991e+07 8.38e+02 5.80e+07  -1.0 9.70e+04    -  1.43e-02 8.81e-03h  1
#  134  2.6331734e+07 8.29e+02 6.01e+07  -1.0 9.67e+04    -  2.24e-02 9.89e-03h  1
#  135  2.6591378e+07 8.20e+02 5.77e+07  -1.0 9.65e+04    -  3.16e-03 1.17e-02h  1
#  136  2.6753901e+07 8.14e+02 5.76e+07  -1.0 9.56e+04    -  9.00e-03 7.31e-03h  1
#  137  2.6938515e+07 8.07e+02 6.50e+07  -1.0 9.52e+04    -  4.63e-02 8.30e-03h  1
#  138  2.7301429e+07 7.94e+02 6.51e+07  -1.0 9.55e+04    -  2.23e-02 1.62e-02h  1
#  139  2.7589688e+07 7.84e+02 6.74e+07  -1.0 9.46e+04    -  2.93e-02 1.29e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140  2.7896094e+07 7.73e+02 6.81e+07  -1.0 9.39e+04    -  2.20e-02 1.37e-02h  1
#  141  2.7920325e+07 7.72e+02 7.13e+07  -1.0 9.30e+04    -  1.96e-02 1.09e-03h  1
#  142  2.8410032e+07 7.55e+02 6.84e+07  -1.0 9.32e+04    -  1.38e-02 2.18e-02h  1
#  143  2.8650285e+07 7.47e+02 6.64e+07  -1.0 9.13e+04    -  3.60e-03 1.08e-02h  1
#  144  2.8815625e+07 7.41e+02 6.47e+07  -1.0 9.01e+04    -  6.59e-04 7.48e-03h  1
#  145  2.8920052e+07 7.38e+02 6.80e+07  -1.0 9.23e+04    -  2.55e-02 4.75e-03h  1
#  146  2.9159086e+07 7.30e+02 6.69e+07  -1.0 9.96e+04    -  9.18e-03 1.09e-02h  1
#  147  2.9339218e+07 7.24e+02 6.69e+07  -1.0 1.00e+05    -  1.14e-02 8.22e-03h  1
#  148  2.9526930e+07 7.18e+02 6.64e+07  -1.0 1.01e+05    -  8.73e-03 8.58e-03h  1
#  149  2.9698763e+07 7.12e+02 6.63e+07  -1.0 1.01e+05    -  1.08e-02 7.86e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150  2.9883516e+07 7.06e+02 6.62e+07  -1.0 1.02e+05    -  1.13e-02 8.46e-03h  1
#  151  3.0066267e+07 7.00e+02 6.70e+07  -1.0 1.03e+05    -  1.70e-02 8.39e-03h  1
#  152  3.0280208e+07 6.93e+02 6.65e+07  -1.0 1.03e+05    -  1.09e-02 9.83e-03h  1
#  153  3.0476156e+07 6.87e+02 6.53e+07  -1.0 1.04e+05    -  4.66e-03 9.02e-03h  1
#  154  3.0617077e+07 6.83e+02 6.52e+07  -1.0 1.04e+05    -  8.81e-03 6.51e-03h  1
#  155  3.0786337e+07 6.77e+02 6.52e+07  -1.0 1.04e+05    -  1.12e-02 7.83e-03h  1
#  156  3.0958652e+07 6.72e+02 6.52e+07  -1.0 1.05e+05    -  1.19e-02 7.99e-03h  1
#  157  3.1141345e+07 6.66e+02 6.53e+07  -1.0 1.05e+05    -  1.25e-02 8.48e-03h  1
#  158  3.1329444e+07 6.60e+02 6.54e+07  -1.0 1.06e+05    -  1.34e-02 8.76e-03h  1
#  159  3.1524704e+07 6.54e+02 6.62e+07  -1.0 1.06e+05    -  1.92e-02 9.11e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  3.1743723e+07 6.48e+02 6.43e+07  -1.0 1.07e+05    -  1.51e-03 1.02e-02h  1
#  161  3.1868893e+07 6.44e+02 6.43e+07  -1.0 1.07e+05    -  8.40e-03 5.89e-03h  1
#  162  3.2023659e+07 6.39e+02 6.57e+07  -1.0 1.07e+05    -  2.00e-02 7.30e-03h  1
#  163  3.2239959e+07 6.32e+02 6.57e+07  -1.0 1.07e+05    -  1.41e-02 1.02e-02h  1
#  164  3.2438178e+07 6.27e+02 6.47e+07  -1.0 1.07e+05    -  7.29e-03 9.42e-03h  1
#  165  3.2596856e+07 6.22e+02 6.85e+07  -1.0 1.06e+05    -  3.17e-02 7.59e-03h  1
#  166  3.2867519e+07 6.14e+02 6.84e+07  -1.0 1.07e+05    -  1.74e-02 1.30e-02h  1
#  167  3.3092538e+07 6.07e+02 7.81e+07  -1.0 1.08e+05    -  6.35e-02 1.08e-02h  1
#  168  3.3490745e+07 5.95e+02 8.57e+07  -1.0 1.21e+05    -  6.58e-02 1.91e-02h  1
#  169  3.3924195e+07 5.83e+02 8.22e+07  -1.0 1.44e+05    -  1.16e-02 2.08e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  3.4188619e+07 5.76e+02 7.90e+07  -1.0 1.40e+05    -  7.97e-04 1.28e-02h  1
#  171  3.4345662e+07 5.71e+02 8.37e+07  -1.0 1.37e+05    -  3.74e-02 7.63e-03h  1
#  172  3.4692401e+07 5.62e+02 8.16e+07  -1.0 1.36e+05    -  1.28e-02 1.68e-02h  1
#  173  3.4928987e+07 5.55e+02 8.04e+07  -1.0 1.35e+05    -  9.79e-03 1.15e-02h  1
#  174  3.5144608e+07 5.49e+02 7.80e+07  -1.0 1.33e+05    -  1.49e-03 1.06e-02h  1
#  175  3.5290766e+07 5.45e+02 7.71e+07  -1.0 1.33e+05    -  4.81e-03 7.19e-03h  1
#  176  3.5446240e+07 5.41e+02 7.65e+07  -1.0 1.32e+05    -  7.54e-03 7.67e-03h  1
#  177  3.5604846e+07 5.37e+02 7.58e+07  -1.0 1.31e+05    -  7.26e-03 7.84e-03h  1
#  178  3.5760013e+07 5.33e+02 7.50e+07  -1.0 1.30e+05    -  6.27e-03 7.69e-03h  1
#  179  3.5906729e+07 5.29e+02 7.57e+07  -1.0 1.30e+05    -  1.55e-02 7.29e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  3.6099291e+07 5.24e+02 7.44e+07  -1.0 1.30e+05    -  5.54e-03 9.58e-03h  1
#  181  3.6244936e+07 5.20e+02 7.38e+07  -1.0 1.30e+05    -  7.08e-03 7.28e-03h  1
#  182  3.6393061e+07 5.16e+02 7.32e+07  -1.0 1.31e+05    -  7.10e-03 7.42e-03h  1
#  183  3.6542295e+07 5.12e+02 7.28e+07  -1.0 1.31e+05    -  8.66e-03 7.50e-03h  1
#  184  3.6684429e+07 5.09e+02 7.18e+07  -1.0 1.33e+05    -  3.65e-03 7.16e-03h  1
#  185  3.6795446e+07 5.06e+02 7.29e+07  -1.0 1.34e+05    -  1.59e-02 5.61e-03h  1
#  186  3.6963119e+07 5.01e+02 7.40e+07  -1.0 1.38e+05    -  1.97e-02 8.48e-03h  1
#  187  3.7131935e+07 4.97e+02 8.27e+07  -1.0 1.45e+05    -  7.36e-02 8.55e-03h  1
#  188  3.7445342e+07 4.89e+02 8.48e+07  -1.0 2.11e+05    -  4.15e-02 1.59e-02h  1
#  189  3.7732181e+07 4.82e+02 8.66e+07  -1.0 2.46e+05    -  3.79e-02 1.46e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190  3.8018110e+07 4.75e+02 9.36e+07  -1.0 2.13e+05    -  8.28e-02 1.46e-02h  1
#  191  3.8437152e+07 4.65e+02 9.01e+07  -1.0 2.16e+05    -  7.85e-03 2.14e-02h  1
#  192  3.8451047e+07 4.65e+02 9.01e+07  -1.0 1.93e+05    -  9.53e-04 7.22e-04h  1
#  193  3.8452426e+07 4.65e+02 9.81e+07  -1.0 1.72e+05    -  7.36e-02 7.32e-05h  1
#  194  3.9064399e+07 4.50e+02 9.25e+07  -1.0 1.41e+05    -  8.59e-03 3.20e-02h  1
#  195  3.9305739e+07 4.44e+02 1.17e+08  -1.0 1.25e+05    -  2.71e-01 1.28e-02h  1
#  196  4.0081470e+07 4.26e+02 1.12e+08  -1.0 7.33e+04    -  3.75e-02 4.03e-02h  1
#  197  4.0498039e+07 4.17e+02 1.36e+08  -1.0 6.43e+04    -  4.18e-01 2.20e-02h  1
#  198  4.1363713e+07 3.98e+02 1.28e+08  -1.0 6.06e+04    -  7.54e-03 4.52e-02h  1
#  199  4.1383039e+07 3.97e+02 1.28e+08  -1.0 1.83e+05    -  3.78e-04 1.05e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200  4.1397792e+07 3.97e+02 1.30e+08  -1.0 2.36e+05    -  5.70e-02 8.02e-04h  1
#  201  4.2789041e+07 3.68e+02 1.18e+08  -1.0 1.08e+05    -  3.75e-03 7.37e-02h  1
#  202  4.2828339e+07 3.67e+02 1.33e+08  -1.0 4.24e+04    -  3.18e-01 2.19e-03h  1
#  203  4.5033264e+07 3.24e+02 1.10e+08  -1.0 2.64e+04    -  1.77e-02 1.18e-01h  1
#  204  4.5426731e+07 3.16e+02 1.14e+08  -1.0 3.11e+04    -  1.02e-01 2.29e-02h  1
#  205  4.5844740e+07 3.08e+02 1.10e+08  -1.0 3.71e+04    -  1.87e-03 2.45e-02h  1
#  206  4.5851444e+07 3.08e+02 1.27e+08  -1.0 3.77e+04    -  2.40e-01 4.00e-04h  1
#  207  4.7378281e+07 2.81e+02 1.12e+08  -1.0 4.90e+04    -  1.81e-02 8.87e-02h  1
#  208  4.7514624e+07 2.79e+02 1.41e+08  -1.0 4.24e+04    -  6.08e-01 8.46e-03h  1
#  209  4.9951370e+07 2.38e+02 1.21e+08  -1.0 3.63e+04    -  1.60e-01 1.45e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210  5.0771195e+07 2.25e+02 1.24e+08  -1.0 2.87e+04    -  8.74e-01 5.47e-02h  1
#  211  5.1231046e+07 2.18e+02 1.20e+08  -1.0 2.51e+04    -  5.12e-01 3.19e-02h  1
#  212  5.1384453e+07 2.16e+02 1.18e+08  -1.0 2.45e+04    -  9.93e-01 1.09e-02h  1
#  213  5.1807925e+07 2.09e+02 1.14e+08  -1.0 2.43e+04    -  3.31e-01 3.03e-02h  1
#  214  5.4301232e+07 1.72e+02 9.40e+07  -1.0 2.32e+04    -  2.75e-01 1.77e-01h  1
#  215  5.4453584e+07 1.70e+02 9.17e+07  -1.0 2.59e+04    -  3.36e-01 1.27e-02h  1
#  216  5.6247833e+07 1.45e+02 7.83e+07  -1.0 2.84e+04    -  2.06e-01 1.48e-01h  1
#  217  5.6640661e+07 1.39e+02 7.65e+07  -1.0 1.80e+04    -  1.11e-01 3.72e-02h  1
#  218  5.6668819e+07 1.39e+02 1.01e+08  -1.0 1.49e+04    -  1.00e+00 2.76e-03h  1
#  219  6.0010229e+07 9.54e+01 6.85e+07  -1.0 1.62e+04    -  3.86e-02 3.14e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220  6.0685569e+07 8.69e+01 6.33e+07  -1.0 1.14e+04    -  1.00e+00 8.86e-02h  1
#  221  6.1383136e+07 7.83e+01 5.69e+07  -1.0 1.06e+04    -  6.53e-01 9.89e-02h  1
#  222  6.1394518e+07 7.82e+01 5.63e+07  -1.0 9.56e+03    -  1.00e+00 1.78e-03h  1
#  223  6.2031010e+07 7.04e+01 5.28e+07  -1.0 9.60e+03    -  8.23e-01 9.91e-02h  1
#  224  6.2360273e+07 6.65e+01 5.27e+07  -1.0 9.55e+03    -  1.00e+00 5.64e-02h  1
#  225  6.2955620e+07 5.94e+01 4.88e+07  -1.0 9.42e+03    -  9.47e-01 1.07e-01h  1
#  226  6.4806183e+07 3.79e+01 3.20e+07  -1.0 8.47e+03    -  1.00e+00 3.61e-01h  1
#  227  6.4830246e+07 3.76e+01 3.08e+07  -1.0 5.41e+03    -  1.00e+00 7.22e-03h  1
#  228  6.4842017e+07 3.75e+01 2.31e+08  -1.0 3.35e+03    -  1.00e+00 3.60e-03h  1
#  229  6.6191153e+07 2.30e+01 1.68e+08  -1.0 2.74e+03    -  1.00e+00 3.88e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230  6.6597307e+07 1.88e+01 1.40e+08  -1.0 1.48e+03    -  9.50e-01 1.79e-01h  1
#  231  6.6631342e+07 1.85e+01 1.38e+08  -1.0 1.15e+03    -  1.00e+00 1.80e-02h  1
#  232  6.7526051e+07 9.85e+00 7.35e+07  -1.0 1.11e+03    -  2.91e-01 4.68e-01h  1
#  233  6.8112058e+07 4.41e+00 3.31e+07  -1.0 5.97e+02    -  1.00e+00 5.52e-01h  1
#  234  6.8447734e+07 1.38e+00 1.04e+07  -1.0 2.71e+02    -  1.00e+00 6.88e-01h  1
#  235  6.8492650e+07 9.76e-01 7.43e+06  -1.0 8.63e+01    -  9.94e-01 2.91e-01h  1
#  236  6.8601219e+07 1.02e-02 7.75e+04  -1.0 6.13e+01    -  1.00e+00 9.90e-01h  1
#  237  6.8602361e+07 2.70e-08 7.73e-02  -1.0 2.05e+00    -  1.00e+00 1.00e+00h  1
#  238  6.8602295e+07 2.69e-07 1.72e+05  -7.0 1.90e+01    -  9.50e-01 9.99e-01f  1
#  239  6.8602295e+07 1.06e-08 4.43e+03  -7.0 1.07e+01    -  9.75e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240  6.8602295e+07 2.79e-09 3.44e+00  -7.0 5.43e+00    -  9.99e-01 1.00e+00f  1
#  241  6.8602295e+07 1.83e-04 6.16e-06  -7.0 2.71e+00    -  1.00e+00 1.00e+00f  1
#  242  6.8602295e+07 1.43e-04 1.24e-06  -7.0 1.21e+00    -  1.00e+00 1.00e+00h  1
#  243  6.8602295e+07 2.33e-10 2.98e-07  -7.0 4.19e-01    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 243
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.8602294701723933e+07    6.8602294701723933e+07
# Dual infeasibility......:   2.9802322387695318e-07    2.9802322387695318e-07
# Constraint violation....:   2.3283064365386963e-10    2.3283064365386963e-10
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   1.5122827164668625e-05    1.5122827164668625e-05
# Overall NLP error.......:   1.5052970482351269e-09    1.5122827164668625e-05
#
#
# Number of objective function evaluations             = 244
# Number of objective gradient evaluations             = 244
# Number of equality constraint evaluations            = 244
# Number of inequality constraint evaluations          = 244
# Number of equality constraint Jacobian evaluations   = 244
# Number of inequality constraint Jacobian evaluations = 244
# Number of Lagrangian Hessian evaluations             = 243
# Total seconds in IPOPT                               = 11.695
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms ( 12.30us)   6.36ms ( 26.07us)       244
#        nlp_g  |  80.00ms (327.87us)  48.16ms (197.38us)       244
#   nlp_grad_f  |  18.00ms ( 73.47us)  12.54ms ( 51.17us)       245
#   nlp_hess_l  | 135.00ms (555.56us) 199.54ms (821.14us)       243
#    nlp_jac_g  | 134.00ms (546.94us) 101.38ms (413.79us)       245
#        total  |  11.69 s ( 11.69 s)  11.70 s ( 11.70 s)         1

# %%
for i, phase in enumerate(phases):
        # print(f"\nPhase: {phase['name']}")
        X_debug = sol.value(X_list[i])
        U_debug = sol.value(U_list[i])
        T_debug = sol.value(T_list[i])

        # print("  States (X) [v, fpa, h, s, m]:")
        # print(X_debug)
        # print("  Controls (U) [thrust, fpa, spdbrk]:")
        # print(U_debug)
        print(f"  Duration (T): {T_debug}")

        # if "Infeasible_Problem_Detected" in str(e):
            # print("Solver detected infeasibility. Analyzing...")
            # opti.debug.show_infeasibilities()  # Show summary


        # Plot the states
        #from state_plot import plot_states, plot_states_ext
        #plot_states(X_debug[0], X_debug[1], X_debug[2], X_debug[3], X_debug[4], U_debug[0], U_debug[1], U_debug[2])
# Out:
#   Duration (T): 228.50582352859269
#   Duration (T): 483.3114223544508
#   Duration (T): 3363.7365295315185
#   Duration (T): 1404.000014039999
#   Duration (T): 319.1037184652664
#   Duration (T): 156.0000015599998

# %%
from state_plot import plot_states_with_phases_clb2ds3
plot_states_with_phases_clb2ds3(sol.value(X_list[0]), sol.value(X_list[1]), sol.value(X_list[2]), sol.value(X_list[3]), sol.value(X_list[4]), sol.value(X_list[5]),
                        sol.value(U_list[0]), sol.value(U_list[1]), sol.value(U_list[2]), sol.value(U_list[3]), sol.value(U_list[4]), sol.value(U_list[5]),
                        [sol.value(T_list[i]) for i in range(len(T_list))])

# %%
for i, phase in enumerate(phases):
    # print(f"\nPhase: {phase['name']}")
    X_debug = opti.debug.value(X_list[i])
    U_debug = opti.debug.value(U_list[i])
    T_debug = opti.debug.value(T_list[i])

    # print("  States (X) [v, fpa, h, s, m]:")
    # print(X_debug)
    # print("  Controls (U) [thrust, fpa, spdbrk]:")
    # print(U_debug)
    print(f"Phase {phase['name']}, Duration {T_debug}")

    # if "Infeasible_Problem_Detected" in str(e):
        # print("Solver detected infeasibility. Analyzing...")
        # opti.debug.show_infeasibilities()  # Show summary


    # Plot the states
    from state_plot import plot_states, plot_states_ext
    plot_states(X_debug[0], X_debug[1], X_debug[2], X_debug[3], X_debug[4], U_debug[0], U_debug[1], U_debug[2])

    X_ext = np.empty((7, phase['N']))

    # Compute the additional variables
    for k in range(phase['N']):
        xk = X_debug[:,k]
        uk = U_debug[:,k]
        dyn_func = aircraft_dynamics(xk, uk, opti.debug.value(wind_s), opti.debug.value(phi), phase['name'], fiche_engine, fiche_ac, fiche_control)
        dyn_values = opti.debug.value(dyn_func)

        #Further break down
        g = 9.81
        k_gamma = fiche_control['k_gamma']
        v, gamma, h, s, m = xk[0], xk[1], xk[2], xk[3], xk[4]
        T, gamma_ref, beta = uk[0], uk[1], uk[2]
        rho0 = 1.225
        H = 8500.0
        rho = rho0 * np.exp(-h / H)  # Use numpy for scalar calculations during debugging
        nz = (-v * k_gamma * (gamma - gamma_ref) + g * np.cos(gamma))/(g * np.cos(0))
        L = nz * m * g
        epsilon = 1e-6
        v_sq = v**2 + epsilon
        S_area = fiche_ac['wing']['area']
        Cl = L / (0.5 * rho * v_sq * S_area)
        k_drag = fiche_ac['drag']['k']
        Cd = fiche_ac['drag']['cd0'] + beta + k_drag * Cl**2
        D = 0.5 * rho * v**2 * S_area * Cd

        # Fuel flow model (different for each phase)
        if phase['name'] in ['cruise', 'landing', 'descent1', 'descent2']:
            cruise_sfc = fiche_engine['cruise_sfc'] / 3600.0  # [kg/(N·s)]
            fuel_coef = fiche_ac['fuel']['fuel_coef']
            fuel_flow = fuel_coef * cruise_sfc * T
        elif phase['name'] == 'takeoff':
            fuel_flow = fiche_engine['ff_to'] * 2
        elif phase['name'] in ['climb1', 'climb2', 'climb3']:
            fuel_flow = fiche_engine['ff_co'] * 2
        # elif phase['name'] in ['descent1', 'descent2']:
        #     fuel_flow = fiche_engine['ff_app'] * 2
        # elif phase['name'] == 'landing':
        #     fuel_flow = fiche_engine['ff_idl'] * 2
        else:
            fuel_flow = 0.0

        X_ext[:,k] = np.array([L, D, nz, Cl, Cd, rho, fuel_flow])

        if np.isnan(X_ext[:,k]).any():
            print(f"NaN detected at index {k}")
            print(f"X_ext[:,k]: {X_ext[:,k]}")
            print(f"X_ext: {X_ext}")
            print(f"X_ext[0]: {X_ext[0]}")
            print(f"X_ext[1]: {X_ext[1]}")
        
    plot_states_ext(X_ext[0], X_ext[1], X_ext[2], X_ext[3], X_ext[4], X_ext[5], X_ext[6])
# Out:
# Phase climb1, Duration 228.50582352859269
# Phase climb2, Duration 483.3114223544508
# Phase cruise, Duration 3363.7365295315185
# Phase descent1, Duration 1404.000014039999
# Phase descent2, Duration 319.1037184652664
# Phase landing, Duration 156.0000015599998
