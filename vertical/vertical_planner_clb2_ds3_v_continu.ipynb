# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Problem Inputs

# %%
import casadi as ca
import numpy as np
import matplotlib.pyplot as plt
from openap import prop

# -------------------------
# 0. Load aircraft and engine data
# -------------------------
fiche_ac = prop.aircraft("A320")
fiche_engine = prop.engine("CFM56-5-A1")
# Ensure all engine parameters are valid
for key in fiche_engine:
    if isinstance(fiche_engine[key], (int, float)):
        if np.isnan(fiche_engine[key]) or fiche_engine[key] <= 0:
            print(f"Warning: Invalid engine parameter: {key}")
print('Check these warnings carefully since they may cause NaNs in the optimization.')

fiche_engine['cruise_sfc'] = 16.9 / 1000 # kg/(N.s), from Wikipedia 

fiche_control = {
    'k_gamma': 0.45  # P controller gain for flight path angle
}

# Problem Inputs ----------
FL_CRZ = 37000
S_MAX = 684 * 1852
# -------------------------

# 1. Conversion factors and target values
# -------------------------
knots_to_ms = 0.514444
ft_to_m     = 0.3048

# Speeds (m/s)
v_250    = 250 * knots_to_ms       # ~128.61 m/s
v_300    = 300 * knots_to_ms       # ~154.33 m/s
v_mach78 = 0.78 * 340              # ~265.2 m/s (approx.)
v_180    = 180 * knots_to_ms 


# Altitudes (m)
h_takeoff_end  = 1000  * ft_to_m    # 1,000 ft
h_climb1_end   = 10000 * ft_to_m    # 10,000 ft (~3048 m)
h_climb2_end   = FL_CRZ * ft_to_m    # 35,000 ft (~10668 m) transition altitude
h_cruise       = FL_CRZ * ft_to_m    # 35,000 ft (~10668 m)
h_descent1_end = 10000 * ft_to_m    # 10,000 ft (~3048 m)
h_descent2_end = 3000 * ft_to_m    # 3,000 ft (~914.4 m)
h_landing_end  = 0.0               # ground
# Out:
# Warning: Invalid engine parameter: cruise_thrust
# Warning: Invalid engine parameter: cruise_sfc
# Warning: Invalid engine parameter: cruise_mach
# Warning: Invalid engine parameter: cruise_alt
# Check these warnings carefully since they may cause NaNs in the optimization.

# %% [markdown]
# # Aircraft Dynamics

# %%
# -------------------------
# 2. Define the aircraft dynamics function (same as before)
# -------------------------
def aircraft_dynamics(x, u, wind_s, phi, phase, fiche_engine, fiche_ac, fiche_control, num_engines = 2):
    """
    Computes the state derivative for the vertical dynamics.
    x = [v, gamma, h, s, m] # speed, flight path angle, altitude, along-path distance, mass
    u = [T, gamma_ref, beta] # thrust, reference flight path angle, speedbrake parameter
    """
    g = 9.81  # gravitational acceleration (m/s^2)

    # Unpack control parameters
    k_gamma = fiche_control['k_gamma']
    
    # Unpack state and control
    v, gamma, h, s, m = x[0], x[1], x[2], x[3], x[4]  # speed, flight path angle, altitude, along-path distance, mass
    T, gamma_ref, beta = u[0], u[1], u[2]  # thrust, controlled flight path angle, speedbrake parameter
    
    # --- Drag Model ---
    rho0 = 1.225  # sea-level density [kg/m^3]
    H    = 8500.0 # scale height [m]
    rho  = rho0 * ca.exp(-h/H) # air density [kg/m^3]

    # --- Load factor calculation ---
    nz = (-v * k_gamma * (gamma - gamma_ref) + g * ca.cos(gamma))/(g * ca.cos(phi))

    # --- Lift/Drag Calculations ---
    L = nz * m * g  # Required lift force
    epsilon = 1e-6  # small number to avoid division by zero
    v_sq = v**2 + epsilon

    S_area = fiche_ac['wing']['area']  # wing area [m^2]
    Cl = L / (0.5 * rho * v_sq * S_area)
    
    k = fiche_ac['drag']['k']
    Cd = fiche_ac['drag']['cd0'] + beta + k * Cl**2  # parabolic drag model
    D = 0.5 * rho * v**2 * S_area * Cd  # Drag force [N]

    # Fuel flow model (different for each phase)
    if phase in ['cruise', 'descent1', 'descent2', 'landing']:
        cruise_sfc = fiche_engine['cruise_sfc'] / 3600.0  # [kg/(N·s)]
        fuel_coef = fiche_ac['fuel']['fuel_coef']
        fuel_flow = fuel_coef * cruise_sfc * T
    elif phase == 'takeoff':
        fuel_flow = fiche_engine['ff_to'] * num_engines
    elif phase in ['climb1', 'climb2', 'climb3']:
        fuel_flow = fiche_engine['ff_co'] * num_engines
    # elif phase in ['descent1', 'descent2']:
    #     fuel_flow = fiche_engine['ff_app'] * num_engines
    # elif phase == 'landing':
    #     fuel_flow = fiche_engine['ff_idl'] * num_engines
    
    # Dynamics equations
    v_dot     = (T - D) / m - g * ca.sin(gamma)
    gamma_dot = k_gamma * (gamma_ref - gamma)
    h_dot     = v * ca.sin(gamma)
    s_dot     = v * ca.cos(gamma) + wind_s
    m_dot     = -fuel_flow
    
    return ca.vertcat(v_dot, gamma_dot, h_dot, s_dot, m_dot)

# %% [markdown]
# # Phases

# %%
# -------------------------
# 3. Phase definitions
# -------------------------
# We define three phases:
#   - climb1: from 0 ft to 10,000 ft, target speed 250 kts.
#   - climb2: from 10,000 ft to 18,000 ft, target speed 300 kts.
#   - cruise: from 18,000 ft to 35,000 ft, target speed Mach 0.78.

h_takeoff_end  = 1000  * ft_to_m    # 1,000 ft
h_climb1_end   = 10000 * ft_to_m    # 10,000 ft (~3048 m)
h_climb2_end   = FL_CRZ * ft_to_m    # 35,000 ft (~10668 m) transition altitude
h_cruise       = FL_CRZ * ft_to_m    # 35,000 ft (~10668 m)
h_descent1_end = 10000 * ft_to_m    # 10,000 ft (~3048 m)
h_descent2_end = 3000 * ft_to_m    # 3,000 ft (~914.4 m)
h_landing_end  = 0.0               # ground

phases = [
    {"name": "climb1", "N": 50, "h0": 0.0,          "hF": h_climb1_end,  "v_target": v_250},
    {"name": "climb2", "N": 50, "h0": h_climb1_end,  "hF": h_climb2_end,  "v_target": v_300},
    {"name": "cruise", "N": 100, "h0": h_climb2_end,  "hF": h_cruise,      "v_target": v_mach78},
    {"name": "descent1", "N": 100, "h0": h_cruise, "hF": h_descent1_end, "v_target": v_300},
    {"name": "descent2", "N": 50, "h0": h_descent1_end, "hF": h_descent2_end, "v_target": v_250},
    {"name": "landing", "N": 50, "h0": h_descent2_end, "hF": h_landing_end, "v_target": v_180}
]

# %%
# -------------------------
# 4. Set up the Opti problem and common parameters
# -------------------------
opti = ca.Opti()

wind_s = opti.parameter();  opti.set_value(wind_s, 0.0)
phi    = opti.parameter();  opti.set_value(phi, 0.0)
CI     = opti.parameter();  opti.set_value(CI, 100.0)

X_list = []  # states for each phase
U_list = []  # controls for each phase
T_list = []  # phase durations
N_list = []  # discretization intervals
phase_names = []

# %% [markdown]
# # Altitude, Speed Boundaries, Phase Time and State Limits

# %%
# -------------------------
# 5. Create decision variables for each phase
# -------------------------

# Slack variables for soft constraints about speed and altitude
V_slacks = []
H_slacks = []

for i, phase in enumerate(phases):
    name = phase["name"]
    phase_names.append(name)
    N_phase = phase["N"]
    N_list.append(N_phase)
    
    T_phase = opti.variable()
    opti.subject_to(T_phase >= 0)
    T_list.append(T_phase)
    if name == 'climb1':
        opti.set_initial(T_phase, 10_000 / (3000 / 60)) # climb at 3000 ft/mi
    elif name == 'climb2':
        opti.set_initial(T_phase, (FL_CRZ - 10_000) / (3000 / 60)) # climb at 3000 ft/min
    elif name == 'descent1':
        opti.set_initial(T_phase, (FL_CRZ - 10_000) / (1500 / 60)) # descent at 1500 ft/min
        opti.subject_to(T_phase < 1.3 * (FL_CRZ - 10_000) / (1500 / 60))
    elif name == 'descent2':
        opti.set_initial(T_phase, 7_000 / (1500 / 60)) # descent at 1500 ft/min
        opti.subject_to(T_phase < 1.3 * 7_000 / (1500 / 60))
    elif name == "landing":
        opti.set_initial(T_phase, 3_000 / (1500 / 60))
        opti.subject_to(T_phase < 1.3 * 3_000 / (1500 / 60))
    elif name == "cruise":
        opti.set_initial(T_phase, 0.7 * S_MAX / v_250)
        opti.subject_to(T_phase >= 0.5 * S_MAX / v_250)
    # if name == "descent1":
    #     opti.set_initial(T_phase, 0.15 * S_MAX / v_250)
    #     opti.subject_to(T_phase >= 0.05 * S_MAX / v_250)
    # if name == "descent2":
    #     opti.set_initial(T_phase, 0.1 * S_MAX / v_250)
    #     opti.subject_to(T_phase >= 0.05 * S_MAX / v_250)
    dt = T_phase / N_phase  # time step
    
    # State vector: [v, gamma, h, s, m] over (N_phase+1) nodes
    X = opti.variable(5, N_phase+1) # N_phase+1 time steps
    # Control vector: [T, gamma_ref, beta] over N_phase intervals
    U = opti.variable(3, N_phase)
    
    X_list.append(X)
    U_list.append(U)
    
    # Multiple shooting dynamics via explicit Euler integration
    for k in range(N_phase): # between N_phase + 1 time steps are N_phase intervals
        xk = X[:, k]
        uk = U[:, k]
        x_next = X[:, k+1]
        x_next_euler = xk + dt * aircraft_dynamics(xk, uk, wind_s, phi, name, fiche_engine, fiche_ac, fiche_control)
        opti.subject_to(x_next == x_next_euler)
    
    # Altitude boundary conditions for each phase (altitude at the beginning and end of each phase)
    # Soft constraints for initial and final altitude with slack variables
    h_slack_init = opti.variable()
    h_slack_final = opti.variable()
    opti.set_initial(h_slack_init, 0)
    opti.set_initial(h_slack_final, 0)
    
    max_alt_dev = 100.0  # Allow ±50m deviation
    opti.subject_to(h_slack_init <= max_alt_dev)
    opti.subject_to(h_slack_init >= -max_alt_dev)
    opti.subject_to(h_slack_final <= max_alt_dev) 
    opti.subject_to(h_slack_final >= -max_alt_dev)
    
    opti.subject_to(X[2, 0] == phase["h0"] + h_slack_init)
    opti.subject_to(X[2, -1] == phase["hF"] + h_slack_final)
    
    # Enforce prescribed speed if provided
    # if phase["v_target"] is not None:
    #     for k in range(N_phase+1):
    #         opti.subject_to(X[0, k] == phase["v_target"])
    
    # Soft constraints on prescribed speed and altitude
    V_slack = opti.variable(N_phase + 1)
    H_slack = opti.variable(N_phase + 1)
    opti.set_initial(V_slack, 0) # set initial guess for slack variables
    if phase["v_target"] is not None:
        max_speed_dev = 10.0  # Allow ±20 m/s deviation
        
        if phase['name'] == 'climb1':
            for k in range(N_phase + 1):
                opti.subject_to(V_slack[k] <= max_speed_dev)
                opti.subject_to(V_slack[k] >= -max_speed_dev)
                opti.subject_to(X[0, k] == phase["v_target"] + V_slack[k])

        elif phase['name'] == 'climb2':
            last_phase = phases[i-1]
            for k in range(5): # first 5 timesteps, accelerating from last phase's speed
                if k == 0:
                    opti.subject_to(V_slack[k] > 0)
                else:
                    opti.subject_to(V_slack[k] > V_slack[k-1])
                opti.subject_to(V_slack[k] <= phase["v_target"] - last_phase["v_target"])
                opti.subject_to(X[0, k] == last_phase["v_target"] + V_slack[k])
            for k in range(5, N_phase + 1): # middle timesteps
                opti.subject_to(V_slack[k] <= max_speed_dev)
                opti.subject_to(V_slack[k] >= -max_speed_dev)
                opti.subject_to(X[0, k] == phase["v_target"] + V_slack[k])

        elif phase['name'] == 'cruise':
            last_phase = phases[i-1]
            for k in range(5): # first 5 timesteps, accelerating from last phase's speed
                if k == 0:
                    opti.subject_to(V_slack[k] > 0)
                else:
                    opti.subject_to(V_slack[k] > V_slack[k-1])
                    opti.subject_to(V_slack[k] <= phase["v_target"] - last_phase["v_target"])
                opti.subject_to(X[0, k] == last_phase["v_target"] + V_slack[k])
            for k in range(5, N_phase + 1): # middle timesteps
                opti.subject_to(V_slack[k] <= max_speed_dev)
                opti.subject_to(V_slack[k] >= -max_speed_dev)
                opti.subject_to(X[0, k] == phase["v_target"] + V_slack[k])

        elif phase['name'] in ['descent1', 'descent2', 'landing']:
            last_phase = phases[i-1]
            for k in range(10): # first 5 timesteps, decelerating from last phase's speed
                if k == 0:
                    opti.subject_to(V_slack[k] < 0)
                else:
                    opti.subject_to(V_slack[k] < V_slack[k-1])
                opti.subject_to(V_slack[k] >= phase["v_target"] - last_phase["v_target"])
                opti.subject_to(X[0, k] == last_phase["v_target"] + V_slack[k])
            for k in range(10, N_phase + 1): # middle timesteps
                opti.subject_to(V_slack[k] <= max_speed_dev)
                opti.subject_to(V_slack[k] >= -max_speed_dev)
                opti.subject_to(X[0, k] == phase["v_target"] + V_slack[k])

        else:
            for k in range(N_phase + 1):
                opti.subject_to(V_slack[k] <= max_speed_dev)
            opti.subject_to(V_slack[k] >= -max_speed_dev)
            opti.subject_to(X[0, k] == phase["v_target"] + V_slack[k])
    else:
        # For phases without a prescribed speed, enforce zero slack.
        for k in range(N_phase + 1):
            opti.subject_to(V_slack[k] == 0)
    V_slacks.append(V_slack)
    
    # For cruise phase, enforce constant altitude along the entire phase
    # if name == "cruise":
    #     for k in range(N_phase + 1):
    #         opti.subject_to(X[2, k] == h_cruise)
    
    # For cruise phase, use soft constraints for altitude
    H_slack = opti.variable(N_phase + 1)
    opti.set_initial(H_slack, 0) # set initial guess for slack variables
    if name == "cruise":
        max_alt_dev = 100.0  # Allow ±100 m deviation
        for k in range(N_phase + 1):
            opti.subject_to(H_slack[k] <= max_alt_dev)
            opti.subject_to(H_slack[k] >= -max_alt_dev)
            opti.subject_to(X[2, k] == h_cruise + H_slack[k])
    elif name in ['descent1', 'descent2', 'landing']:
        last_phase = phases[i-1]
        last_phase_alt = last_phase.get("hF")
        current_phase_alt = phase.get("hF")
        
        max_alt_dev = 100.0  # Allow ±100 m deviation
        for k in range(N_phase + 1):
            # Linear interpolation between altitudes
            target_alt = last_phase_alt + (current_phase_alt - last_phase_alt) * (k / N_phase)
            
            opti.subject_to(H_slack[k] <= max_alt_dev)
            opti.subject_to(H_slack[k] >= -max_alt_dev)
            opti.subject_to(X[2, k] == target_alt + H_slack[k])
    else:
        # For phases other than cruise, enforce zero slack.
        for k in range(N_phase + 1):
            opti.subject_to(H_slack[k] == 0)
    H_slacks.append(H_slack)


    # Additional state bounds (applied at every node)
    for k in range(N_phase+1):
        opti.subject_to(X[0, k] >= 0)        # v lower bound
        opti.subject_to(X[0, k] <= 350)      # v upper bound
        opti.subject_to(X[1, k] >= -0.5)       # gamma lower bound
        opti.subject_to(X[1, k] <= 0.5)        # gamma upper bound
        opti.subject_to(X[2, k] >= 0)          # altitude lower bound
        opti.subject_to(X[2, k] <= 12000)      # altitude upper bound (sufficient for cruise)
        opti.subject_to(X[3, k] >= 0)          # along-path distance lower bound
        opti.subject_to(X[4, k] >= 30000)      # mass lower bound
        opti.subject_to(X[4, k] <= 90000)      # mass upper bound
    
    # Control bounds for each interval
    for k in range(N_phase):
        opti.subject_to(U[0, k] >= 0.1 * fiche_engine['max_thrust'])        # Thrust lower bound
        opti.subject_to(U[0, k] <= fiche_engine['max_thrust'])   # Thrust upper bound
        opti.subject_to(U[1, k] >= -0.5)       # gamma_ref lower bound
        opti.subject_to(U[1, k] <= 0.5)        # gamma_ref upper bound
        opti.subject_to(U[2, k] >= 0.0)        # beta lower bound
        opti.subject_to(U[2, k] <= 0.02)        # beta upper bound

# %% [markdown]
# # Phase Continuity

# %%
# -------------------------
# 6. Impose continuity between phases
# -------------------------
# Ensure that the final state of phase i equals the initial state of phase i+1.
for i in range(len(phases)-1):
    opti.subject_to(X_list[i+1][:, 0] == X_list[i][:, -1]) # skip velocity mismatch

# %% [markdown]
# # Initial and Final Conditions

# %%
# -------------------------
# 7. Impose boundary conditions on the first phase (takeoff/climb1)
# -------------------------
# Initial state: [v, gamma, h, s, m]
x0 = np.array([v_250, 0.0, 0.0, 0.0, 70000.0])
opti.set_initial(X_list[0][:, 0], x0)
opti.subject_to(X_list[0][3, 0] == 0.0)   # along-path distance

# Until traveled distance s is 200_000m - only constrain final point
# opti.subject_to(X_list[-1][3, -1] == 200_000)

# At final descent, the traveled distance (soft constraint)
S_slack = opti.variable()  # Slack variable for distance constraint
opti.subject_to(S_slack >= 0)  # Slack must be non-negative
opti.subject_to(X_list[-1][3, -1] + S_slack >= S_MAX)  # Soft constraint with slack

# For climb1, ensure the final speed is the prescribed v_250
# opti.subject_to(X_list[0][0, -1] == v_250)

# %% [markdown]
# # Cost Function

# %%
# -------------------------
# 8. Define the overall cost function
# -------------------------
# Here, the cost in each phase is integrated over time.
total_cost = 0
for i, phase in enumerate(phases):
    N_phase = phase["N"]
    T_phase = T_list[i]
    dt = T_phase / N_phase
    X = X_list[i]
    U = U_list[i]
    J_phase = 0
    alt_h0_hf_weight = 1e3
    speed_penalty_weight = 1e3
    alt_penalty_weight = 1e3
    distance_penalty_weight = 1e4
    control_smoothing_weight = [1e-5, 1e-3, 1e-3] # [T, gamma_ref, beta]
            
    for k in range(N_phase):
        T_k = U[0, k]
        # Example: simple cost (you can replace fuel_flow model as needed)
        # fuel_flow_k = 0.0001 * T_k  # [kg/s]
        # J_phase += (fuel_flow_k + CI) * dt
        J_phase += (CI) * dt
        speed_penalty = speed_penalty_weight * V_slacks[i][k]**2
        alt_penalty = alt_penalty_weight * H_slacks[i][k]**2
        J_phase += speed_penalty + alt_penalty

    alt_h0_hf_penalty = alt_h0_hf_weight * (h_slack_init**2 + h_slack_final**2)
    J_phase += alt_h0_hf_penalty
    J_phase += distance_penalty_weight * S_slack**2

    # --------------------------------
    # CONTROL-RATE PENALTY
    # --------------------------------
    # We add a loop from k=1..N_phase-1 to penalize changes in U
    for k in range(1, N_phase):
        # Sums of squares of changes in [T, gamma_ref, beta]
        J_phase += ca.sumsqr(control_smoothing_weight * (U[:, k] - U[:, k-1]))
    # --------------------------------
    total_cost += J_phase
    
opti.minimize(total_cost)

# %% [markdown]
# # Initial Guesses

# %%
# -------------------------
# 9. Provide initial guesses for states and controls
# -------------------------
for i, phase in enumerate(phases):
    N_phase = phase["N"]
    X = X_list[i]
    for k in range(N_phase+1):
        # Linear interpolation for altitude between phase boundaries
        h_guess = phase["h0"] + (phase["hF"] - phase["h0"]) * k / N_phase
        opti.set_initial(X[2, k], h_guess)
        
        # For speed, if v_target is enforced, it is already fixed.
        if phase["v_target"] is not None:
            if phase["name"] == "takeoff":
                v_guess = 0 + (v_250 - 0) * k / N_phase
                opti.set_initial(X[0, k], v_guess) # set initial guess, not initial condition
            elif phase["name"] == "climb1":
                opti.set_initial(X[0, k], v_250)
            elif phase["name"] == "climb2":
                last_phase_speed = v_250  # Speed from climb1
                target_speed = v_300
                if k <= N_phase/2:
                    # Linear interpolation for first half
                    v_guess = last_phase_speed + (target_speed - last_phase_speed) * (k/(N_phase/2))
                else:
                    # Constant speed for second half
                    v_guess = target_speed
                opti.set_initial(X[0, k], v_guess)
            elif phase["name"] == "cruise":
                last_phase_speed = v_300  # Speed from climb2
                target_speed = v_mach78
                if k <= N_phase/2:
                    v_guess = last_phase_speed + (target_speed - last_phase_speed) * (k/(N_phase/2))
                else:
                    v_guess = target_speed
                opti.set_initial(X[0, k], v_guess)
            elif phase["name"] == "descent1":
                last_phase_speed = v_mach78  # Speed from cruise
                target_speed = v_300
                if k <= N_phase/2:
                    v_guess = last_phase_speed + (target_speed - last_phase_speed) * (k/(N_phase/2))
                else:
                    v_guess = target_speed
                opti.set_initial(X[0, k], v_guess)
            elif phase["name"] == "descent2":
                last_phase_speed = v_300  # Speed from descent1
                target_speed = v_250
                if k <= N_phase/2:
                    v_guess = last_phase_speed + (target_speed - last_phase_speed) * (k/(N_phase/2))
                else:
                    v_guess = target_speed
                opti.set_initial(X[0, k], v_guess)
            elif phase["name"] == "landing":
                last_phase_speed = v_250  # Speed from descent2
                target_speed = v_180
                if k <= N_phase/2:
                    v_guess = last_phase_speed + (target_speed - last_phase_speed) * (k/(N_phase/2))
                else:
                    v_guess = target_speed
                opti.set_initial(X[0, k], v_guess)
        else:
            opti.set_initial(X[0, k], v_250) # other phases without v_target prescribed
        # Provide guesses for other states.
        opti.set_initial(X[1, k], 0.0)  # gamma
        opti.set_initial(X[4, k], 70000.0 - 1000*i)  # mass

# Along-path distance initial guesses
for i, phase in enumerate(phases):
    N_phase = phase["N"]
    X = X_list[i]
    for k in range(N_phase+1):
        if phase["name"] == "climb1":
            opti.set_initial(X[3, k], 0.0 + 0.05 * S_MAX * (k/float(N_phase)))  # along-path distance
        elif phase["name"] == "climb2":
            opti.set_initial(X[3, k], 0.05 * S_MAX + 0.05 * S_MAX *(k/float(N_phase)))  # along-path distance
        elif phase["name"] == "cruise":
            opti.set_initial(X[3, k], 0.1 * S_MAX + 0.8 * S_MAX *(k/float(N_phase)))  # along-path distance
        elif phase["name"] == "descent1":
            opti.set_initial(X[3, k], 0.9 * S_MAX + 0.04 * S_MAX *(k/float(N_phase)))  # along-path distance
        elif phase["name"] == "descent2":
            opti.set_initial(X[3, k], 0.94 * S_MAX + 0.03 * S_MAX *(k/float(N_phase)))  # along-path distance
        elif phase["name"] == "landing":
            opti.set_initial(X[3, k], 0.97 * S_MAX + 0.03 * S_MAX *(k/float(N_phase)))  # along-path distance
    
    # Initial guesses for controls.
    U = U_list[i]
    for k in range(N_phase):
        opti.set_initial(U[0, k], 50000.0)  # thrust
        opti.set_initial(U[1, k], 0.0)       # gamma_ref
        opti.set_initial(U[2, k], 0.0)       # beta

# %% [markdown]
# # Solve

# %%
# -------------------------
# 10. Solve the NLP
# -------------------------
p_opts = {"expand": True}
s_opts = {"max_iter": 50e3, "print_level": 5, "tol":1e-6, "acceptable_tol":1e-4}
opti.solver('ipopt', p_opts, s_opts)

try:
    sol = opti.solve()  # Solve the optimization problem
except RuntimeError as e:
    print("Solver error:", e)
    
    # Inspect values at the point where the error occurred
    print("\n--- Debugging Information ---")
    for i, phase in enumerate(phases):
        # print(f"\nPhase: {phase['name']}")
        X_debug = opti.debug.value(X_list[i])
        U_debug = opti.debug.value(U_list[i])
        T_debug = opti.debug.value(T_list[i])

        # print("  States (X) [v, fpa, h, s, m]:")
        # print(X_debug)
        # print("  Controls (U) [thrust, fpa, spdbrk]:")
        # print(U_debug)
        print(f"Phase {phase['name']}, Duration {T_debug}")

        # if "Infeasible_Problem_Detected" in str(e):
            # print("Solver detected infeasibility. Analyzing...")
            # opti.debug.show_infeasibilities()  # Show summary


        # Plot the states
        from state_plot import plot_states, plot_states_ext
        plot_states(X_debug[0], X_debug[1], X_debug[2], X_debug[3], X_debug[4], U_debug[0], U_debug[1], U_debug[2])

        X_ext = np.empty((6, phase['N']))

        # Compute the additional variables
        for k in range(phase['N']):
            xk = X_debug[:,k]
            uk = U_debug[:,k]
            dyn_func = aircraft_dynamics(xk, uk, opti.debug.value(wind_s), opti.debug.value(phi), phase['name'], fiche_engine, fiche_ac, fiche_control)
            dyn_values = opti.debug.value(dyn_func)

            #Further break down
            g = 9.81
            k_gamma = fiche_control['k_gamma']
            v, gamma, h, s, m = xk[0], xk[1], xk[2], xk[3], xk[4]
            T, gamma_ref, beta = uk[0], uk[1], uk[2]
            rho0 = 1.225
            H = 8500.0
            rho = rho0 * np.exp(-h / H)  # Use numpy for scalar calculations during debugging
            nz = (-v * k_gamma * (gamma - gamma_ref) + g * np.cos(gamma))/(g * np.cos(0))
            L = nz * m * g
            epsilon = 1e-6
            v_sq = v**2 + epsilon
            S_area = fiche_ac['wing']['area']
            Cl = L / (0.5 * rho * v_sq * S_area)
            k_drag = fiche_ac['drag']['k']
            Cd = fiche_ac['drag']['cd0'] + beta + k_drag * Cl**2
            D = 0.5 * rho * v**2 * S_area * Cd

            X_ext[:,k] = np.array([L, D, nz, Cl, Cd, rho])
            if np.isnan(X_ext[:,k]).any():
                print(f"NaN detected at index {k}")
                print(f"X_ext[:,k]: {X_ext[:,k]}")
                print(f"X_ext: {X_ext}")
                print(f"X_ext[0]: {X_ext[0]}")
                print(f"X_ext[1]: {X_ext[1]}")
            
            # Check the constraints manually
        # Manually check constraints
        print("\nChecking constraints for phase:", phase['name'])
        
        # Check altitude constraints
        h_min = phase['h0']
        h_max = phase['hF'] 
        h_violations = np.where((X_debug[2,:-1] < h_min) | (X_debug[2,:-1] > h_max))[0]
        if len(h_violations) > 0:
            print(f"Altitude constraint violations at steps: {h_violations}")
            print(f"Values: {X_debug[2,h_violations]}")
            print(f"Bounds: [{h_min}, {h_max}]")
            
        # Check speed constraints
        v_target = phase['v_target']
        v_tolerance = 10.0  # m/s tolerance
        v_violations = np.where(abs(X_debug[0,:-1] - v_target) > v_tolerance)[0]
        if len(v_violations) > 0:
            print(f"Speed constraint violations at steps: {v_violations}")
            print(f"Values: {X_debug[0,v_violations]}")
            print(f"Target: {v_target} ± {v_tolerance}")
            
        # Check load factor constraints
        nz_max = 1.3  # maximum load factor
        nz_violations = np.where(abs(X_ext[2,:]) > nz_max)[0]
        if len(nz_violations) > 0:
            print(f"Load factor constraint violations at steps: {nz_violations}")
            print(f"Values: {X_ext[2,nz_violations]}")
            print(f"Bound: ±{nz_max}")
            
        # Check thrust constraints
        T_max = fiche_engine['max_thrust'] * 2  # 2 engines
        T_violations = np.where((U_debug[0,:] < 0) | (U_debug[0,:] > T_max))[0]
        if len(T_violations) > 0:
            print(f"Thrust constraint violations at steps: {T_violations}")
            print(f"Values: {U_debug[0,T_violations]}")
            print(f"Bounds: [0, {T_max}]")
            
        # Check speedbrake constraints
        beta_max = 0.1
        beta_violations = np.where((U_debug[2,:] < 0) | (U_debug[2,:] > beta_max))[0]
        if len(beta_violations) > 0:
            print(f"Speedbrake constraint violations at steps: {beta_violations}")
            print(f"Values: {U_debug[2,beta_violations]}")
            print(f"Bounds: [0, {beta_max}]")
            
        # Check the slack variables
        # Check slack variables for NaNs
        if len(V_slacks) > 0 and len(H_slacks) > 0:
            v_slack_vals = opti.debug.value(V_slacks[-1])
            h_slack_vals = opti.debug.value(H_slacks[-1])
            
            print(f"v_slack_vals: {v_slack_vals}")
            print(f"h_slack_vals: {h_slack_vals}")
            
            if np.any(np.isnan(v_slack_vals)):
                print(f"NaN detected in velocity slack variables!")
                print(f"Indices of NaNs: {np.where(np.isnan(v_slack_vals))[0]}")
            
            if np.any(np.isnan(h_slack_vals)):
                print(f"NaN detected in altitude slack variables!")
                print(f"Indices of NaNs: {np.where(np.isnan(h_slack_vals))[0]}")
                
        plot_states_ext(X_ext[0], X_ext[1], X_ext[2], X_ext[3], X_ext[4], X_ext[5])
        
    # Let's deal with NaNs
    # Get the current values of all decision variables:
    x_val = opti.debug.value(opti.x)
    if np.any(np.isnan(x_val)):
        print("NaN detected in decision variable values!")
        print("Indices of NaNs:", np.where(np.isnan(x_val)))
    else:
        print("No NaNs in decision variables.")
    
    # Evaluate the constraint function values:
    g_val = opti.debug.value(opti.g)
    if np.any(np.isnan(g_val)):
        print("NaN detected in constraint values!")
        print("Indices of NaNs:", np.where(np.isnan(g_val)))
    else:
        print("No NaNs in constraint values.")
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:    12297
# Number of nonzeros in inequality constraint Jacobian.:     7545
# Number of nonzeros in Lagrangian Hessian.............:    13185
#
# Total number of variables............................:     4061
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2850
# Total number of inequality constraints...............:     7509
#         inequality constraints with only lower bounds:     3953
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:     3556
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  9.1147260e+05 8.15e+03 1.08e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  9.0519847e+05 8.01e+03 1.07e+00  -1.0 2.54e+04    -  9.58e-03 1.75e-02f  1
#    2  9.0513200e+05 8.01e+03 4.46e+02  -1.0 2.45e+04    -  5.11e-02 1.89e-04f  1
#    3  9.0500772e+05 8.00e+03 7.57e+02  -1.0 3.49e+04    -  5.98e-04 3.58e-04f  1
#    4  8.9865646e+05 7.85e+03 2.07e+04  -1.0 3.45e+04    -  2.14e-03 1.90e-02f  1
#    5  8.9859663e+05 7.85e+03 4.58e+04  -1.0 3.70e+04    -  4.88e-02 1.91e-04f  1
#    6  8.9856385e+05 7.85e+03 4.61e+04  -1.0 2.91e+05    -  3.43e-04 1.04e-04f  1
#    7  8.9814835e+05 7.84e+03 4.50e+04  -1.0 2.91e+05    -  4.81e-04 1.34e-03f  1
#    8  8.9591166e+05 7.78e+03 4.21e+05  -1.0 2.90e+05    -  3.75e-02 7.92e-03f  1
#    9  8.9586834e+05 7.78e+03 5.42e+05  -1.0 2.71e+05    -  8.56e-03 1.69e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  8.9537408e+05 7.76e+03 7.31e+05  -1.0 2.66e+05    -  1.50e-02 1.98e-03f  1
#   11  8.9484455e+05 7.74e+03 7.72e+05  -1.0 2.55e+05    -  5.19e-03 2.29e-03f  1
#   12  8.9460721e+05 7.73e+03 7.78e+05  -1.0 2.49e+05    -  1.64e-03 1.12e-03f  1
#   13  8.9328999e+05 7.68e+03 1.18e+06  -1.0 2.47e+05    -  3.52e-02 7.25e-03f  1
#   14  8.9225350e+05 7.61e+03 1.19e+06  -1.0 2.19e+05    -  9.86e-03 8.53e-03f  1
#   15  8.9223351e+05 7.61e+03 1.21e+06  -1.0 2.05e+05    -  1.57e-03 2.41e-04f  1
#   16  8.9212347e+05 7.60e+03 1.21e+06  -1.0 2.04e+05    -  1.48e-03 1.49e-03f  1
#   17  8.9186424e+05 7.53e+03 2.64e+06  -1.0 2.02e+05    -  1.03e-01 8.53e-03f  1
#   18  8.9187455e+05 7.53e+03 2.81e+06  -1.0 1.44e+05    -  1.12e-02 4.02e-04h  1
#   19  8.9236325e+05 7.48e+03 3.26e+06  -1.0 1.40e+05    -  3.75e-02 7.34e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  8.9249358e+05 7.47e+03 3.25e+06  -1.0 1.23e+05    -  9.80e-04 1.14e-03h  1
#   21  8.9285983e+05 7.45e+03 3.72e+06  -1.0 1.22e+05    -  3.36e-02 2.71e-03h  1
#   22  8.9617202e+05 7.34e+03 3.53e+06  -1.0 1.11e+05    -  5.53e-03 1.42e-02h  1
#   23  8.9747924e+05 7.31e+03 3.90e+06  -1.0 1.09e+05    -  2.88e-02 3.94e-03h  1
#   24  8.9783068e+05 7.31e+03 4.26e+06  -1.0 1.11e+05    -  2.44e-02 9.71e-04h  1
#   25  9.0127698e+05 7.25e+03 4.79e+06  -1.0 1.20e+05    -  4.50e-02 8.24e-03h  1
#   26  9.0208772e+05 7.23e+03 5.29e+06  -1.0 1.73e+05    -  3.06e-02 1.75e-03h  1
#   27  9.0621028e+05 7.18e+03 5.59e+06  -1.0 1.81e+05    -  2.78e-02 7.92e-03h  1
#   28  9.0886989e+05 7.14e+03 5.54e+06  -1.0 1.80e+05    -  3.20e-03 4.60e-03h  1
#   29  9.1040748e+05 7.12e+03 5.55e+06  -1.0 2.01e+05    -  3.85e-03 2.57e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  9.1351654e+05 7.09e+03 7.41e+06  -1.0 2.04e+05    -  9.59e-02 4.90e-03h  1
#   31  9.2296288e+05 7.00e+03 7.26e+06  -1.0 2.27e+05    -  9.96e-03 1.27e-02h  1
#   32  9.2682228e+05 6.97e+03 7.16e+06  -1.0 2.37e+05    -  1.23e-03 4.67e-03h  1
#   33  9.2759208e+05 6.96e+03 7.14e+06  -1.0 2.35e+05    -  2.36e-04 8.91e-04h  1
#   34  9.2947239e+05 6.95e+03 7.36e+06  -1.0 2.35e+05    -  1.33e-02 2.13e-03h  1
#   35  9.3171052e+05 6.93e+03 7.33e+06  -1.0 2.35e+05    -  2.10e-03 2.43e-03h  1
#   36  9.3439230e+05 6.91e+03 7.39e+06  -1.0 2.33e+05    -  6.72e-03 2.80e-03h  1
#   37  9.3845002e+05 6.88e+03 7.45e+06  -1.0 2.36e+05    -  8.14e-03 4.08e-03h  1
#   38  9.4094556e+05 6.86e+03 7.45e+06  -1.0 2.40e+05    -  3.18e-03 2.43e-03h  1
#   39  9.4453055e+05 6.84e+03 7.46e+06  -1.0 2.41e+05    -  5.18e-03 3.39e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  9.6022366e+05 6.75e+03 8.16e+06  -1.0 2.44e+05    -  5.05e-02 1.36e-02h  1
#   41  9.6298244e+05 6.73e+03 8.57e+06  -1.0 2.62e+05    -  2.14e-02 2.22e-03h  1
#   42  9.8775851e+05 6.61e+03 1.01e+07  -1.0 2.69e+05    -  9.44e-02 1.81e-02h  1
#   43  9.9201937e+05 6.59e+03 1.11e+07  -1.0 2.99e+05    -  4.85e-02 2.84e-03h  1
#   44  9.9710252e+05 6.57e+03 1.12e+07  -1.0 3.09e+05    -  6.96e-03 3.25e-03h  1
#   45  1.0103658e+06 6.52e+03 1.15e+07  -1.0 3.11e+05    -  2.68e-02 8.15e-03h  1
#   46  1.0148237e+06 6.50e+03 1.15e+07  -1.0 3.16e+05    -  2.16e-03 2.63e-03h  1
#   47  1.0305782e+06 6.44e+03 1.14e+07  -1.0 3.17e+05    -  1.04e-02 8.99e-03h  1
#   48  1.0530196e+06 6.36e+03 1.17e+07  -1.0 3.19e+05    -  2.88e-02 1.21e-02h  1
#   49  1.0572993e+06 6.35e+03 1.34e+07  -1.0 3.25e+05    -  6.95e-02 2.26e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  1.1048395e+06 6.20e+03 1.43e+07  -1.0 3.13e+05    -  7.41e-02 2.30e-02h  1
#   51  1.1110763e+06 6.19e+03 1.43e+07  -1.0 2.49e+05    -  2.60e-03 2.83e-03h  1
#   52  1.1343805e+06 6.12e+03 1.44e+07  -1.0 2.43e+05    -  1.68e-02 1.03e-02h  1
#   53  1.1712681e+06 6.03e+03 1.56e+07  -1.0 2.17e+05    -  5.11e-02 1.53e-02h  1
#   54  1.2023287e+06 5.96e+03 1.71e+07  -1.0 1.68e+05    -  3.88e-02 1.15e-02h  1
#   55  1.2038770e+06 5.96e+03 1.72e+07  -1.0 2.23e+05    -  2.84e-03 5.39e-04h  1
#   56  1.2127956e+06 5.94e+03 1.71e+07  -1.0 2.70e+05    -  1.93e-03 3.06e-03h  1
#   57  1.2580050e+06 5.85e+03 1.95e+07  -1.0 2.71e+05    -  5.60e-02 1.45e-02h  1
#   58  1.2775450e+06 5.82e+03 1.93e+07  -1.0 2.93e+05    -  4.96e-03 5.73e-03h  1
#   59  1.4920084e+06 5.51e+03 1.63e+07  -1.0 2.92e+05    -  2.15e-02 5.23e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  1.4963190e+06 5.51e+03 1.70e+07  -1.0 2.64e+05    -  1.22e-02 9.32e-04h  1
#   61  1.5788347e+06 5.41e+03 1.60e+07  -1.0 2.57e+05    -  5.49e-03 1.70e-02h  1
#   62  1.6188907e+06 5.37e+03 2.78e+07  -1.0 2.32e+05    -  1.77e-01 7.86e-03h  1
#   63  1.6505643e+06 5.34e+03 2.93e+07  -1.0 1.34e+05    -  2.69e-02 5.72e-03h  1
#   64  1.8247776e+06 5.19e+03 2.96e+07  -1.0 1.36e+05    -  4.29e-02 2.86e-02h  1
#   65  1.8443879e+06 5.17e+03 3.69e+07  -1.0 1.38e+05    -  9.13e-02 3.01e-03h  1
#   66  1.8560334e+06 5.16e+03 3.69e+07  -1.0 3.23e+05    -  2.67e-03 1.74e-03h  1
#   67  1.9105092e+06 5.12e+03 3.63e+07  -1.0 3.23e+05    -  3.83e-03 7.93e-03h  1
#   68  2.0351627e+06 5.03e+03 4.58e+07  -1.0 3.21e+05    -  1.39e-01 1.72e-02h  1
#   69  2.0445092e+06 5.03e+03 4.70e+07  -1.0 3.20e+05    -  1.71e-02 1.23e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  2.1825476e+06 4.94e+03 5.24e+07  -1.0 3.15e+05    -  9.64e-02 1.73e-02h  1
#   71  2.7131834e+06 4.66e+03 4.63e+07  -1.0 2.70e+05    -  1.84e-02 5.75e-02h  1
#   72  2.9245892e+06 4.56e+03 5.10e+07  -1.0 1.62e+05    -  8.45e-02 2.13e-02h  1
#   73  3.0611696e+06 4.50e+03 5.44e+07  -1.0 1.56e+05    -  5.32e-02 1.33e-02h  1
#   74  3.0658624e+06 4.50e+03 5.44e+07  -1.0 1.89e+05    -  5.13e-04 4.53e-04h  1
#   75  3.0754824e+06 4.49e+03 5.42e+07  -1.0 2.60e+05    -  3.65e-05 9.28e-04h  1
#   76  3.6361425e+06 4.27e+03 4.71e+07  -1.0 2.59e+05    -  7.76e-03 5.00e-02h  1
#   77  3.7270600e+06 4.23e+03 4.98e+07  -1.0 2.13e+05    -  3.39e-02 8.16e-03h  1
#   78  3.9573488e+06 4.15e+03 5.11e+07  -1.0 2.09e+05    -  3.96e-02 2.01e-02h  1
#   79  3.9602337e+06 4.15e+03 7.27e+07  -1.0 1.86e+05    -  1.70e-01 2.55e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  4.2731735e+06 4.04e+03 7.81e+07  -1.0 2.35e+05    -  9.19e-02 2.55e-02h  1
#   81  4.6844903e+06 3.91e+03 7.49e+07  -1.0 2.43e+05    -  2.72e-02 3.27e-02h  1
#   82  4.7065816e+06 3.90e+03 1.07e+08  -1.0 2.30e+05    -  2.43e-01 1.87e-03h  1
#   83  5.1741921e+06 3.77e+03 1.01e+08  -1.0 2.88e+05    -  1.19e-02 3.42e-02h  1
#   84  5.1976328e+06 3.76e+03 1.02e+08  -1.0 2.83e+05    -  1.03e-02 1.81e-03h  1
#   85  5.3870019e+06 3.71e+03 1.06e+08  -1.0 2.83e+05    -  5.86e-02 1.44e-02h  1
#   86  5.3931489e+06 3.70e+03 1.29e+08  -1.0 2.78e+05    -  1.90e-01 4.66e-04h  1
#   87  7.0693187e+06 3.32e+03 1.06e+08  -1.0 3.00e+05    -  8.43e-03 1.05e-01h  1
#   88  7.2037084e+06 3.28e+03 1.04e+08  -1.0 2.57e+05    -  6.95e-05 1.04e-02h  1
#   89  7.3080310e+06 3.25e+03 1.20e+08  -1.0 2.54e+05    -  1.18e-01 8.35e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  7.7865693e+06 3.15e+03 1.13e+08  -1.0 2.72e+05    -  4.70e-03 3.23e-02h  1
#   91  7.9399423e+06 3.11e+03 1.11e+08  -1.0 2.66e+05    -  6.38e-03 1.10e-02h  1
#   92  8.0066826e+06 3.10e+03 1.12e+08  -1.0 2.63e+05    -  1.59e-02 4.84e-03h  1
#   93  8.0695579e+06 3.08e+03 1.13e+08  -1.0 2.63e+05    -  1.50e-02 4.50e-03h  1
#   94  8.1858280e+06 3.06e+03 1.20e+08  -1.0 2.63e+05    -  6.70e-02 8.19e-03h  1
#   95  8.4483358e+06 3.01e+03 1.17e+08  -1.0 2.64e+05    -  7.91e-03 1.74e-02h  1
#   96  8.5866679e+06 2.98e+03 1.21e+08  -1.0 2.59e+05    -  4.65e-02 9.26e-03h  1
#   97  8.8599005e+06 2.93e+03 1.22e+08  -1.0 2.58e+05    -  4.21e-02 1.77e-02h  1
#   98  9.1540860e+06 2.87e+03 1.19e+08  -1.0 2.55e+05    -  1.53e-02 1.87e-02h  1
#   99  9.5029106e+06 2.81e+03 1.17e+08  -1.0 2.52e+05    -  2.44e-02 2.22e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  9.7603660e+06 2.76e+03 1.13e+08  -1.0 2.51e+05    -  9.76e-04 1.65e-02h  1
#  101  9.7722183e+06 2.76e+03 1.19e+08  -1.0 2.44e+05    -  4.93e-02 7.75e-04h  1
#  102  1.0495037e+07 2.64e+03 1.09e+08  -1.0 2.45e+05    -  6.73e-03 4.49e-02h  1
#  103  1.0575729e+07 2.62e+03 1.15e+08  -1.0 2.35e+05    -  5.08e-02 5.28e-03h  1
#  104  1.1345433e+07 2.49e+03 1.03e+08  -1.0 2.36e+05    -  5.50e-03 4.83e-02h  1
#  105  1.1435413e+07 2.48e+03 1.03e+08  -1.0 2.32e+05    -  5.13e-03 5.95e-03h  1
#  106  1.1464018e+07 2.48e+03 1.07e+08  -1.0 2.27e+05    -  2.88e-02 1.90e-03h  1
#  107  1.1779690e+07 2.42e+03 1.02e+08  -1.0 2.28e+05    -  1.20e-03 2.03e-02h  1
#  108  1.1795780e+07 2.42e+03 1.07e+08  -1.0 2.21e+05    -  3.04e-02 1.05e-03h  1
#  109  1.2045327e+07 2.38e+03 1.14e+08  -1.0 2.22e+05    -  6.65e-02 1.59e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  1.2211920e+07 2.36e+03 1.11e+08  -1.0 2.22e+05    -  1.49e-03 1.03e-02h  1
#  111  1.2333255e+07 2.34e+03 1.13e+08  -1.0 2.24e+05    -  2.13e-02 7.51e-03h  1
#  112  1.2372888e+07 2.34e+03 1.12e+08  -1.0 2.19e+05    -  1.37e-03 2.43e-03h  1
#  113  1.2546289e+07 2.31e+03 1.15e+08  -1.0 2.22e+05    -  3.67e-02 1.06e-02h  1
#  114  1.2619199e+07 2.30e+03 1.14e+08  -1.0 2.15e+05    -  2.08e-03 4.40e-03h  1
#  115  1.2797346e+07 2.28e+03 1.12e+08  -1.0 2.20e+05    -  5.61e-03 1.07e-02h  1
#  116  1.2843343e+07 2.27e+03 1.26e+08  -1.0 2.11e+05    -  8.48e-02 2.77e-03h  1
#  117  1.6840447e+07 1.79e+03 8.69e+07  -1.0 2.11e+05    -  1.30e-01 2.10e-01h  1
#  118  1.7156308e+07 1.76e+03 8.42e+07  -1.0 1.67e+05    -  1.05e-02 1.77e-02h  1
#  119  1.7770612e+07 1.70e+03 8.45e+07  -1.0 1.65e+05    -  5.27e-02 3.41e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  1.7948129e+07 1.68e+03 8.91e+07  -1.0 1.56e+05    -  4.29e-02 9.77e-03h  1
#  121  1.9291125e+07 1.56e+03 7.43e+07  -1.0 1.54e+05    -  1.79e-02 7.14e-02h  1
#  122  1.9333867e+07 1.56e+03 7.40e+07  -1.0 4.36e+04  -4.0 1.94e-03 2.29e-03h  1
#  123  1.9349301e+07 1.56e+03 7.48e+07  -1.0 1.53e+05    -  4.71e-03 8.90e-04h  1
#  124  1.9506830e+07 1.54e+03 8.00e+07  -1.0 1.43e+05    -  3.44e-02 9.04e-03h  1
#  125  1.9914533e+07 1.51e+03 7.55e+07  -1.0 1.41e+05    -  1.11e-02 2.30e-02h  1
#  126  2.0935959e+07 1.42e+03 6.18e+07  -1.0 1.37e+05    -  1.49e-02 5.65e-02h  1
#  127  2.1396160e+07 1.39e+03 5.57e+07  -1.0 1.25e+05    -  5.94e-03 2.56e-02h  1
#  128  2.1494292e+07 1.38e+03 5.80e+07  -1.0 1.23e+05    -  1.65e-02 5.48e-03h  1
#  129  2.2059836e+07 1.34e+03 5.00e+07  -1.0 1.22e+05    -  4.01e-03 3.11e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  2.2581898e+07 1.30e+03 4.47e+07  -1.0 1.17e+05    -  1.14e-02 2.87e-02h  1
#  131  2.3643447e+07 1.22e+03 3.65e+07  -1.0 1.12e+05    -  3.30e-02 5.76e-02h  1
#  132  2.4649001e+07 1.16e+03 3.13e+07  -1.0 1.03e+05    -  3.97e-02 5.44e-02h  1
#  133  2.4888652e+07 1.14e+03 2.89e+07  -1.0 9.43e+04    -  3.59e-03 1.31e-02h  1
#  134  2.4918733e+07 1.14e+03 3.37e+07  -1.0 9.25e+04    -  2.47e-02 1.65e-03h  1
#  135  2.5908698e+07 1.08e+03 2.57e+07  -1.0 9.15e+04    -  2.32e-02 5.33e-02h  1
#  136  2.6302481e+07 1.06e+03 3.10e+07  -1.0 8.41e+04    -  5.09e-02 2.16e-02h  1
#  137  2.6562217e+07 1.04e+03 3.43e+07  -1.0 8.08e+04    -  3.37e-02 1.42e-02h  1
#  138  2.7256289e+07 1.00e+03 3.52e+07  -1.0 7.97e+04    -  5.00e-02 3.77e-02h  1
#  139  2.7560900e+07 9.85e+02 3.18e+07  -1.0 7.70e+04    -  5.28e-04 1.67e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140  2.7787295e+07 9.73e+02 3.09e+07  -1.0 6.71e+04  -4.5 9.24e-03 1.25e-02h  1
#  141  2.7799190e+07 9.72e+02 3.14e+07  -1.0 7.30e+04    -  3.82e-03 6.62e-04h  1
#  142  2.7922039e+07 9.65e+02 3.18e+07  -1.0 7.24e+04    -  1.05e-02 6.83e-03h  1
#  143  2.8037770e+07 9.59e+02 3.98e+07  -1.0 7.07e+04    -  5.35e-02 6.45e-03h  1
#  144  2.8401776e+07 9.40e+02 4.00e+07  -1.0 6.94e+04    -  2.61e-02 2.03e-02h  1
#  145  2.8711873e+07 9.23e+02 3.81e+07  -1.0 8.46e+04    -  1.27e-02 1.76e-02h  1
#  146  2.8940747e+07 9.11e+02 3.48e+07  -1.0 8.44e+04    -  1.14e-03 1.31e-02h  1
#  147  2.8979937e+07 9.09e+02 4.26e+07  -1.0 8.36e+04    -  3.52e-02 2.25e-03h  1
#  148  3.0167546e+07 8.49e+02 2.88e+07  -1.0 8.42e+04    -  1.92e-02 6.65e-02h  1
#  149  3.1446111e+07 7.87e+02 1.27e+07  -1.0 8.00e+04    -  9.77e-03 7.26e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150  3.1778147e+07 7.72e+02 1.38e+07  -1.0 7.25e+04  -5.0 8.38e-03 1.95e-02h  1
#  151  3.2005734e+07 7.61e+02 1.25e+07  -1.0 7.35e+04  -5.4 2.57e-02 1.35e-02h  1
#  152  3.2091042e+07 7.57e+02 1.37e+07  -1.0 7.35e+04    -  1.11e-02 5.10e-03h  1
#  153  3.2277695e+07 7.49e+02 1.20e+07  -1.0 7.33e+04    -  3.65e-03 1.12e-02h  1
#  154  3.2916287e+07 7.20e+02 1.17e+07  -1.0 7.26e+04    -  3.72e-02 3.81e-02h  1
#  155  3.2922759e+07 7.20e+02 1.49e+07  -1.0 7.03e+04    -  1.86e-02 3.95e-04h  1
#  156  3.2924169e+07 7.20e+02 1.72e+07  -1.0 6.90e+04    -  1.21e-02 8.85e-05h  1
#  157  3.3650530e+07 6.88e+02 1.18e+07  -1.0 6.90e+04    -  8.88e-03 4.50e-02h  1
#  158  3.3686133e+07 6.86e+02 1.24e+07  -1.0 6.61e+04    -  1.79e-02 2.27e-03h  1
#  159  3.4342783e+07 6.58e+02 1.32e+07  -1.0 6.60e+04    -  1.02e-02 4.13e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  3.4375932e+07 6.56e+02 1.15e+07  -1.0 6.35e+04    -  1.66e-02 2.13e-03h  1
#  161  3.4991823e+07 6.31e+02 1.45e+07  -1.0 6.34e+04    -  9.61e-03 3.92e-02h  1
#  162  3.5026129e+07 6.29e+02 1.35e+07  -1.0 6.11e+04    -  1.05e-02 2.23e-03h  1
#  163  3.5673218e+07 6.03e+02 1.55e+07  -1.0 6.10e+04    -  1.88e-02 4.16e-02h  1
#  164  3.5708391e+07 6.02e+02 1.44e+07  -1.0 5.87e+04    -  1.20e-02 2.31e-03h  1
#  165  3.6048214e+07 5.88e+02 1.47e+07  -1.0 5.87e+04    -  1.62e-02 2.22e-02h  1
#  166  3.6158172e+07 5.84e+02 1.41e+07  -1.0 5.75e+04    -  1.25e-02 7.25e-03h  1
#  167  3.6161668e+07 5.84e+02 1.10e+07  -1.0 5.69e+04    -  5.71e-02 2.33e-04h  1
#  168  3.6727705e+07 5.62e+02 9.63e+06  -1.0 5.70e+04    -  3.06e-02 3.72e-02h  1
#  169  3.6885447e+07 5.56e+02 1.34e+07  -1.0 5.45e+04    -  3.72e-02 1.05e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  3.7643954e+07 5.28e+02 8.76e+06  -1.0 5.31e+04    -  2.18e-02 5.01e-02h  1
#  171  3.7691814e+07 5.27e+02 9.04e+06  -1.0 5.09e+04    -  4.90e-03 3.28e-03h  1
#  172  3.7793174e+07 5.23e+02 1.16e+07  -1.0 6.00e+04    -  1.95e-02 6.96e-03h  1
#  173  3.8057078e+07 5.14e+02 1.01e+07  -1.0 5.97e+04    -  1.17e-02 1.81e-02h  1
#  174  3.8532097e+07 4.97e+02 8.29e+06  -1.0 5.88e+04    -  2.52e-02 3.25e-02h  1
#  175  3.8606027e+07 4.94e+02 2.23e+07  -1.0 5.73e+04    -  7.78e-02 5.13e-03h  1
#  176  3.9550998e+07 4.63e+02 1.04e+07  -1.0 5.75e+04    -  5.67e-03 6.40e-02h  1
#  177  3.9603197e+07 4.61e+02 1.33e+07  -1.0 5.41e+04    -  2.01e-02 3.69e-03h  1
#  178  3.9808343e+07 4.54e+02 1.21e+07  -1.0 5.40e+04    -  8.63e-03 1.44e-02h  1
#  179  3.9929522e+07 4.50e+02 1.54e+07  -1.0 5.33e+04    -  2.91e-02 8.59e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  4.0192489e+07 4.42e+02 1.22e+07  -1.0 5.30e+04    -  6.36e-04 1.86e-02h  1
#  181  4.0195953e+07 4.42e+02 1.70e+07  -1.0 5.20e+04    -  2.97e-02 2.49e-04h  1
#  182  4.0301145e+07 4.39e+02 1.80e+07  -1.0 5.21e+04    -  1.43e-02 7.56e-03h  1
#  183  4.0486663e+07 4.33e+02 2.34e+07  -1.0 5.17e+04    -  4.98e-02 1.33e-02h  1
#  184  4.0596389e+07 4.29e+02 3.72e+07  -1.0 5.13e+04    -  1.03e-01 7.91e-03h  1
#  185  4.1318266e+07 4.07e+02 7.82e+07  -1.0 5.12e+04    -  3.75e-01 5.12e-02h  1
#  186  4.2106137e+07 3.84e+02 7.09e+07  -1.0 4.94e+04    -  2.06e-02 5.64e-02h  1
#  187  4.2811576e+07 3.64e+02 7.50e+07  -1.0 4.66e+04    -  1.53e-01 5.20e-02h  1
#  188  4.3843812e+07 3.36e+02 7.31e+07  -1.0 4.43e+04    -  1.40e-01 7.76e-02h  1
#  189  4.4446801e+07 3.20e+02 6.92e+07  -1.0 4.08e+04    -  4.03e-02 4.79e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190  4.4762497e+07 3.12e+02 9.85e+07  -1.0 3.89e+04    -  6.54e-01 2.60e-02h  1
#  191  4.4768138e+07 3.12e+02 9.98e+07  -1.0 3.91e+04    -  8.50e-02 4.73e-04h  1
#  192  4.4967695e+07 3.06e+02 1.06e+08  -1.0 4.11e+04    -  5.27e-01 1.67e-02h  1
#  193  4.8116821e+07 2.29e+02 7.79e+07  -1.0 3.82e+04    -  8.93e-02 2.53e-01h  1
#  194  4.8640577e+07 2.17e+02 7.38e+07  -1.0 3.16e+04    -  7.78e-02 5.35e-02h  1
#  195  4.9317930e+07 2.01e+02 6.85e+07  -1.0 2.39e+04  -5.9 7.20e-02 7.18e-02h  1
#  196  4.9443013e+07 1.98e+02 6.83e+07  -1.0 1.01e+04  -6.4 3.61e-02 1.42e-02h  1
#  197  4.9489627e+07 1.97e+02 6.93e+07  -1.0 1.67e+04  -6.9 4.39e-02 5.34e-03h  1
#  198  4.9504251e+07 1.97e+02 6.93e+07  -1.0 6.40e+04  -7.3 4.24e-03 1.69e-03h  1
#  199  5.0116758e+07 1.83e+02 7.36e+07  -1.0 1.79e+04  -6.9 3.38e-01 7.00e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200  5.0877346e+07 1.66e+02 6.53e+07  -1.0 3.67e+04    -  1.93e-02 9.13e-02h  1
#  201  5.1892858e+07 1.45e+02 5.50e+07  -1.0 8.01e+04    -  4.14e-02 1.31e-01h  1
#  202  5.2192857e+07 1.38e+02 5.28e+07  -1.0 8.30e+04    -  5.55e-02 4.36e-02h  1
#  203  5.2988043e+07 1.22e+02 4.52e+07  -1.0 9.40e+04    -  4.31e-02 1.19e-01h  1
#  204  5.3078706e+07 1.20e+02 4.53e+07  -1.0 9.39e+04    -  6.33e-02 1.52e-02h  1
#  205  5.3224876e+07 1.17e+02 4.44e+07  -1.0 1.05e+05    -  4.05e-02 2.49e-02h  1
#  206  5.3226864e+07 1.17e+02 4.49e+07  -1.0 1.08e+05    -  4.07e-02 3.47e-04h  1
#  207  5.3371398e+07 1.14e+02 4.39e+07  -1.0 1.17e+05    -  3.04e-02 2.51e-02h  1
#  208  5.3799027e+07 1.05e+02 4.00e+07  -1.0 1.15e+05    -  3.45e-02 7.57e-02h  1
#  209  5.3803808e+07 1.05e+02 4.06e+07  -1.0 1.14e+05    -  5.19e-02 9.11e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210  5.3838663e+07 1.05e+02 4.08e+07  -1.0 1.26e+05    -  3.24e-02 6.65e-03h  1
#  211  5.4342475e+07 9.45e+01 3.58e+07  -1.0 1.31e+05    -  2.89e-02 9.60e-02h  1
#  212  5.4749468e+07 8.65e+01 3.22e+07  -1.0 1.25e+05    -  5.19e-02 8.47e-02h  1
#  213  5.4771535e+07 8.61e+01 3.27e+07  -1.0 1.39e+05    -  4.98e-02 4.99e-03h  1
#  214  5.4775051e+07 8.60e+01 3.32e+07  -1.0 1.48e+05    -  3.46e-02 7.99e-04h  1
#  215  5.5230145e+07 7.72e+01 2.87e+07  -1.0 1.53e+05    -  2.87e-02 1.03e-01h  1
#  216  5.5507761e+07 7.19e+01 2.65e+07  -1.0 1.44e+05    -  5.18e-02 6.91e-02h  1
#  217  5.5687362e+07 6.84e+01 2.52e+07  -1.0 1.54e+05    -  4.92e-02 4.77e-02h  1
#  218  5.5908159e+07 6.43e+01 2.35e+07  -1.0 1.60e+05    -  4.58e-02 6.12e-02h  1
#  219  5.6087251e+07 6.09e+01 2.22e+07  -1.0 1.59e+05    -  4.91e-02 5.26e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220  5.6297064e+07 5.69e+01 2.06e+07  -1.0 1.59e+05    -  4.94e-02 6.46e-02h  1
#  221  5.6476098e+07 5.36e+01 1.93e+07  -1.0 1.64e+05    -  5.08e-02 5.86e-02h  1
#  222  5.6492845e+07 5.33e+01 1.97e+07  -1.0 1.72e+05    -  4.93e-02 5.81e-03h  1
#  223  5.6493062e+07 5.33e+01 2.20e+07  -1.0 1.80e+05    -  3.59e-02 7.59e-05h  1
#  224  5.6524471e+07 5.27e+01 2.68e+07  -1.0 1.85e+05    -  3.15e-02 1.10e-02h  1
#  225  5.6862056e+07 4.65e+01 1.46e+07  -1.0 1.82e+05    -  2.94e-02 1.17e-01h  1
#  226  5.6879330e+07 4.62e+01 1.50e+07  -1.0 1.81e+05    -  4.94e-02 6.67e-03h  1
#  227  5.7045786e+07 4.32e+01 1.37e+07  -1.0 2.01e+05    -  3.32e-02 6.40e-02h  1
#  228  5.7181694e+07 4.09e+01 1.28e+07  -1.0 1.98e+05    -  4.37e-02 5.49e-02h  1
#  229  5.7287701e+07 3.90e+01 1.22e+07  -1.0 2.09e+05    -  4.28e-02 4.48e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230  5.7378639e+07 3.75e+01 1.18e+07  -1.0 2.17e+05    -  4.19e-02 3.98e-02h  1
#  231  5.7503671e+07 3.54e+01 1.10e+07  -1.0 2.24e+05    -  4.04e-02 5.64e-02h  1
#  232  5.7597138e+07 3.38e+01 1.04e+07  -1.0 2.31e+05    -  4.06e-02 4.42e-02h  1
#  233  5.7688873e+07 3.23e+01 9.93e+06  -1.0 2.30e+05    -  3.93e-02 4.50e-02h  1
#  234  5.7778462e+07 3.08e+01 9.44e+06  -1.0 2.37e+05    -  4.12e-02 4.56e-02h  1
#  235  5.7864299e+07 2.94e+01 8.95e+06  -1.0 2.52e+05    -  3.74e-02 4.54e-02h  1
#  236  5.7942330e+07 2.82e+01 8.55e+06  -1.0 2.34e+05    -  4.10e-02 4.29e-02h  1
#  237  5.8017905e+07 2.69e+01 8.28e+06  -1.0 2.64e+05    -  3.61e-02 4.31e-02h  1
#  238  5.8090441e+07 2.58e+01 8.19e+06  -1.0 2.44e+05    -  3.93e-02 4.30e-02h  1
#  239  5.8156372e+07 2.47e+01 8.10e+06  -1.0 2.69e+05    -  3.72e-02 4.06e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240  5.8224774e+07 2.37e+01 8.30e+06  -1.0 2.71e+05    -  3.55e-02 4.36e-02h  1
#  241  5.8281946e+07 2.28e+01 8.08e+06  -1.0 2.55e+05    -  3.66e-02 3.79e-02h  1
#  242  5.8339970e+07 2.19e+01 7.95e+06  -1.0 2.49e+05    -  3.68e-02 3.98e-02h  1
#  243  5.8396525e+07 2.10e+01 7.69e+06  -1.0 2.68e+05    -  3.92e-02 4.02e-02h  1
#  244  5.8455631e+07 2.01e+01 7.64e+06  -1.0 2.93e+05    -  3.87e-02 4.36e-02h  1
#  245  5.8505455e+07 1.93e+01 7.40e+06  -1.0 3.07e+05    -  3.73e-02 3.82e-02h  1
#  246  5.8554752e+07 1.85e+01 7.18e+06  -1.0 3.10e+05    -  3.78e-02 3.92e-02h  1
#  247  5.8601492e+07 1.78e+01 6.87e+06  -1.0 3.16e+05    -  3.93e-02 3.85e-02h  1
#  248  5.8647462e+07 1.71e+01 6.49e+06  -1.0 3.23e+05    -  4.15e-02 3.93e-02h  1
#  249  5.8692247e+07 1.64e+01 6.00e+06  -1.0 3.31e+05    -  4.44e-02 3.97e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250  5.8736439e+07 1.58e+01 5.41e+06  -1.0 3.37e+05    -  4.81e-02 4.06e-02h  1
#  251  5.8779858e+07 1.51e+01 4.70e+06  -1.0 3.42e+05    -  5.24e-02 4.15e-02h  1
#  252  5.8822685e+07 1.45e+01 4.41e+06  -1.0 3.46e+05    -  5.74e-02 4.25e-02h  1
#  253  5.8864822e+07 1.39e+01 4.28e+06  -1.0 3.48e+05    -  6.33e-02 4.35e-02h  1
#  254  5.8906368e+07 1.32e+01 4.17e+06  -1.0 3.48e+05    -  7.02e-02 4.47e-02h  1
#  255  5.8947315e+07 1.26e+01 4.06e+06  -1.0 3.46e+05    -  7.84e-02 4.60e-02h  1
#  256  5.8987757e+07 1.20e+01 6.05e+06  -1.0 3.41e+05    -  8.58e-02 4.75e-02h  1
#  257  5.9027242e+07 1.14e+01 7.47e+06  -1.0 3.35e+05    -  7.80e-02 4.85e-02h  1
#  258  5.9058086e+07 1.10e+01 1.52e+07  -1.0 2.50e+05    -  1.91e-01 3.97e-02h  1
#  259  5.9142091e+07 9.75e+00 8.85e+06  -1.0 2.45e+05    -  4.10e-03 1.12e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260  5.9157401e+07 9.53e+00 4.70e+07  -1.0 1.20e+04    -  9.12e-01 2.30e-02h  1
#  261  5.9749151e+07 1.07e+00 4.75e+06  -1.0 7.51e+03    -  7.49e-01 8.88e-01h  1
#  262  5.9753835e+07 1.00e+00 5.40e+06  -1.0 1.05e+04    -  1.00e+00 6.24e-02h  1
#  263  5.9754725e+07 9.70e-01 5.37e+06  -1.0 9.80e-01   4.9 4.45e-03 3.44e-02h  1
#  264  5.9758219e+07 8.33e-01 5.05e+06  -1.0 9.84e-01   4.5 5.97e-02 1.40e-01h  1
#  265  5.9758374e+07 8.31e-01 7.90e+06  -1.0 1.57e+00   4.0 5.38e-03 2.26e-03h  1
#  266  5.9759267e+07 8.21e-01 2.20e+07  -1.0 1.66e+00   3.5 3.70e-02 1.31e-02h  1
#  267  5.9762041e+07 7.11e-01 2.03e+07  -1.0 9.24e-01   3.9 7.54e-02 1.33e-01h  1
#  268  5.9763833e+07 6.38e-01 1.54e+07  -1.0 8.70e-01   3.4 2.44e-01 1.03e-01h  1
#  269  5.9770510e+07 5.70e-01 3.12e+06  -1.0 1.53e+00   3.0 4.85e-03 1.07e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270  5.9773270e+07 4.65e-01 6.10e+05  -1.0 6.15e-01   4.3 8.03e-01 1.84e-01h  1
#  271  5.9783967e+07 6.96e-02 5.35e+05  -1.0 5.69e-01   3.8 1.34e-01 8.50e-01h  1
#  272  5.9786361e+07 6.58e-02 8.10e+06  -1.0 6.72e-01   3.3 3.29e-02 5.50e-02h  1
#  273  5.9788429e+07 6.24e-02 1.24e+07  -1.0 7.10e-01   2.9 2.73e-01 5.09e-02h  1
#  274  5.9791886e+07 5.66e-02 1.14e+07  -1.0 1.27e+00   2.4 7.75e-02 9.26e-02h  1
#  275  5.9791888e+07 5.66e-02 7.68e+06  -1.0 1.33e-01   3.7 3.28e-01 5.25e-04h  1
#  276  5.9792694e+07 3.64e-02 6.25e+06  -1.0 9.66e-02   4.1 1.86e-01 3.58e-01h  1
#  277  5.9795129e+07 1.15e-02 2.57e+05  -1.0 1.33e-01   3.7 9.59e-01 6.85e-01h  1
#  278  5.9794831e+07 1.15e-02 3.59e+07  -1.0 4.15e+03    -  4.51e-01 4.41e-04f  1
#  279  5.9795012e+07 9.77e-03 2.66e+07  -1.0 4.10e-02   4.1 2.59e-01 1.47e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280  5.9797021e+07 3.25e-03 3.88e+04  -1.0 9.43e-02   3.6 1.00e+00 6.67e-01h  1
#  281  5.9796690e+07 3.24e-03 4.60e+07  -1.0 4.35e+03    -  8.83e-01 4.89e-03f  1
#  282  5.9797599e+07 6.69e-04 1.45e+07  -1.0 3.37e-02   4.0 6.86e-01 7.93e-01h  1
#  283  5.9797791e+07 6.26e-04 1.26e+06  -1.0 7.42e-01   3.6 1.00e+00 6.44e-02h  1
#  284  5.9797796e+07 6.24e-04 2.44e+07  -1.0 4.16e+03    -  4.73e-01 2.68e-03h  1
#  285  5.9797908e+07 5.78e-04 1.89e+07  -1.0 2.80e-02   4.0 2.25e-01 8.19e-02h  1
#  286  5.9801274e+07 2.56e-04 2.21e+04  -1.0 1.02e-01   3.5 1.00e+00 7.95e-01h  1
#  287  5.9801454e+07 2.50e-04 5.07e+07  -1.0 4.09e+03    -  1.00e+00 2.14e-02h  1
#  288  5.9801552e+07 2.40e-04 8.79e+04  -1.0 3.44e-02   3.9 1.00e+00 6.01e-02h  1
#  289  5.9802224e+07 2.32e-04 4.87e+07  -1.0 4.03e+03    -  1.00e+00 3.44e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290  5.9803328e+07 3.28e-04 1.70e+05  -1.0 1.23e-01   3.5 1.00e+00 2.23e-01h  1
#  291  5.9805807e+07 2.87e-04 4.25e+07  -1.0 4.05e+03    -  1.00e+00 1.25e-01h  1
#  292  5.9822013e+07 1.81e-04 5.59e+06  -1.0 3.74e+03    -  1.00e+00 8.68e-01h  1
#  293  5.9822101e+07 1.02e-04 8.06e+03  -1.0 4.19e-03   3.9 1.00e+00 4.38e-01h  1
#  294  5.9822635e+07 4.69e-05 1.39e+03  -1.7 1.38e-02   3.4 9.02e-01 8.33e-01h  1
#  295  5.9822733e+07 4.72e-05 3.34e+06  -2.5 8.50e+03    -  6.58e-01 5.98e-02h  3
#  296  5.9823970e+07 2.32e-04 1.29e+06  -2.5 8.81e+03    -  1.00e+00 7.54e-01H  1
#  297  5.9824387e+07 2.47e-05 4.67e+00  -2.5 1.63e+02    -  1.00e+00 1.00e+00h  1
#  298  5.9824385e+07 7.95e-07 2.73e+03  -5.7 3.95e+02    -  9.79e-01 1.00e+00f  1
#  299  5.9824385e+07 6.16e-08 5.81e-06  -5.7 8.91e+00    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300  5.9824385e+07 6.34e-05 5.79e-07  -7.0 7.26e-01    -  1.00e+00 1.00e+00f  1
#  301  5.9824385e+07 6.49e-03 3.25e-02  -7.0 2.14e-01    -  9.78e-01 1.00e+00h  1
#  302  5.9824385e+07 1.72e-07 2.38e-07  -7.0 8.95e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 302
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.9824384940249272e+07    5.9824384940249272e+07
# Dual infeasibility......:   2.3841857910156345e-07    2.3841857910156345e-07
# Constraint violation....:   1.7208934366408357e-07    1.7208934366408357e-07
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   4.5128544692255737e-06    4.5128544692255737e-06
# Overall NLP error.......:   1.7208934366408357e-07    4.5128544692255737e-06
#
#
# Number of objective function evaluations             = 308
# Number of objective gradient evaluations             = 303
# Number of equality constraint evaluations            = 308
# Number of inequality constraint evaluations          = 308
# Number of equality constraint Jacobian evaluations   = 303
# Number of inequality constraint Jacobian evaluations = 303
# Number of Lagrangian Hessian evaluations             = 302
# Total seconds in IPOPT                               = 14.903
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  20.00ms ( 64.94us)   7.34ms ( 23.82us)       308
#        nlp_g  |  37.00ms (120.13us)  52.64ms (170.90us)       308
#   nlp_grad_f  |  22.00ms ( 72.37us)  14.65ms ( 48.18us)       304
#   nlp_hess_l  | 183.00ms (605.96us) 228.79ms (757.58us)       302
#    nlp_jac_g  | 103.00ms (338.82us) 113.04ms (371.85us)       304
#        total  |  14.90 s ( 14.90 s)  14.90 s ( 14.90 s)         1

# %%
for i, phase in enumerate(phases):
        # print(f"\nPhase: {phase['name']}")
        X_debug = sol.value(X_list[i])
        U_debug = sol.value(U_list[i])
        T_debug = sol.value(T_list[i])

        # print("  States (X) [v, fpa, h, s, m]:")
        # print(X_debug)
        # print("  Controls (U) [thrust, fpa, spdbrk]:")
        # print(U_debug)
        print(f"  Duration (T): {T_debug}")

        # if "Infeasible_Problem_Detected" in str(e):
            # print("Solver detected infeasibility. Analyzing...")
            # opti.debug.show_infeasibilities()  # Show summary


        # Plot the states
        #from state_plot import plot_states, plot_states_ext
        #plot_states(X_debug[0], X_debug[1], X_debug[2], X_debug[3], X_debug[4], U_debug[0], U_debug[1], U_debug[2])
# Out:
#   Duration (T): 79.4471330495483
#   Duration (T): 199.74648202959122
#   Duration (T): 4924.8042054433645
#   Duration (T): 1404.000014039999
#   Duration (T): 364.000003639922
#   Duration (T): 156.0000015599998

# %%
from state_plot import plot_states_with_phases_clb2ds3
plot_states_with_phases_clb2ds3(sol.value(X_list[0]), sol.value(X_list[1]), sol.value(X_list[2]), sol.value(X_list[3]), sol.value(X_list[4]), sol.value(X_list[5]),
                        sol.value(U_list[0]), sol.value(U_list[1]), sol.value(U_list[2]), sol.value(U_list[3]), sol.value(U_list[4]), sol.value(U_list[5]),
                        [sol.value(T_list[i]) for i in range(len(T_list))])

# %%
for i, phase in enumerate(phases):
    # print(f"\nPhase: {phase['name']}")
    X_debug = opti.debug.value(X_list[i])
    U_debug = opti.debug.value(U_list[i])
    T_debug = opti.debug.value(T_list[i])

    # print("  States (X) [v, fpa, h, s, m]:")
    # print(X_debug)
    # print("  Controls (U) [thrust, fpa, spdbrk]:")
    # print(U_debug)
    print(f"Phase {phase['name']}, Duration {T_debug}")

    # if "Infeasible_Problem_Detected" in str(e):
        # print("Solver detected infeasibility. Analyzing...")
        # opti.debug.show_infeasibilities()  # Show summary


    # Plot the states
    from state_plot import plot_states, plot_states_ext
    plot_states(X_debug[0], X_debug[1], X_debug[2], X_debug[3], X_debug[4], U_debug[0], U_debug[1], U_debug[2])

    X_ext = np.empty((7, phase['N']))

    # Compute the additional variables
    for k in range(phase['N']):
        xk = X_debug[:,k]
        uk = U_debug[:,k]
        dyn_func = aircraft_dynamics(xk, uk, opti.debug.value(wind_s), opti.debug.value(phi), phase['name'], fiche_engine, fiche_ac, fiche_control)
        dyn_values = opti.debug.value(dyn_func)

        #Further break down
        g = 9.81
        k_gamma = fiche_control['k_gamma']
        v, gamma, h, s, m = xk[0], xk[1], xk[2], xk[3], xk[4]
        T, gamma_ref, beta = uk[0], uk[1], uk[2]
        rho0 = 1.225
        H = 8500.0
        rho = rho0 * np.exp(-h / H)  # Use numpy for scalar calculations during debugging
        nz = (-v * k_gamma * (gamma - gamma_ref) + g * np.cos(gamma))/(g * np.cos(0))
        L = nz * m * g
        epsilon = 1e-6
        v_sq = v**2 + epsilon
        S_area = fiche_ac['wing']['area']
        Cl = L / (0.5 * rho * v_sq * S_area)
        k_drag = fiche_ac['drag']['k']
        Cd = fiche_ac['drag']['cd0'] + beta + k_drag * Cl**2
        D = 0.5 * rho * v**2 * S_area * Cd

        # Fuel flow model (different for each phase)
        if phase['name'] in ['cruise', 'landing', 'descent1', 'descent2']:
            cruise_sfc = fiche_engine['cruise_sfc'] / 3600.0  # [kg/(N·s)]
            fuel_coef = fiche_ac['fuel']['fuel_coef']
            fuel_flow = fuel_coef * cruise_sfc * T
        elif phase['name'] == 'takeoff':
            fuel_flow = fiche_engine['ff_to'] * 2
        elif phase['name'] in ['climb1', 'climb2', 'climb3']:
            fuel_flow = fiche_engine['ff_co'] * 2
        # elif phase['name'] in ['descent1', 'descent2']:
        #     fuel_flow = fiche_engine['ff_app'] * 2
        # elif phase['name'] == 'landing':
        #     fuel_flow = fiche_engine['ff_idl'] * 2
        else:
            fuel_flow = 0.0

        X_ext[:,k] = np.array([L, D, nz, Cl, Cd, rho, fuel_flow])

        if np.isnan(X_ext[:,k]).any():
            print(f"NaN detected at index {k}")
            print(f"X_ext[:,k]: {X_ext[:,k]}")
            print(f"X_ext: {X_ext}")
            print(f"X_ext[0]: {X_ext[0]}")
            print(f"X_ext[1]: {X_ext[1]}")
        
    plot_states_ext(X_ext[0], X_ext[1], X_ext[2], X_ext[3], X_ext[4], X_ext[5], X_ext[6])
# Out:
# Phase climb1, Duration 79.4471330495483
# Phase climb2, Duration 199.74648202959122
# Phase cruise, Duration 4924.8042054433645
# Phase descent1, Duration 1404.000014039999
# Phase descent2, Duration 364.000003639922
# Phase landing, Duration 156.0000015599998
