# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Problem Inputs

# %%
import casadi as ca
import numpy as np
import matplotlib.pyplot as plt
from openap import prop

# -------------------------
# 0. Load aircraft and engine data
# -------------------------
fiche_ac = prop.aircraft("A320")
fiche_engine = prop.engine("CFM56-5-A1")
# Ensure all engine parameters are valid
for key in fiche_engine:
    if isinstance(fiche_engine[key], (int, float)):
        if np.isnan(fiche_engine[key]) or fiche_engine[key] <= 0:
            print(f"Warning: Invalid engine parameter: {key}")
print('Check these warnings carefully since they may cause NaNs in the optimization.')

fiche_engine['cruise_sfc'] = 16.9 / 1000 # kg/(N.s), from Wikipedia 

fiche_control = {
    'k_gamma': 0.45  # P controller gain for flight path angle
}

# Problem Inputs ----------
FL_CRZ = 31000
S_MAX = 567 * 1852
# -------------------------

# 1. Conversion factors and target values
# -------------------------
knots_to_ms = 0.514444
ft_to_m     = 0.3048

# Speeds (m/s)
v_250    = 250 * knots_to_ms       # ~128.61 m/s
v_300    = 300 * knots_to_ms       # ~154.33 m/s
v_mach78 = 0.78 * 340              # ~265.2 m/s (approx.)
v_180    = 180 * knots_to_ms 


# Altitudes (m)
h_takeoff_end  = 1000  * ft_to_m    # 1,000 ft
h_climb1_end   = 10000 * ft_to_m    # 10,000 ft (~3048 m)
h_climb2_end   = FL_CRZ * ft_to_m    # 35,000 ft (~10668 m) transition altitude
h_cruise       = FL_CRZ * ft_to_m    # 35,000 ft (~10668 m)
h_descent1_end = 10000 * ft_to_m    # 10,000 ft (~3048 m)
h_descent2_end = 3000 * ft_to_m    # 3,000 ft (~914.4 m)
h_landing_end  = 0.0               # ground
# Out:
# Warning: Invalid engine parameter: cruise_thrust
# Warning: Invalid engine parameter: cruise_sfc
# Warning: Invalid engine parameter: cruise_mach
# Warning: Invalid engine parameter: cruise_alt
# Check these warnings carefully since they may cause NaNs in the optimization.

# %% [markdown]
# # Aircraft Dynamics

# %%
# -------------------------
# 2. Define the aircraft dynamics function (same as before)
# -------------------------
def aircraft_dynamics(x, u, wind_s, phi, phase, fiche_engine, fiche_ac, fiche_control, num_engines = 2):
    """
    Computes the state derivative for the vertical dynamics.
    x = [v, gamma, h, s, m] # speed, flight path angle, altitude, along-path distance, mass
    u = [T, gamma_ref, beta] # thrust, reference flight path angle, speedbrake parameter
    """
    g = 9.81  # gravitational acceleration (m/s^2)

    # Unpack control parameters
    k_gamma = fiche_control['k_gamma']
    
    # Unpack state and control
    v, gamma, h, s, m = x[0], x[1], x[2], x[3], x[4]  # speed, flight path angle, altitude, along-path distance, mass
    T, gamma_ref, beta = u[0], u[1], u[2]  # thrust, controlled flight path angle, speedbrake parameter
    
    # --- Drag Model ---
    rho0 = 1.225  # sea-level density [kg/m^3]
    H    = 8500.0 # scale height [m]
    rho  = rho0 * ca.exp(-h/H) # air density [kg/m^3]

    # --- Load factor calculation ---
    nz = (-v * k_gamma * (gamma - gamma_ref) + g * ca.cos(gamma))/(g * ca.cos(phi))

    # --- Lift/Drag Calculations ---
    L = nz * m * g  # Required lift force
    epsilon = 1e-6  # small number to avoid division by zero
    v_sq = v**2 + epsilon

    S_area = fiche_ac['wing']['area']  # wing area [m^2]
    Cl = L / (0.5 * rho * v_sq * S_area)
    
    k = fiche_ac['drag']['k']
    Cd = fiche_ac['drag']['cd0'] + beta + k * Cl**2  # parabolic drag model
    D = 0.5 * rho * v**2 * S_area * Cd  # Drag force [N]

    # Fuel flow model (different for each phase)
    if phase == 'cruise':
        cruise_sfc = fiche_engine['cruise_sfc'] / 3600.0  # [kg/(N·s)]
        # fuel_coef = fiche_ac['fuel']['fuel_coef']
        fuel_flow = cruise_sfc * T
    elif phase == 'takeoff':
        fuel_flow = fiche_engine['ff_to'] * num_engines
    elif phase in ['climb1', 'climb2', 'climb3']:
        fuel_flow = fiche_engine['ff_co'] * num_engines
    elif phase in ['descent1', 'descent2', 'descent3']:
        fuel_flow = fiche_engine['ff_app'] * num_engines
    elif phase == 'landing':
        fuel_flow = fiche_engine['ff_idl'] * num_engines
    
    # Dynamics equations
    v_dot     = (T - D) / m - g * ca.sin(gamma)
    gamma_dot = k_gamma * (gamma_ref - gamma)
    h_dot     = v * ca.sin(gamma)
    s_dot     = v * ca.cos(gamma) + wind_s
    m_dot     = -fuel_flow
    
    return ca.vertcat(v_dot, gamma_dot, h_dot, s_dot, m_dot)

# %% [markdown]
# # Phases

# %%
# -------------------------
# 3. Phase definitions
# -------------------------
# We define three phases:
#   - climb1: from 0 ft to 10,000 ft, target speed 250 kts.
#   - climb2: from 10,000 ft to 18,000 ft, target speed 300 kts.
#   - cruise: from 18,000 ft to 35,000 ft, target speed Mach 0.78.

h_takeoff_end  = 1000  * ft_to_m    # 1,000 ft
h_climb1_end   = 10000 * ft_to_m    # 10,000 ft (~3048 m)
h_climb2_end   = FL_CRZ * ft_to_m    # 35,000 ft (~10668 m) transition altitude
h_cruise       = FL_CRZ * ft_to_m    # 35,000 ft (~10668 m)
h_descent1_end = 10000 * ft_to_m    # 10,000 ft (~3048 m)
h_descent2_end = 3000 * ft_to_m    # 3,000 ft (~914.4 m)
h_landing_end  = 0.0               # ground

phases = [
    {"name": "climb1", "N": 50, "h0": 0.0,          "hF": h_climb1_end,  "v_target": v_250},
    {"name": "climb2", "N": 50, "h0": h_climb1_end,  "hF": h_climb2_end,  "v_target": v_300},
    {"name": "cruise", "N": 50, "h0": h_climb2_end,  "hF": h_cruise,      "v_target": v_mach78},
    {"name": "descent1", "N": 50, "h0": h_cruise, "hF": h_descent1_end, "v_target": v_300},
    # {"name": "descent2", "N": 50, "h0": h_descent1_end, "hF": h_descent2_end, "v_target": v_250},
    # {"name": "landing", "N": 50, "h0": h_descent2_end, "hF": h_landing_end, "v_target": v_180}
]

# %%
# -------------------------
# 4. Set up the Opti problem and common parameters
# -------------------------
opti = ca.Opti()

wind_s = opti.parameter();  opti.set_value(wind_s, 0.0)
phi    = opti.parameter();  opti.set_value(phi, 0.0)
CI     = opti.parameter();  opti.set_value(CI, 1.0)

X_list = []  # states for each phase
U_list = []  # controls for each phase
T_list = []  # phase durations
N_list = []  # discretization intervals
phase_names = []

# %% [markdown]
# # Altitude, Speed Boundaries and State Limits

# %%
# -------------------------
# 5. Create decision variables for each phase
# -------------------------

# Slack variables for soft constraints about speed and altitude
V_slacks = []
H_slacks = []

for phase in phases:
    name = phase["name"]
    phase_names.append(name)
    N_phase = phase["N"]
    N_list.append(N_phase)
    
    T_phase = opti.variable()
    opti.set_initial(T_phase, 100.0)
    opti.subject_to(T_phase >= 0)
    T_list.append(T_phase)
    if name == "cruise":
        opti.set_initial(T_phase, 0.9 * S_MAX / v_mach78)
        opti.subject_to(T_phase >= 0.5 * S_MAX / v_mach78)
    dt = T_phase / N_phase  # time step
    
    # State vector: [v, gamma, h, s, m] over (N_phase+1) nodes
    X = opti.variable(5, N_phase+1) # N_phase+1 time steps
    # Control vector: [T, gamma_ref, beta] over N_phase intervals
    U = opti.variable(3, N_phase)
    
    X_list.append(X)
    U_list.append(U)
    
    # Multiple shooting dynamics via explicit Euler integration
    for k in range(N_phase): # between N_phase + 1 time steps are N_phase intervals
        xk = X[:, k]
        uk = U[:, k]
        x_next = X[:, k+1]
        x_next_euler = xk + dt * aircraft_dynamics(xk, uk, wind_s, phi, name, fiche_engine, fiche_ac, fiche_control)
        opti.subject_to(x_next == x_next_euler)
    
    # Altitude boundary conditions for each phase (altitude at the beginning and end of each phase)
    # Soft constraints for initial and final altitude with slack variables
    h_slack_init = opti.variable()
    h_slack_final = opti.variable()
    opti.set_initial(h_slack_init, 0)
    opti.set_initial(h_slack_final, 0)
    
    max_alt_dev = 50.0  # Allow ±50m deviation
    opti.subject_to(h_slack_init <= max_alt_dev)
    opti.subject_to(h_slack_init >= -max_alt_dev)
    opti.subject_to(h_slack_final <= max_alt_dev) 
    opti.subject_to(h_slack_final >= -max_alt_dev)
    
    opti.subject_to(X[2, 0] == phase["h0"] + h_slack_init)
    opti.subject_to(X[2, -1] == phase["hF"] + h_slack_final)
    
    # Enforce prescribed speed if provided
    # if phase["v_target"] is not None:
    #     for k in range(N_phase+1):
    #         opti.subject_to(X[0, k] == phase["v_target"])
    
    # Soft constraints on prescribed speed
    V_slack = opti.variable(N_phase + 1)
    opti.set_initial(V_slack, 0) # set initial guess for slack variables
    if phase["v_target"] is not None:
        max_speed_dev = 10.0  # Allow ±10 m/s deviation
        for k in range(N_phase + 1):
            opti.subject_to(V_slack[k] <= max_speed_dev)
            opti.subject_to(V_slack[k] >= -max_speed_dev)
            opti.subject_to(X[0, k] == phase["v_target"] + V_slack[k])
    else:
        # For phases without a prescribed speed, enforce zero slack.
        for k in range(N_phase + 1):
            opti.subject_to(V_slack[k] == 0)
    V_slacks.append(V_slack)
    
    # For cruise phase, enforce constant altitude along the entire phase
    # if name == "cruise":
    #     for k in range(N_phase + 1):
    #         opti.subject_to(X[2, k] == h_cruise)
    
    # For cruise phase, use soft constraints for altitude
    H_slack = opti.variable(N_phase + 1)
    opti.set_initial(H_slack, 0) # set initial guess for slack variables
    if name == "cruise":
        max_alt_dev = 100.0  # Allow ±100 m deviation
        for k in range(N_phase + 1):
            opti.subject_to(H_slack[k] <= max_alt_dev)
            opti.subject_to(H_slack[k] >= -max_alt_dev)
            opti.subject_to(X[2, k] == h_cruise + H_slack[k])
    else:
        # For phases other than cruise, enforce zero slack.
        for k in range(N_phase + 1):
            opti.subject_to(H_slack[k] == 0)
    H_slacks.append(H_slack)


    # Additional state bounds (applied at every node)
    for k in range(N_phase+1):
        opti.subject_to(X[0, k] >= 0)        # v lower bound
        opti.subject_to(X[0, k] <= 350)      # v upper bound
        opti.subject_to(X[1, k] >= -0.5)       # gamma lower bound
        opti.subject_to(X[1, k] <= 0.5)        # gamma upper bound
        opti.subject_to(X[2, k] >= 0)          # altitude lower bound
        opti.subject_to(X[2, k] <= 12000)      # altitude upper bound (sufficient for cruise)
        opti.subject_to(X[3, k] >= 0)          # along-path distance lower bound
        opti.subject_to(X[4, k] >= 50000)      # mass lower bound
        opti.subject_to(X[4, k] <= 90000)      # mass upper bound
    
    # Control bounds for each interval
    for k in range(N_phase):
        opti.subject_to(U[0, k] >= 0)        # Thrust lower bound
        opti.subject_to(U[0, k] <= fiche_engine['max_thrust'])   # Thrust upper bound
        opti.subject_to(U[1, k] >= -0.5)       # gamma_ref lower bound
        opti.subject_to(U[1, k] <= 0.5)        # gamma_ref upper bound
        opti.subject_to(U[2, k] >= 0.0)        # beta lower bound
        opti.subject_to(U[2, k] <= 0.02)        # beta upper bound

# %% [markdown]
# # Phase Continuity

# %%
# -------------------------
# 6. Impose continuity between phases
# -------------------------
# Ensure that the final state of phase i equals the initial state of phase i+1.
for i in range(len(phases)-1):
    opti.subject_to(X_list[i+1][1:, 0] == X_list[i][1:, -1]) # skip velocity mismatch

# %% [markdown]
# # Initial and Final Conditions

# %%
# -------------------------
# 7. Impose boundary conditions on the first phase (takeoff/climb1)
# -------------------------
# Initial state: [v, gamma, h, s, m]
x0 = np.array([v_250, 0.0, 0.0, 0.0, 70000.0])
opti.set_initial(X_list[0][:, 0], x0)
opti.subject_to(X_list[0][3, 0] == 0.0)   # along-path distance

# Until traveled distance s is 200_000m - only constrain final point
# opti.subject_to(X_list[-1][3, -1] == 200_000)

# At final descent, the traveled distance (soft constraint)
S_slack = opti.variable()  # Slack variable for distance constraint
opti.subject_to(S_slack >= 0)  # Slack must be non-negative
opti.subject_to(X_list[-1][3, -1] + S_slack >= S_MAX)  # Soft constraint with slack

# For climb1, ensure the final speed is the prescribed v_250
# opti.subject_to(X_list[0][0, -1] == v_250)

# %% [markdown]
# # Cost Function

# %%
# -------------------------
# 8. Define the overall cost function
# -------------------------
# Here, the cost in each phase is integrated over time.
total_cost = 0
for i, phase in enumerate(phases):
    N_phase = phase["N"]
    T_phase = T_list[i]
    dt = T_phase / N_phase
    X = X_list[i]
    U = U_list[i]
    J_phase = 0
    alt_h0_hf_weight = 1e3
    speed_penalty_weight = 1e3
    alt_penalty_weight = 1e3
    distance_penalty_weight = 1e4
            
    for k in range(N_phase):
        T_k = U[0, k]
        # Example: simple cost (you can replace fuel_flow model as needed)
        # fuel_flow_k = 0.0001 * T_k  # [kg/s]
        # J_phase += (fuel_flow_k + CI) * dt
        J_phase += (CI) * dt
        speed_penalty = speed_penalty_weight * V_slacks[i][k]**2
        alt_penalty = alt_penalty_weight * H_slacks[i][k]**2
        alt_h0_hf_penalty = alt_h0_hf_weight * (h_slack_init**2 + h_slack_final**2)
        J_phase += speed_penalty + alt_penalty + alt_h0_hf_penalty
        J_phase += distance_penalty_weight * S_slack**2

    total_cost += J_phase
opti.minimize(total_cost)

# %% [markdown]
# # Initial Guesses

# %%
# -------------------------
# 9. Provide initial guesses for states and controls
# -------------------------
for i, phase in enumerate(phases):
    N_phase = phase["N"]
    X = X_list[i]
    for k in range(N_phase+1):
        # Linear interpolation for altitude between phase boundaries
        h_guess = phase["h0"] + (phase["hF"] - phase["h0"]) * k / N_phase
        opti.set_initial(X[2, k], h_guess)
        
        # For speed, if v_target is enforced, it is already fixed.
        if phase["v_target"] is not None:
            if phase["name"] == "takeoff":
                v_guess = 0 + (v_250 - 0) * k / N_phase
                opti.set_initial(X[0, k], v_guess) # set initial guess, not initial condition
            elif phase["name"] == "climb1":
                opti.set_initial(X[0, k], v_250)
            elif phase["name"] == "climb2":
                opti.set_initial(X[0, k], v_300)
            elif phase["name"] == "cruise":
                opti.set_initial(X[0, k], v_mach78)
            elif phase["name"] == "descent1":
                opti.set_initial(X[0, k], v_300)
            elif phase["name"] == "descent2":
                opti.set_initial(X[0, k], v_250)
            elif phase["name"] == "landing":
                opti.set_initial(X[0, k], v_180)
        else:
            opti.set_initial(X[0, k], v_250) # other phases without v_target prescribed
        # Provide guesses for other states.
        opti.set_initial(X[1, k], 0.0)  # gamma
        opti.set_initial(X[4, k], 70000.0 - 1000*i)  # mass

# Along-path distance initial guesses
for phase in phases:
    N_phase = phase["N"]
    X = X_list[i]
    for k in range(N_phase+1):
        if phase["name"] == "climb1":
            opti.set_initial(X[3, k], 0.0 + 0.05 * S_MAX * (k/float(N_phase)))  # along-path distance
        elif phase["name"] == "climb2":
            opti.set_initial(X[3, k], 0.05 * S_MAX + 0.05 * S_MAX *(k/float(N_phase)))  # along-path distance
        elif phase["name"] == "cruise":
            opti.set_initial(X[3, k], 0.1 * S_MAX + 0.8 * S_MAX *(k/float(N_phase)))  # along-path distance
        elif phase["name"] == "descent1":
            opti.set_initial(X[3, k], 0.9 * S_MAX + 0.04 * S_MAX *(k/float(N_phase)))  # along-path distance
        elif phase["name"] == "descent2":
            opti.set_initial(X[3, k], 0.94 * S_MAX + 0.03 * S_MAX *(k/float(N_phase)))  # along-path distance
        elif phase["name"] == "landing":
            opti.set_initial(X[3, k], 0.97 * S_MAX + 0.03 * S_MAX *(k/float(N_phase)))  # along-path distance
    
    # Initial guesses for controls.
    U = U_list[i]
    for k in range(N_phase):
        opti.set_initial(U[0, k], 50000.0)  # thrust
        opti.set_initial(U[1, k], 0.0)       # gamma_ref
        opti.set_initial(U[2, k], 0.0)       # beta

# %% [markdown]
# # Solve

# %%
# -------------------------
# 10. Solve the NLP
# -------------------------
p_opts = {"expand": True}
s_opts = {"max_iter": 50e3, "print_level": 5, "tol":1e-6, "acceptable_tol":1e-4}
opti.solver('ipopt', p_opts, s_opts)

try:
    sol = opti.solve()  # Solve the optimization problem
except RuntimeError as e:
    print("Solver error:", e)
    
    # Inspect values at the point where the error occurred
    print("\n--- Debugging Information ---")
    for i, phase in enumerate(phases):
        # print(f"\nPhase: {phase['name']}")
        X_debug = opti.debug.value(X_list[i])
        U_debug = opti.debug.value(U_list[i])
        T_debug = opti.debug.value(T_list[i])

        # print("  States (X) [v, fpa, h, s, m]:")
        # print(X_debug)
        # print("  Controls (U) [thrust, fpa, spdbrk]:")
        # print(U_debug)
        print(f"Phase {phase['name']}, Duration {T_debug}")

        # if "Infeasible_Problem_Detected" in str(e):
            # print("Solver detected infeasibility. Analyzing...")
            # opti.debug.show_infeasibilities()  # Show summary


        # Plot the states
        from state_plot import plot_states, plot_states_ext
        plot_states(X_debug[0], X_debug[1], X_debug[2], X_debug[3], X_debug[4], U_debug[0], U_debug[1], U_debug[2])

        X_ext = np.empty((6, phase['N']))

        # Compute the additional variables
        for k in range(phase['N']):
            xk = X_debug[:,k]
            uk = U_debug[:,k]
            dyn_func = aircraft_dynamics(xk, uk, opti.debug.value(wind_s), opti.debug.value(phi), phase['name'], fiche_engine, fiche_ac, fiche_control)
            dyn_values = opti.debug.value(dyn_func)

            #Further break down
            g = 9.81
            k_gamma = fiche_control['k_gamma']
            v, gamma, h, s, m = xk[0], xk[1], xk[2], xk[3], xk[4]
            T, gamma_ref, beta = uk[0], uk[1], uk[2]
            rho0 = 1.225
            H = 8500.0
            rho = rho0 * np.exp(-h / H)  # Use numpy for scalar calculations during debugging
            nz = (-v * k_gamma * (gamma - gamma_ref) + g * np.cos(gamma))/(g * np.cos(0))
            L = nz * m * g
            epsilon = 1e-6
            v_sq = v**2 + epsilon
            S_area = fiche_ac['wing']['area']
            Cl = L / (0.5 * rho * v_sq * S_area)
            k_drag = fiche_ac['drag']['k']
            Cd = fiche_ac['drag']['cd0'] + beta + k_drag * Cl**2
            D = 0.5 * rho * v**2 * S_area * Cd

            X_ext[:,k] = np.array([L, D, nz, Cl, Cd, rho])
            if np.isnan(X_ext[:,k]).any():
                print(f"NaN detected at index {k}")
                print(f"X_ext[:,k]: {X_ext[:,k]}")
                print(f"X_ext: {X_ext}")
                print(f"X_ext[0]: {X_ext[0]}")
                print(f"X_ext[1]: {X_ext[1]}")
            
            # Check the constraints manually
        # Manually check constraints
        print("\nChecking constraints for phase:", phase['name'])
        
        # Check altitude constraints
        h_min = phase['h0']
        h_max = phase['hF'] 
        h_violations = np.where((X_debug[2,:-1] < h_min) | (X_debug[2,:-1] > h_max))[0]
        if len(h_violations) > 0:
            print(f"Altitude constraint violations at steps: {h_violations}")
            print(f"Values: {X_debug[2,h_violations]}")
            print(f"Bounds: [{h_min}, {h_max}]")
            
        # Check speed constraints
        v_target = phase['v_target']
        v_tolerance = 10.0  # m/s tolerance
        v_violations = np.where(abs(X_debug[0,:-1] - v_target) > v_tolerance)[0]
        if len(v_violations) > 0:
            print(f"Speed constraint violations at steps: {v_violations}")
            print(f"Values: {X_debug[0,v_violations]}")
            print(f"Target: {v_target} ± {v_tolerance}")
            
        # Check load factor constraints
        nz_max = 1.3  # maximum load factor
        nz_violations = np.where(abs(X_ext[2,:]) > nz_max)[0]
        if len(nz_violations) > 0:
            print(f"Load factor constraint violations at steps: {nz_violations}")
            print(f"Values: {X_ext[2,nz_violations]}")
            print(f"Bound: ±{nz_max}")
            
        # Check thrust constraints
        T_max = fiche_engine['max_thrust'] * 2  # 2 engines
        T_violations = np.where((U_debug[0,:] < 0) | (U_debug[0,:] > T_max))[0]
        if len(T_violations) > 0:
            print(f"Thrust constraint violations at steps: {T_violations}")
            print(f"Values: {U_debug[0,T_violations]}")
            print(f"Bounds: [0, {T_max}]")
            
        # Check speedbrake constraints
        beta_max = 0.1
        beta_violations = np.where((U_debug[2,:] < 0) | (U_debug[2,:] > beta_max))[0]
        if len(beta_violations) > 0:
            print(f"Speedbrake constraint violations at steps: {beta_violations}")
            print(f"Values: {U_debug[2,beta_violations]}")
            print(f"Bounds: [0, {beta_max}]")
            
        # Check the slack variables
        # Check slack variables for NaNs
        if len(V_slacks) > 0 and len(H_slacks) > 0:
            v_slack_vals = opti.debug.value(V_slacks[-1])
            h_slack_vals = opti.debug.value(H_slacks[-1])
            
            print(f"v_slack_vals: {v_slack_vals}")
            print(f"h_slack_vals: {h_slack_vals}")
            
            if np.any(np.isnan(v_slack_vals)):
                print(f"NaN detected in velocity slack variables!")
                print(f"Indices of NaNs: {np.where(np.isnan(v_slack_vals))[0]}")
            
            if np.any(np.isnan(h_slack_vals)):
                print(f"NaN detected in altitude slack variables!")
                print(f"Indices of NaNs: {np.where(np.isnan(h_slack_vals))[0]}")
                
        plot_states_ext(X_ext[0], X_ext[1], X_ext[2], X_ext[3], X_ext[4], X_ext[5])
        
    # Let's deal with NaNs
    # Get the current values of all decision variables:
    x_val = opti.debug.value(opti.x)
    if np.any(np.isnan(x_val)):
        print("NaN detected in decision variable values!")
        print("Indices of NaNs:", np.where(np.isnan(x_val)))
    else:
        print("No NaNs in decision variables.")
    
    # Evaluate the constraint function values:
    g_val = opti.debug.value(opti.g)
    if np.any(np.isnan(g_val)):
        print("NaN detected in constraint values!")
        print("Indices of NaNs:", np.where(np.isnan(g_val)))
    else:
        print("No NaNs in constraint values.")
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:     5954
# Number of nonzeros in inequality constraint Jacobian.:     3570
# Number of nonzeros in Lagrangian Hessian.............:     5603
#
# Total number of variables............................:     2041
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1429
# Total number of inequality constraints...............:     3569
#         inequality constraints with only lower bounds:     1890
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:     1679
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.8636335e+03 9.45e+05 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.9014856e+03 9.34e+05 3.00e+00  -1.0 9.45e+05    -  5.95e-03 1.12e-02h  1
#    2  3.9123390e+03 9.31e+05 1.13e+01  -1.0 9.34e+05    -  1.87e-02 3.20e-03h  1
#    3  3.9167565e+03 9.30e+05 2.35e+02  -1.0 9.31e+05    -  2.73e-02 1.28e-03h  1
#    4  3.9382475e+03 9.25e+05 3.03e+02  -1.0 9.30e+05    -  9.98e-03 6.09e-03h  1
#    5  3.9563150e+03 9.20e+05 3.43e+02  -1.0 9.25e+05    -  7.07e-03 5.04e-03h  1
#    6  3.9653348e+03 9.18e+05 3.72e+02  -1.0 9.20e+05    -  3.64e-03 2.43e-03h  1
#    7  3.9693870e+03 9.17e+05 3.89e+02  -1.0 9.18e+05    -  1.69e-03 1.05e-03h  1
#    8  3.9714111e+03 9.16e+05 4.06e+02  -1.0 9.17e+05    -  1.11e-03 5.15e-04h  1
#    9  3.9732142e+03 9.16e+05 1.97e+03  -1.0 9.16e+05    -  6.72e-03 4.64e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.9828236e+03 9.14e+05 4.82e+03  -1.0 9.16e+05    -  8.59e-03 2.29e-03h  1
#   11  4.6097013e+03 9.14e+05 4.58e+03  -1.0 5.75e+05  -2.0 1.38e-06 1.59e-04h  1
#   12  5.0990798e+03 9.14e+05 4.50e+03  -1.0 6.09e+05  -1.6 3.89e-06 4.34e-05h  1
#   13  5.5326154e+03 9.14e+05 4.43e+03  -1.0 4.66e+05  -2.1 6.49e-06 4.84e-05h  1
#   14  5.7650452e+03 9.14e+05 4.40e+03  -1.0 6.75e+05  -1.6 4.08e-06 1.98e-05h  1
#   15  6.0813528e+03 9.14e+05 4.37e+03  -1.0 7.45e+05  -1.2 7.87e-06 1.92e-05h  1
#   16  7.1687652e+03 9.13e+05 4.20e+03  -1.0 6.85e+05  -1.7 1.37e-06 8.06e-05h  1
#   17  7.7062737e+03 9.13e+05 4.18e+03  -1.0 7.46e+05  -1.3 1.96e-05 2.58e-05h  1
#   18  9.7347925e+03 9.13e+05 4.69e+03  -1.0 6.87e+05  -1.7 2.10e-06 1.18e-04h  1
#   19  1.0413856e+04 9.13e+05 4.54e+03  -1.0 7.44e+05  -1.3 2.99e-05 2.57e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.1073447e+04 9.13e+05 4.97e+03  -1.0 7.67e+05  -0.9 1.40e-05 1.83e-05h  1
#   21  1.3178601e+04 9.13e+05 7.10e+03  -1.0 7.41e+05  -1.4 8.58e-06 7.30e-05h  1
#   22  1.3609139e+04 9.13e+05 4.15e+03  -1.0 7.65e+05  -0.9 1.06e-04 1.04e-05h  1
#   23  2.1814058e+04 9.13e+05 5.81e+03  -1.0 7.37e+05  -1.4 1.76e-06 2.31e-04h  1
#   24r 2.1814058e+04 9.13e+05 1.00e+03   6.0 0.00e+00  -1.0 0.00e+00 2.53e-07R  6
#   25r 2.2485175e+04 9.07e+05 1.00e+03   6.0 7.00e+07    -  8.05e-05 8.05e-05f  1
#   26r 2.8560563e+04 3.04e+05 2.56e+04   3.9 5.81e+07    -  8.95e-04 1.04e-02f  1
#   27  2.3777960e+04 2.58e+05 6.93e+04  -1.0 3.10e+05    -  2.09e-01 1.49e-01f  1
#   28  2.5166115e+04 2.58e+05 6.93e+04  -1.0 1.75e+05  -1.5 2.27e-03 2.36e-04h  1
#   29  3.8966721e+04 2.58e+05 6.92e+04  -1.0 1.67e+05  -1.0 4.81e-03 1.29e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  1.0864667e+06 2.51e+05 8.75e+04  -1.0 1.74e+05  -1.5 2.98e-03 2.79e-02h  1
#   31  1.4324542e+06 2.50e+05 8.73e+04  -1.0 1.45e+05  -0.2 2.22e-02 2.80e-03h  1
#   32  1.4566279e+06 2.50e+05 8.72e+04  -1.0 1.56e+05  -0.7 3.92e-02 2.09e-04h  1
#   33  1.4788345e+06 2.50e+05 4.38e+05  -1.0 1.31e+05  -0.2 3.89e-02 1.75e-04h  1
#   34  2.0496555e+06 2.49e+05 5.95e+05  -1.0 1.31e+05  -0.7 3.43e-02 4.89e-03h  1
#   35  2.1108948e+06 2.49e+05 9.48e+05  -1.0 1.45e+05  -0.3 2.94e-02 5.14e-04h  1
#   36  3.2126782e+06 2.46e+05 1.07e+06  -1.0 1.52e+05  -0.8 3.50e-02 9.36e-03h  1
#   37  3.2572392e+06 2.46e+05 1.64e+06  -1.0 1.57e+05  -0.3 4.86e-02 2.74e-04h  1
#   38  4.1620456e+06 2.45e+05 1.80e+06  -1.0 1.64e+05  -0.8 4.46e-02 6.81e-03h  1
#   39  4.3042269e+06 2.44e+05 2.46e+06  -1.0 1.58e+05  -0.4 6.05e-02 6.86e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  5.7611321e+06 2.42e+05 2.72e+06  -1.0 1.59e+05  -0.9 7.23e-02 8.50e-03h  1
#   41  7.6874794e+06 2.41e+05 3.33e+06  -1.0 1.63e+05  -0.4 7.03e-02 6.35e-03h  1
#   42  1.0921901e+07 2.38e+05 3.44e+06  -1.0 1.64e+05  -0.9 6.02e-02 1.24e-02h  1
#   43  1.1331832e+07 2.38e+05 4.24e+06  -1.0 1.64e+05  -0.5 9.87e-02 9.69e-04h  1
#   44  1.4226092e+07 2.35e+05 4.29e+06  -1.0 1.66e+05  -1.0 5.55e-02 9.65e-03h  1
#   45  1.6989775e+07 2.34e+05 5.08e+06  -1.0 1.62e+05  -0.5 1.22e-01 5.63e-03h  1
#   46  2.1140095e+07 2.33e+05 6.23e+06  -1.0 1.47e+05  -0.1 6.24e-02 6.19e-03h  1
#   47  2.3458817e+07 2.31e+05 6.58e+06  -1.0 1.39e+05  -0.6 4.24e-02 6.24e-03h  1
#   48  2.6241298e+07 2.30e+05 7.98e+06  -1.0 1.25e+05  -0.2 4.87e-02 4.51e-03h  1
#   49  2.9909044e+07 2.29e+05 8.34e+06  -1.0 1.18e+05   0.3 8.70e-03 4.01e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  3.2013076e+07 2.28e+05 8.84e+06  -1.0 1.32e+05  -0.2 2.10e-02 4.07e-03h  1
#   51  3.2371781e+07 2.28e+05 8.84e+06  -1.0 1.51e+05  -0.7 4.67e-03 2.14e-03h  1
#   52  3.2377740e+07 2.28e+05 9.04e+06  -1.0 1.45e+05  -0.3 6.47e-03 2.12e-05h  1
#   53r 3.2377740e+07 2.28e+05 1.00e+03   5.4 0.00e+00   0.2 0.00e+00 3.13e-07R  4
#   54r 4.0965973e+07 1.77e+05 9.99e+02   5.4 8.39e+07    -  6.08e-04 6.09e-04f  1
#   55  3.7889365e+07 1.70e+05 9.57e+04  -1.0 2.13e+05    -  1.42e-02 3.85e-02f  1
#   56  3.7970104e+07 1.70e+05 9.57e+04  -1.0 1.05e+05  -0.3 4.77e-02 3.36e-04h  1
#   57  3.8029686e+07 1.70e+05 9.57e+04  -1.0 1.15e+05  -0.8 7.64e-02 2.82e-04h  1
#   58  3.8087046e+07 1.70e+05 1.10e+05  -1.0 1.24e+05  -1.3 7.67e-02 2.80e-04h  1
#   59  3.8261915e+07 1.69e+05 1.36e+05  -1.0 1.30e+05  -1.7 2.17e-02 1.28e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  3.8799048e+07 1.68e+05 1.35e+05  -1.0 1.30e+05  -2.2 9.16e-03 8.87e-03h  1
#   61  3.8820850e+07 1.68e+05 1.79e+05  -1.0 1.26e+05  -1.8 3.24e-02 1.55e-04h  1
#   62  3.9823937e+07 1.65e+05 1.74e+05  -1.0 1.26e+05  -2.3 1.47e-02 1.84e-02h  1
#   63  4.0386057e+07 1.64e+05 2.37e+05  -1.0 1.25e+05  -1.8 5.51e-02 4.20e-03h  1
#   64  4.1072283e+07 1.64e+05 4.55e+05  -1.0 1.23e+05  -1.4 8.90e-02 2.88e-03h  1
#   65  4.1820741e+07 1.62e+05 4.90e+05  -1.0 1.20e+05  -1.9 4.58e-02 9.37e-03h  1
#   66  4.2371284e+07 1.61e+05 6.29e+05  -1.0 1.13e+05  -1.5 5.07e-02 4.93e-03h  1
#   67  4.2519351e+07 1.60e+05 6.27e+05  -1.0 1.20e+05  -1.9 1.30e-02 9.11e-03h  1
#   68  4.2753831e+07 1.60e+05 6.32e+05  -1.0 1.03e+05  -1.5 3.45e-03 6.68e-04h  1
#   69  4.3223563e+07 1.60e+05 6.45e+05  -1.0 1.36e+05  -1.1 3.47e-03 1.09e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  4.3460240e+07 1.59e+05 6.47e+05  -1.0 2.86e+05  -1.6 3.11e-03 6.78e-04h  1
#   71  4.3600855e+07 1.59e+05 6.67e+05  -1.0 3.01e+05  -1.1 4.23e-03 3.60e-04h  1
#   72  4.3807133e+07 1.59e+05 8.34e+05  -1.0 3.34e+05  -1.6 4.78e-03 7.14e-04h  1
#   73  4.3933168e+07 1.59e+05 1.49e+06  -1.0 3.44e+05  -1.2 6.10e-03 3.64e-04h  1
#   74  4.4106261e+07 1.59e+05 1.84e+06  -1.0 3.60e+05  -1.7 7.93e-03 7.53e-04h  1
#   75  4.4239068e+07 1.59e+05 3.22e+06  -1.0 3.68e+05  -1.3 1.20e-02 4.50e-04h  1
#   76  4.4407566e+07 1.59e+05 3.88e+06  -1.0 3.81e+05  -1.7 1.45e-02 9.93e-04h  1
#   77  4.4580755e+07 1.59e+05 5.76e+06  -1.0 3.89e+05  -1.3 1.63e-02 7.60e-04h  1
#   78  4.4663419e+07 1.59e+05 6.38e+06  -1.0 4.00e+05  -1.8 1.40e-02 8.90e-04h  1
#   79  4.4769357e+07 1.59e+05 7.22e+06  -1.0 4.00e+05  -1.4 7.78e-03 5.83e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  4.4913359e+07 1.58e+05 7.03e+06  -1.0 4.07e+05  -0.9 7.64e-05 6.83e-04h  1
#   81  4.4956052e+07 1.58e+05 6.98e+06  -1.0 4.09e+05  -1.4 1.65e-06 3.94e-04h  1
#   82r 4.4956052e+07 1.58e+05 1.00e+03   5.2 0.00e+00  -1.0 0.00e+00 4.74e-07R  5
#   83r 4.5591115e+07 1.55e+05 1.00e+03   5.2 5.53e+07    -  1.21e-04 6.18e-05f  1
#   84r 6.9305022e+07 5.06e+04 1.00e+03   3.8 5.91e+07    -  3.05e-04 1.77e-03f  1
#   85  6.9303543e+07 5.06e+04 1.18e+05  -1.0 1.02e+05    -  2.12e-03 1.25e-05f  1
#   86  6.9259670e+07 5.06e+04 1.18e+05  -1.0 4.35e+05    -  2.33e-03 6.07e-04f  1
#   87  6.9194934e+07 5.05e+04 1.18e+05  -1.0 4.42e+05    -  4.04e-03 7.79e-04f  1
#   88  6.9147130e+07 5.05e+04 1.18e+05  -1.0 4.54e+05    -  6.75e-03 4.71e-04f  1
#   89  6.8384532e+07 5.02e+04 1.17e+05  -1.0 4.65e+05    -  6.79e-03 6.55e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  6.6372632e+07 4.94e+04 1.15e+05  -1.0 4.67e+05    -  4.85e-03 1.66e-02f  1
#   91  6.6384590e+07 4.94e+04 1.15e+05  -1.0 8.77e+04  -1.5 3.72e-03 2.27e-05h  1
#   92  6.6457708e+07 4.93e+04 1.15e+05  -1.0 1.35e+05  -1.9 6.60e-03 1.60e-04h  1
#   93  6.6475571e+07 4.93e+04 1.15e+05  -1.0 2.33e+05  -2.4 4.04e-03 8.78e-05h  1
#   94  6.6467438e+07 4.93e+04 1.15e+05  -1.0 3.20e+05  -2.9 2.23e-03 1.21e-04f  1
#   95  6.6333941e+07 4.93e+04 1.16e+05  -1.0 4.09e+05  -3.4 4.16e-03 9.51e-04f  1
#   96  6.6278334e+07 4.93e+04 1.34e+05  -1.0 3.87e+05  -2.9 4.14e-03 3.00e-04f  1
#   97  6.5660250e+07 4.91e+04 1.50e+05  -1.0 4.32e+05  -3.4 1.40e-02 3.69e-03f  1
#   98  6.5369062e+07 4.90e+04 1.68e+05  -1.0 4.07e+05  -3.0 5.75e-03 1.42e-03f  1
#   99  6.5047297e+07 4.90e+04 2.29e+05  -1.0 3.97e+05  -2.6 7.03e-03 1.29e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  6.0744563e+07 4.79e+04 2.27e+05  -1.0 4.14e+05  -3.0 2.28e-02 2.19e-02f  1
#  101  5.9829046e+07 4.77e+04 2.25e+05  -1.0 3.89e+05  -2.6 4.12e-03 4.24e-03f  1
#  102  5.8244490e+07 4.73e+04 1.10e+05  -1.0 3.88e+05  -2.2 4.40e-04 8.14e-03f  1
#  103  5.7635596e+07 4.71e+04 1.15e+05  -1.0 3.85e+05  -2.7 1.13e-02 3.30e-03f  1
#  104  5.7631271e+07 4.71e+04 6.53e+05  -1.0 3.83e+05  -2.2 2.67e-02 2.34e-05f  1
#  105  5.7485026e+07 4.71e+04 1.89e+06  -1.0 3.91e+05  -1.8 2.60e-02 8.48e-04f  1
#  106  5.6529816e+07 4.69e+04 2.78e+06  -1.0 3.91e+05  -2.3 5.69e-02 4.18e-03f  1
#  107  5.6232931e+07 4.68e+04 3.85e+06  -1.0 3.89e+05  -1.9 2.62e-02 1.35e-03f  1
#  108  5.4415918e+07 4.65e+04 4.30e+06  -1.0 3.96e+05  -2.3 4.36e-02 7.52e-03f  1
#  109  5.3206684e+07 4.62e+04 5.19e+06  -1.0 3.94e+05  -1.9 2.93e-02 5.21e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  5.2564767e+07 4.61e+04 5.40e+06  -1.0 4.05e+05  -2.4 2.50e-02 2.72e-03f  1
#  111  4.9658642e+07 4.56e+04 7.26e+06  -1.0 4.05e+05  -2.0 6.87e-02 1.14e-02f  1
#  112  4.7829184e+07 4.50e+04 1.05e+07  -1.0 4.00e+05  -1.5 5.01e-02 1.26e-02f  1
#  113  4.7766532e+07 4.50e+04 1.09e+07  -1.0 3.95e+05  -2.0 1.57e-02 4.11e-04f  1
#  114  4.7417770e+07 4.49e+04 1.33e+07  -1.0 4.02e+05  -1.6 3.44e-02 2.34e-03f  1
#  115  4.7311917e+07 4.48e+04 2.07e+07  -1.0 4.01e+05  -1.2 3.85e-02 2.92e-03f  1
#  116  4.6717726e+07 4.46e+04 2.70e+07  -1.0 4.06e+05  -1.6 1.11e-01 3.51e-03f  1
#  117  4.6279020e+07 4.44e+04 3.09e+07  -1.0 4.05e+05  -1.2 2.74e-02 4.98e-03f  1
#  118  4.6124651e+07 4.43e+04 4.20e+07  -1.0 4.08e+05  -0.8 2.34e-02 2.23e-03f  1
#  119  4.5495961e+07 4.40e+04 4.27e+07  -1.0 4.09e+05  -1.3 1.20e-02 5.39e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  4.5313491e+07 4.40e+04 7.61e+07  -1.0 4.10e+05  -0.8 7.28e-02 1.27e-03f  1
#  121  4.4428944e+07 4.37e+04 8.56e+07  -1.0 4.12e+05  -1.3 1.14e-01 5.81e-03f  1
#  122  4.4307006e+07 4.37e+04 9.56e+07  -1.0 4.09e+05  -0.9 2.84e-02 8.71e-04f  1
#  123  4.2881318e+07 4.33e+04 1.09e+08  -1.0 4.09e+05  -0.5 2.15e-02 8.71e-03f  1
#  124  4.1092306e+07 4.32e+04 1.41e+08  -1.0 4.05e+05  -0.0 1.30e-02 2.72e-03f  1
#  125  4.1076862e+07 4.32e+04 2.73e+08  -1.0 4.04e+05   0.4 1.56e-02 2.00e-05f  1
#  126  4.1073232e+07 4.32e+04 3.37e+08  -1.0 4.04e+05  -0.1 2.46e-02 6.77e-06f  1
#  127  3.7323024e+07 4.29e+04 7.00e+08  -1.0 4.04e+05   0.3 5.69e-02 7.33e-03f  1
#  128  3.6761673e+07 4.28e+04 1.16e+09  -1.0 4.01e+05   0.8 2.46e-02 1.39e-03f  1
#  129  3.6750791e+07 4.28e+04 8.79e+09  -1.0 4.01e+05   1.2 1.43e-01 3.38e-05f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  3.5619166e+07 4.26e+04 9.07e+09  -1.0 4.01e+05   0.7 3.90e-02 4.85e-03f  1
#  131  3.5078390e+07 4.25e+04 1.17e+10  -1.0 3.99e+05   1.1 7.10e-02 3.21e-03f  1
#  132  3.3993461e+07 4.21e+04 1.17e+10  -1.0 3.97e+05   0.7 3.35e-02 8.85e-03f  1
#  133  3.3511271e+07 4.18e+04 1.52e+10  -1.0 3.94e+05   1.1 1.24e-01 8.01e-03f  1
#  134  3.4260501e+07 4.15e+04 3.22e+10  -1.0 3.91e+05   2.4 2.51e-02 6.17e-03h  1
#  135  3.7257375e+07 4.15e+04 2.02e+10  -1.0 3.88e+05   3.7 4.11e-06 6.24e-04h  1
#  136  3.7444037e+07 4.15e+04 2.37e+10  -1.0 3.84e+05   4.2 7.90e-05 1.00e-05h  1
#  137  3.7604692e+07 4.15e+04 2.25e+10  -1.0 3.85e+05   4.6 4.24e-06 1.27e-05h  1
#  138  3.9093007e+07 4.15e+04 2.07e+10  -1.0 3.82e+05   4.1 8.93e-06 5.05e-05h  1
#  139  3.9541786e+07 4.15e+04 2.28e+10  -1.0 3.83e+05   4.5 3.98e-05 2.23e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140  6.8271657e+07 4.15e+04 1.96e+10  -1.0 6.53e+05   4.1 2.03e-06 9.09e-05h  1
#  141r 6.8271657e+07 4.15e+04 1.00e+03   4.6 0.00e+00   4.5 0.00e+00 3.44e-07R  4
#  142r 4.4967071e+07 6.25e+03 3.00e+03   4.6 5.14e+07    -  8.98e-04 9.04e-04f  1
#  143  4.4960082e+07 6.25e+03 1.11e+05  -1.0 2.50e+05    -  3.71e-03 8.03e-05f  1
#  144  4.4725163e+07 6.24e+03 1.11e+05  -1.0 3.58e+05    -  4.66e-03 2.73e-03f  1
#  145  4.2857037e+07 6.10e+03 1.08e+05  -1.0 3.57e+05    -  1.22e-02 2.20e-02f  1
#  146  4.1397750e+07 5.99e+03 1.07e+05  -1.0 3.50e+05    -  4.91e-02 1.78e-02f  1
#  147  4.0643158e+07 5.93e+03 1.06e+05  -1.0 3.44e+05    -  9.55e-02 9.43e-03f  1
#  148  3.8670562e+07 5.79e+03 1.03e+05  -1.0 3.41e+05    -  4.47e-02 2.51e-02f  1
#  149r 3.8670562e+07 5.79e+03 1.00e+03   3.8 0.00e+00   4.0 0.00e+00 3.83e-07R  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150r 3.9791628e+07 5.76e+03 1.08e+03   3.8 2.06e+07    -  7.04e-04 9.50e-06f  1
#  151r 3.9969943e+07 5.69e+03 1.07e+03   3.8 2.18e+07    -  2.39e-04 3.01e-04f  1
#  152r 4.0756840e+07 5.52e+03 1.02e+03   3.8 2.14e+07    -  2.61e-04 5.36e-04f  1
#  153r 4.3084357e+07 5.10e+03 9.97e+02   3.8 1.69e+07    -  5.48e-04 7.81e-04f  1
#  154  4.3077145e+07 5.10e+03 1.29e+05  -1.0 2.77e+05    -  2.12e-02 8.63e-05f  1
#  155  4.1138393e+07 4.98e+03 1.26e+05  -1.0 2.98e+05    -  2.59e-02 2.35e-02f  1
#  156  3.8386638e+07 4.80e+03 1.21e+05  -1.0 2.91e+05    -  6.24e-02 3.50e-02f  1
#  157  3.7123806e+07 4.72e+03 1.19e+05  -1.0 2.82e+05    -  1.26e-01 1.70e-02f  1
#  158  3.5697229e+07 4.63e+03 1.17e+05  -1.0 2.77e+05    -  1.98e-01 1.97e-02f  1
#  159  3.2597514e+07 4.42e+03 1.12e+05  -1.0 2.72e+05    -  4.69e-03 4.48e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  3.0240618e+07 4.26e+03 1.08e+05  -1.0 2.61e+05    -  6.25e-02 3.71e-02f  1
#  161  2.6924555e+07 4.01e+03 1.02e+05  -1.0 2.51e+05    -  1.55e-02 5.68e-02f  1
#  162  2.6936946e+07 4.01e+03 1.02e+05  -1.0 8.31e+02   3.5 3.45e-03 5.46e-05h  1
#  163  2.7056193e+07 4.01e+03 1.02e+05  -1.0 8.35e+02   3.1 3.83e-03 5.30e-04h  1
#  164  2.7148054e+07 4.01e+03 1.04e+06  -1.0 8.39e+02   2.6 2.45e-01 4.16e-04h  1
#  165  2.7683337e+07 4.00e+03 1.05e+06  -1.0 8.33e+02   2.1 1.35e-02 2.47e-03h  1
#  166  2.9237572e+07 3.97e+03 1.06e+06  -1.0 7.85e+02   1.6 2.59e-01 7.12e-03h  1
#  167  2.9490473e+07 3.97e+03 1.22e+06  -1.0 6.52e+02   1.2 3.07e-01 1.15e-03h  1
#  168  3.0228934e+07 3.95e+03 1.67e+06  -1.0 7.70e+02   1.6 3.93e-01 3.30e-03h  1
#  169  3.0277077e+07 3.95e+03 2.39e+08  -1.0 8.59e+03   2.0 3.56e-01 1.90e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  3.1070769e+07 3.95e+03 1.91e+09  -1.0 1.12e+05   1.5 8.85e-02 1.27e-03h  1
#  171  3.2106446e+07 3.95e+03 3.85e+09  -1.0 1.77e+05   2.0 2.09e-02 5.38e-04h  1
#  172  3.2745776e+07 3.94e+03 4.57e+09  -1.0 1.97e+05   1.5 1.91e-02 5.40e-04h  1
#  173  3.4352558e+07 3.94e+03 6.39e+09  -1.0 1.95e+05   1.9 1.54e-02 5.21e-04h  1
#  174  3.4876336e+07 3.94e+03 6.69e+09  -1.0 2.12e+05   1.4 7.47e-03 2.98e-04h  1
#  175  3.5044157e+07 3.94e+03 8.73e+09  -1.0 2.07e+05   1.8 1.56e-02 4.01e-05h  1
#  176  3.7098213e+07 3.94e+03 9.76e+09  -1.0 2.17e+05   1.4 2.79e-02 1.13e-03h  1
#  177  3.7156947e+07 3.94e+03 1.18e+10  -1.0 2.14e+05   1.8 1.81e-02 1.13e-05h  1
#  178  3.7332528e+07 3.94e+03 1.19e+10  -1.0 2.17e+05   1.3 1.99e-03 9.40e-05h  1
#  179  4.1628201e+07 3.93e+03 1.20e+10  -1.0 2.15e+05   1.7 2.07e-03 8.32e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  6.2835199e+07 3.93e+03 1.35e+10  -1.0 2.10e+05   2.2 6.28e-03 1.15e-03h  1
#  181  7.1787718e+07 3.93e+03 1.38e+10  -1.0 2.04e+05   1.7 3.81e-03 1.59e-04h  1
#  182  8.2678523e+07 3.93e+03 1.47e+10  -1.0 2.04e+05   2.1 4.16e-03 2.22e-04h  1
#  183  1.0258972e+08 3.93e+03 1.48e+10  -1.0 2.09e+05   1.6 2.64e-03 5.13e-04h  1
#  184  1.0693270e+08 3.92e+03 1.54e+10  -1.0 2.06e+05   2.1 2.69e-03 1.00e-04h  1
#  185  1.1221720e+08 3.92e+03 1.77e+10  -1.0 2.02e+05   2.5 4.14e-03 1.26e-04h  1
#  186  1.2440317e+08 3.92e+03 1.79e+10  -1.0 2.04e+05   2.0 1.34e-03 2.01e-04h  1
#  187  1.3064053e+08 3.92e+03 1.93e+10  -1.0 2.04e+05   2.4 2.83e-03 1.51e-04h  1
#  188  1.3245789e+08 3.92e+03 2.54e+10  -1.0 2.00e+05   2.9 4.44e-03 5.57e-05h  1
#  189  1.4248232e+08 3.92e+03 2.62e+10  -1.0 2.05e+05   2.4 1.98e-03 2.07e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190  1.4920706e+08 3.92e+03 3.05e+10  -1.0 2.04e+05   2.8 3.64e-03 1.95e-04h  1
#  191  1.5014345e+08 3.92e+03 4.92e+10  -1.0 1.98e+05   3.2 5.69e-03 4.16e-05h  1
#  192  1.5969334e+08 3.92e+03 5.18e+10  -1.0 2.07e+05   2.8 2.55e-03 2.33e-04h  1
#  193  1.6422499e+08 3.92e+03 5.99e+10  -1.0 2.04e+05   3.2 2.90e-03 1.72e-04h  1
#  194  1.6757934e+08 3.92e+03 5.91e+10  -1.0 1.94e+05   3.6 1.16e-05 1.17e-04h  1
#  195  1.6854348e+08 3.92e+03 5.90e+10  -1.0 2.03e+05   3.1 4.06e-06 2.41e-05h  1
#  196  1.6881728e+08 3.92e+03 5.92e+10  -1.0 1.98e+05   3.6 3.32e-05 1.34e-05h  1
#  197  1.7660278e+08 3.92e+03 6.03e+10  -1.0 2.48e+05   3.1 6.05e-04 8.70e-05h  1
#  198  1.8002324e+08 3.92e+03 6.05e+10  -1.0 1.96e+05   3.5 1.19e-04 8.28e-05h  1
#  199r 1.8002324e+08 3.92e+03 1.00e+03   3.6 0.00e+00   3.9 0.00e+00 2.64e-07R  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200r 1.8039432e+08 3.49e+03 1.02e+03   3.6 7.03e+07    -  4.68e-04 1.80e-04f  1
#  201  1.8034356e+08 3.49e+03 2.03e+05  -1.0 2.20e+05    -  1.20e-05 1.52e-04f  1
#  202  1.7964029e+08 3.49e+03 2.02e+05  -1.0 2.21e+05    -  1.06e-04 1.98e-03f  1
#  203  1.7952928e+08 3.49e+03 2.02e+05  -1.0 2.21e+05    -  1.75e-03 3.10e-04f  1
#  204  1.7851280e+08 3.48e+03 2.02e+05  -1.0 2.21e+05    -  2.45e-03 2.85e-03f  1
#  205  1.7672214e+08 3.46e+03 2.01e+05  -1.0 2.21e+05    -  5.78e-03 5.05e-03f  1
#  206  1.7605790e+08 3.45e+03 2.00e+05  -1.0 2.20e+05    -  1.37e-02 1.89e-03f  1
#  207  1.7466198e+08 3.44e+03 2.00e+05  -1.0 2.19e+05    -  2.05e-02 3.99e-03f  1
#  208  1.7039320e+08 3.40e+03 1.97e+05  -1.0 2.19e+05    -  3.13e-02 1.23e-02f  1
#  209  1.6695674e+08 3.36e+03 1.95e+05  -1.0 2.16e+05    -  3.84e-02 1.02e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210  1.6108577e+08 3.30e+03 1.92e+05  -1.0 2.14e+05    -  3.53e-02 1.78e-02f  1
#  211  1.6100878e+08 3.30e+03 1.92e+05  -1.0 2.10e+05    -  2.09e-03 2.40e-04f  1
#  212  1.5536682e+08 3.24e+03 1.88e+05  -1.0 2.10e+05    -  1.22e-02 1.77e-02f  1
#  213  1.5327421e+08 3.22e+03 1.87e+05  -1.0 2.07e+05    -  7.58e-03 6.77e-03f  1
#  214  1.4974273e+08 3.18e+03 1.85e+05  -1.0 2.05e+05    -  9.36e-05 1.16e-02f  1
#  215  1.4921456e+08 3.18e+03 1.84e+05  -1.0 2.03e+05    -  5.70e-03 1.77e-03f  1
#  216  1.4911606e+08 3.18e+03 1.84e+05  -1.0 2.03e+05    -  3.34e-04 3.31e-04f  1
#  217  1.4766395e+08 3.16e+03 1.83e+05  -1.0 2.05e+05    -  1.89e-05 4.89e-03f  1
#  218  1.4755573e+08 3.16e+03 1.83e+05  -1.0 2.04e+05    -  4.51e-03 3.67e-04f  1
#  219  1.4499406e+08 3.13e+03 1.82e+05  -1.0 2.04e+05    -  2.52e-04 8.74e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220  1.4150286e+08 3.09e+03 1.80e+05  -1.0 2.03e+05    -  8.33e-02 1.21e-02f  1
#  221  1.3628944e+08 3.04e+03 1.76e+05  -1.0 2.01e+05    -  4.50e-02 1.86e-02f  1
#  222  1.3140171e+08 2.98e+03 1.73e+05  -1.0 1.97e+05    -  2.99e-02 1.81e-02f  1
#  223  1.2888438e+08 2.95e+03 1.71e+05  -1.0 1.94e+05    -  1.52e-02 9.64e-03f  1
#  224  1.2528108e+08 2.91e+03 1.69e+05  -1.0 1.92e+05    -  6.46e-04 1.41e-02f  1
#  225  1.2516678e+08 2.91e+03 1.69e+05  -1.0 1.90e+05    -  3.72e-02 4.57e-04f  1
#  226  1.2507628e+08 2.91e+03 1.69e+05  -1.0 1.90e+05    -  2.21e-02 3.62e-04f  1
#  227  1.1520994e+08 2.79e+03 1.62e+05  -1.0 1.90e+05    -  1.85e-02 4.03e-02f  1
#  228  1.1432593e+08 2.78e+03 1.61e+05  -1.0 1.83e+05    -  8.15e-03 3.85e-03f  1
#  229  1.1432848e+08 2.78e+03 9.60e+06  -1.0 6.24e+02   3.5 1.28e-01 2.00e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230  1.1449843e+08 2.78e+03 1.21e+07  -1.0 6.27e+02   3.0 1.27e-01 1.78e-03h  1
#  231  1.1485197e+08 2.75e+03 1.20e+07  -1.0 6.28e+02   2.5 1.10e-01 7.47e-03h  1
#  232  1.1485235e+08 2.74e+03 1.05e+07  -1.0 6.14e+02   2.0 2.56e-01 4.75e-03h  1
#  233  1.1504027e+08 2.73e+03 1.13e+07  -1.0 6.22e+02   2.5 2.59e-01 3.84e-03h  1
#  234  1.1504034e+08 2.73e+03 1.07e+07  -1.0 2.83e+03   2.0 1.18e-01 3.50e-04h  1
#  235  1.1528597e+08 2.73e+03 1.06e+07  -1.0 6.30e+03   2.4 1.05e-02 1.06e-03h  1
#  236  1.1661339e+08 2.72e+03 2.93e+07  -1.0 2.76e+04   1.9 6.64e-03 1.11e-03h  1
#  237  1.1790110e+08 2.72e+03 6.65e+07  -1.0 4.17e+04   2.4 2.25e-03 2.90e-04h  1
#  238  1.1822600e+08 2.72e+03 8.89e+07  -1.0 5.07e+04   1.9 2.08e-03 1.15e-04h  1
#  239  1.2165757e+08 2.72e+03 9.80e+07  -1.0 5.10e+04   2.3 8.96e-04 5.84e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240  1.2215795e+08 2.72e+03 1.16e+08  -1.0 5.68e+04   1.8 1.48e-03 1.47e-04h  1
#  241  1.2377220e+08 2.72e+03 1.64e+08  -1.0 5.67e+04   2.3 1.63e-03 2.33e-04h  1
#  242  1.2396476e+08 2.72e+03 3.99e+08  -1.0 5.41e+04   2.7 2.51e-03 1.67e-05h  1
#  243  1.3325652e+08 2.72e+03 3.07e+08  -1.0 5.41e+04   3.1 2.21e-04 5.82e-04h  1
#  244  1.3428687e+08 2.72e+03 2.90e+08  -1.0 3.59e+04   4.4 7.09e-05 7.66e-05h  1
#  245  1.3500956e+08 2.72e+03 3.22e+08  -1.0 3.53e+04   4.9 5.74e-05 5.30e-05h  1
#  246  1.3556683e+08 2.72e+03 4.44e+08  -1.0 3.81e+04   5.3 1.11e-06 3.74e-05h  1
#  247  1.3681160e+08 2.72e+03 8.49e+08  -1.0 5.04e+04   4.8 2.34e-05 5.96e-05h  1
#  248  1.3720713e+08 2.72e+03 8.75e+08  -1.0 5.21e+04   5.2 1.71e-05 1.80e-05h  1
#  249r 1.3720713e+08 2.72e+03 1.00e+03   3.4 0.00e+00   5.7 0.00e+00 2.62e-07R  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250r 1.3087925e+08 2.54e+03 1.03e+03   3.4 1.70e+07    -  4.35e-04 1.31e-04f  1
#  251r 9.8296573e+07 9.47e+02 1.03e+03   3.4 9.34e+06    -  3.52e-04 1.34e-03f  1
#  252  9.8249519e+07 9.47e+02 1.44e+05  -1.0 1.71e+05    -  4.52e-04 2.42e-04f  1
#  253  9.7918429e+07 9.46e+02 1.43e+05  -1.0 1.76e+05    -  7.37e-04 1.69e-03f  1
#  254  9.7750365e+07 9.45e+02 1.43e+05  -1.0 1.76e+05    -  3.29e-03 8.61e-04f  1
#  255  9.7431714e+07 9.43e+02 1.43e+05  -1.0 1.76e+05    -  9.86e-04 1.64e-03f  1
#  256  9.7179905e+07 9.42e+02 1.43e+05  -1.0 1.75e+05    -  1.92e-03 1.30e-03f  1
#  257r 9.7179905e+07 9.42e+02 9.99e+02   2.7 0.00e+00   5.2 0.00e+00 3.33e-08R  2
#  258r 8.6017444e+07 8.03e+02 9.99e+02   2.7 2.98e+06    -  7.32e-04 2.70e-04f  1
#  259r 8.4901614e+07 6.17e+02 9.98e+02   2.7 1.07e+06    -  5.09e-03 1.21e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260r 8.0128461e+07 6.25e+02 9.91e+02   2.7 2.36e+05    -  1.90e-02 6.70e-03f  1
#  261r 6.8073619e+07 6.19e+02 9.70e+02   2.7 1.18e+05    -  4.75e-02 2.15e-02f  1
#  262r 6.8219728e+07 6.24e+02 9.44e+02   2.7 2.01e+02   0.0 1.76e-01 4.29e-02f  1
#  263r 6.7421003e+07 6.37e+02 8.70e+02   2.7 2.67e+02  -0.5 3.17e-01 8.59e-02f  1
#  264r 6.8058246e+07 6.56e+02 6.73e+02   2.7 1.68e+02  -1.0 2.00e-01 2.26e-01f  1
#  265r 7.5832476e+07 6.67e+02 5.79e+02   2.7 7.03e+01  -0.5 9.11e-01 3.13e-01f  1
#  266r 7.4452575e+07 6.70e+02 3.81e+02   2.0 1.59e+01  -0.1 9.46e-01 5.81e-01f  1
#  267r 7.2596319e+07 6.70e+02 3.72e+02   1.3 5.44e+01  -0.6 4.47e-01 3.28e-01f  1
#  268r 7.2008494e+07 6.70e+02 2.94e+02   0.6 1.55e+01  -0.2 5.66e-01 1.94e-01f  1
#  269r 7.1836377e+07 6.70e+02 1.98e+02   0.6 5.91e+01  -0.6 3.59e-01 3.31e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270r 7.1742297e+07 6.70e+02 4.00e+02   0.6 1.59e+01  -0.2 6.38e-01 4.29e-02f  1
#  271r 7.0209693e+07 6.70e+02 4.03e+02   0.6 4.48e+01  -0.7 6.71e-01 4.05e-01f  1
#  272r 6.7869869e+07 6.70e+02 1.81e+02   0.6 1.70e+01  -0.3 9.54e-02 6.27e-01f  1
#  273r 6.7112760e+07 6.70e+02 3.88e+02  -0.0 4.31e+01  -0.7 6.06e-01 1.96e-01f  1
#  274r 6.6937322e+07 6.70e+02 9.16e+01  -0.0 1.64e+01  -0.3 1.40e-01 5.55e-01f  1
#  275r 6.6785499e+07 6.70e+02 8.19e+01  -0.0 6.67e+00   0.1 7.90e-01 4.30e-01f  1
#  276r 6.6714664e+07 6.70e+02 7.26e+01  -0.0 2.23e+01  -0.4 3.36e-01 2.67e-01f  1
#  277r 6.6613889e+07 6.70e+02 1.70e+02  -0.0 8.15e+00   0.1 1.00e+00 2.93e-01f  1
#  278r 6.6527182e+07 6.70e+02 1.61e+02  -0.0 2.66e+01  -0.4 5.52e-01 1.99e-01f  1
#  279r 6.6415455e+07 6.70e+02 1.68e+02  -0.0 9.96e+00   0.0 1.00e+00 2.85e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280r 6.6390121e+07 6.70e+02 1.81e+02  -0.0 3.08e+01  -0.5 7.19e-01 1.72e-01f  1
#  281r 6.6319782e+07 6.70e+02 1.43e+02  -0.0 1.16e+01  -0.0 1.00e+00 2.96e-01f  1
#  282r 6.6341816e+07 6.70e+02 4.83e+02  -0.0 3.01e+01  -0.5 1.00e+00 9.96e-02f  1
#  283r 6.6270723e+07 6.70e+02 1.22e+02  -0.0 1.23e+01  -0.1 2.89e-01 5.14e-01f  1
#  284r 6.6339293e+07 6.70e+02 1.36e+02  -0.0 2.63e+01  -0.6 1.08e-02 1.31e-01f  1
#  285r 6.6355724e+07 6.70e+02 1.21e+02  -0.0 1.16e+01  -0.1 1.00e+00 1.81e-01f  1
#  286r 6.6409656e+07 6.70e+02 1.14e+02  -0.0 2.78e+01  -0.6 1.90e-01 8.62e-02f  1
#  287r 6.6433293e+07 6.70e+02 4.31e+02  -0.0 1.33e+01  -0.2 5.03e-01 2.79e-01f  1
#  288r 6.6525415e+07 6.70e+02 3.10e+02  -0.0 3.49e+01  -0.7 1.42e-02 1.31e-01f  1
#  289r 6.6555532e+07 6.70e+02 2.39e+02  -0.0 1.17e+01  -0.2 1.00e+00 1.57e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290r 6.6678045e+07 6.70e+02 1.97e+02  -0.0 3.30e+01  -0.7 1.16e-01 1.46e-01f  1
#  291r 6.6712685e+07 6.70e+02 1.65e+02  -0.0 1.27e+01  -0.3 1.00e+00 1.42e-01f  1
#  292r 6.6851155e+07 6.70e+02 7.29e+02  -0.0 4.26e+01  -0.8 6.16e-01 1.51e-01f  1
#  293r 6.6923698e+07 6.70e+02 5.08e+02  -0.0 1.27e+01  -0.3 4.11e-02 2.48e-01f  1
#  294r 6.7039113e+07 6.70e+02 4.39e+02  -0.0 3.73e+01  -0.8 1.00e+00 9.51e-02f  1
#  295r 6.7171109e+07 6.70e+02 2.93e+02  -0.0 1.40e+01  -0.4 3.20e-01 3.31e-01f  1
#  296r 6.7340349e+07 6.70e+02 2.57e+02  -0.0 4.19e+01  -0.9 6.69e-01 1.15e-01f  1
#  297r 6.7485456e+07 6.70e+02 1.89e+02  -0.0 1.60e+01  -0.4 1.00e+00 2.73e-01f  1
#  298r 6.7711932e+07 6.70e+02 2.32e+02  -0.0 4.71e+01  -0.9 5.78e-01 1.28e-01f  1
#  299r 6.7835451e+07 6.70e+02 1.56e+02  -0.0 1.80e+01  -0.5 1.00e+00 1.87e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300r 6.7897248e+07 6.70e+02 2.76e+02  -0.0 8.28e+01  -1.0 3.58e-01 2.67e-02f  1
#  301r 6.8127854e+07 6.70e+02 4.43e+02  -0.0 4.11e+01  -0.5 1.00e+00 2.45e-01f  1
#  302r 6.8292880e+07 6.70e+02 4.50e+02  -0.0 1.12e+02  -1.0 2.70e-01 5.81e-02f  1
#  303r 6.8422877e+07 6.70e+02 5.13e+02  -0.0 5.62e+01  -0.6 2.62e-01 1.42e-01f  1
#  304r 6.9168171e+07 6.69e+02 2.69e+02  -0.0 1.49e+02  -1.1 4.28e-03 2.54e-01f  1
#  305r 6.9177045e+07 6.69e+02 6.91e+02  -0.0 3.77e+01  -0.6 1.00e+00 7.57e-03f  1
#  306r 6.9437727e+07 6.69e+02 8.12e+02  -0.0 6.27e+01  -1.1 3.91e-01 1.17e-01f  1
#  307r 6.9649314e+07 6.69e+02 5.93e+02  -0.0 2.36e+01  -0.7 7.74e-01 2.58e-01f  1
#  308r 7.0077603e+07 6.69e+02 4.96e+02  -0.0 6.46e+01  -1.2 1.00e+00 1.86e-01f  1
#  309r 7.0690521e+07 6.69e+02 1.52e+02  -0.0 1.51e+01  -0.8 1.00e+00 7.17e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  310r 7.1633524e+07 6.69e+02 1.39e+02  -0.0 4.23e+01  -1.2 7.17e-01 3.89e-01f  1
#  311r 7.2059275e+07 6.69e+02 7.85e+01  -0.0 1.57e+01  -0.8 1.00e+00 4.78e-01f  1
#  312r 7.3070886e+07 6.69e+02 9.88e+01  -0.0 4.71e+01  -1.3 8.02e-01 3.80e-01f  1
#  313r 7.3841847e+07 6.69e+02 8.75e+01  -0.0 1.41e+02  -1.8 6.98e-02 9.36e-02f  1
#  314r 7.4624104e+07 6.69e+02 2.28e+02  -0.0 5.29e+01  -1.3 1.00e+00 2.60e-01f  1
#  315r 7.6078108e+07 6.69e+02 2.49e+02  -0.0 1.58e+02  -1.8 2.68e-01 1.52e-01f  1
#  316r 7.7203346e+07 6.69e+02 3.04e+02  -0.0 5.92e+01  -1.4 1.00e+00 3.24e-01f  1
#  317r 7.7900858e+07 6.69e+02 9.80e+01  -0.0 2.21e+01  -1.0 1.00e+00 5.39e-01f  1
#  318r 8.0186844e+07 6.68e+02 4.20e+02  -0.0 6.64e+01  -1.4 2.37e-01 5.54e-01f  1
#  319r 8.0849331e+07 6.68e+02 1.72e+02  -0.0 2.49e+01  -1.0 8.50e-01 4.45e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  320r 8.2493842e+07 6.68e+02 9.05e+01  -0.0 7.36e+01  -1.5 3.31e-01 3.52e-01f  1
#  321r 8.3610570e+07 6.68e+02 7.68e+01  -0.0 1.94e+01  -1.1 4.54e-01 6.38e-01f  1
#  322r 8.5086771e+07 6.68e+02 6.67e+01  -0.0 5.90e+01  -1.5 3.00e-01 2.71e-01f  1
#  323r 8.8865807e+07 6.68e+02 5.67e+01  -0.0 1.74e+02  -2.0 9.33e-02 2.10e-01f  1
#  324r 9.1027905e+07 6.68e+02 6.63e+01  -0.0 6.55e+01  -1.6 6.02e-01 3.30e-01f  1
#  325r 9.3320330e+07 6.68e+02 6.08e+00  -0.0 2.46e+01  -1.2 1.00e+00 9.53e-01f  1
#  326r 9.4759379e+07 6.68e+02 1.14e+01  -1.4 7.28e+01  -1.6 1.83e-01 2.15e-01f  1
#  327r 9.5063721e+07 6.68e+02 1.11e+01  -1.4 2.73e+01  -1.2 1.55e-01 9.02e-02f  1
#  328r 9.5415296e+07 6.68e+02 3.50e+01  -1.4 2.53e+02  -1.7 1.46e-02 3.33e-02f  1
#  329r 9.6399137e+07 6.68e+02 6.24e+01  -1.4 3.07e+01  -1.3 4.75e-01 2.62e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  330r 9.6525183e+07 6.68e+02 1.90e+02  -1.4 1.14e+01  -0.8 9.44e-01 1.04e-01f  1
#  331r 9.7325836e+07 6.68e+02 1.46e+02  -1.4 4.28e+01  -1.3 1.39e-01 2.17e-01f  1
#  332r 9.7500634e+07 6.68e+02 2.15e+02  -1.4 1.34e+01  -0.9 9.69e-01 1.41e-01f  1
#  333r 9.7617878e+07 6.68e+02 2.06e+02  -1.4 3.86e+01  -1.4 1.83e-02 2.83e-02f  1
#  334r 9.8265494e+07 6.68e+02 1.53e+02  -1.4 1.58e+01  -0.9 9.66e-01 4.59e-01f  1
#  335r 9.8296503e+07 6.68e+02 1.66e+02  -1.4 9.49e+01  -1.4 1.54e-02 5.93e-03f  1
#  336r 9.9094589e+07 6.68e+02 4.79e+01  -1.4 2.36e+01  -1.0 1.49e-01 4.54e-01f  1
#  337r 9.9230937e+07 6.68e+02 1.10e+02  -1.4 1.05e+01  -0.6 6.22e-01 2.11e-01f  1
#  338r 9.9563394e+07 6.68e+02 9.90e+01  -1.4 6.49e+01  -1.0 3.61e-02 1.42e-01f  1
#  339r 9.9566921e+07 6.68e+02 5.04e+01  -1.4 2.13e+01  -0.6 7.30e-02 4.46e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  340r 9.9582556e+07 6.68e+02 5.03e+01  -1.4 3.34e+02  -1.1 8.35e-04 3.18e-03f  1
#  341r 1.0003271e+08 6.68e+02 6.96e+01  -1.4 1.25e+01  -0.7 4.05e-01 5.11e-01f  1
#  342r 1.0019221e+08 6.68e+02 1.38e+02  -1.4 5.26e+00  -0.2 1.41e-01 4.99e-01f  1
#  343r 1.0030901e+08 6.68e+02 6.52e+00  -1.4 2.02e+00   0.2 1.00e+00 1.00e+00f  1
#  344r 1.0050875e+08 6.68e+02 9.24e+01  -1.4 1.15e+01  -0.3 2.66e-01 4.81e-01f  1
#  345r 1.0053203e+08 6.68e+02 9.58e+01  -1.4 4.51e+00   0.1 1.00e+00 1.72e-01f  1
#  346r 1.0056264e+08 6.68e+02 1.77e+02  -1.4 2.98e+01  -0.3 1.73e-01 6.48e-02f  1
#  347r 1.0056519e+08 6.68e+02 2.24e+02  -1.4 3.70e+01  -0.8 1.08e-01 1.81e-03f  1
#  348r 1.0058575e+08 6.68e+02 2.08e+02  -1.4 8.32e+02  -1.3 1.49e-03 2.50e-03f  1
#  349r 1.0059658e+08 6.68e+02 5.01e+02  -1.4 3.14e+00   0.0 1.00e+00 6.62e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  350r 1.0098289e+08 6.68e+02 2.86e+02  -1.4 8.01e+00  -0.4 5.87e-01 7.52e-01f  1
#  351r 1.0144761e+08 6.68e+02 8.42e+02  -1.4 1.74e+01  -0.9 2.54e-03 2.84e-01f  1
#  352r 1.0145015e+08 6.68e+02 8.41e+02  -1.4 2.17e+02  -1.4 9.54e-03 4.01e-04f  1
#  353r 1.0153628e+08 6.68e+02 8.04e+02  -1.4 2.63e+01  -1.0 8.70e-02 4.42e-02f  1
#  354r 1.0154640e+08 6.68e+02 8.03e+02  -1.4 4.72e+01  -1.4 9.05e-02 1.68e-03f  1
#  355r 1.0183461e+08 6.68e+02 6.93e+02  -1.4 1.77e+01  -1.0 1.54e-01 1.38e-01f  1
#  356r 1.0207398e+08 6.68e+02 6.69e+02  -1.4 5.31e+01  -1.5 1.23e-03 3.46e-02f  1
#  357r 1.0208258e+08 6.68e+02 6.66e+02  -1.4 2.34e+01  -1.1 1.93e-01 3.46e-03f  1
#  358r 1.0219598e+08 6.68e+02 6.56e+02  -1.4 5.97e+01  -1.6 3.22e-03 1.42e-02f  1
#  359r 1.0221133e+08 6.68e+02 6.53e+02  -1.4 2.24e+01  -1.1 1.34e-02 5.58e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  360r 1.0237007e+08 6.68e+02 6.41e+02  -1.4 6.72e+01  -1.6 4.83e-02 1.77e-02f  1
#  361r 1.0258419e+08 6.68e+02 5.97e+02  -1.4 2.52e+01  -1.2 2.11e-01 6.99e-02f  1
#  362r 1.0352509e+08 6.68e+02 5.44e+02  -1.4 8.21e+01  -1.7 8.14e-02 8.89e-02f  1
#  363r 1.0422158e+08 6.68e+02 4.39e+02  -1.4 2.83e+01  -1.2 9.35e-02 1.93e-01f  1
#  364r 1.0448234e+08 6.68e+02 4.30e+02  -1.4 1.12e+02  -1.7 8.46e-04 1.94e-02f  1
#  365r 1.0449307e+08 6.68e+02 4.29e+02  -1.4 3.19e+01  -1.3 9.65e-02 2.55e-03f  1
#  366r 1.0531298e+08 6.68e+02 4.14e+02  -1.4 1.20e+01  -0.9 8.92e-02 5.46e-01f  1
#  367r 1.0551062e+08 6.68e+02 1.87e+02  -1.4 3.59e+01  -1.3 1.38e-01 4.06e-02f  1
#  368r 1.0572983e+08 6.68e+02 2.63e+02  -1.4 1.35e+01  -0.9 3.17e-02 1.26e-01f  1
#  369r 1.0575801e+08 6.68e+02 2.24e+02  -1.4 4.04e+01  -1.4 3.59e-02 5.05e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  370r 1.0586584e+08 6.68e+02 2.11e+02  -1.4 1.51e+01  -1.0 3.18e-02 5.40e-02f  1
#  371r 1.0589949e+08 6.68e+02 2.12e+02  -1.4 1.26e+02  -1.4 1.11e-03 4.78e-03f  1
#  372r 1.0591761e+08 6.68e+02 2.10e+02  -1.4 1.70e+01  -1.0 2.40e-02 8.00e-03f  1
#  373r 1.0597073e+08 6.68e+02 1.97e+02  -1.4 6.39e+00  -0.6 5.14e-01 6.45e-02f  1
#  374r 1.0610584e+08 6.68e+02 6.76e+02  -1.4 1.92e+01  -1.1 8.83e-01 5.28e-02f  1
#  375r 1.0662521e+08 6.68e+02 6.46e+02  -1.4 5.75e+01  -1.5 1.52e-01 6.12e-02f  1
#  376r 1.0838327e+08 6.68e+02 3.05e+02  -1.4 2.16e+01  -1.1 1.00e+00 5.86e-01f  1
#  377r 1.0841523e+08 6.68e+02 3.00e+02  -1.4 6.46e+01  -1.6 1.79e-01 3.34e-03f  1
#  378r 1.1108847e+08 6.68e+02 8.75e+01  -1.4 2.42e+01  -1.2 1.00e+00 7.85e-01f  1
#  379r 1.1196673e+08 6.68e+02 2.05e+02  -1.4 7.27e+01  -1.6 2.74e-01 8.32e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  380r 1.1374070e+08 6.68e+02 1.46e+02  -1.4 2.44e+02  -2.1 2.88e-03 5.11e-02f  1
#  381r 1.1450371e+08 6.68e+02 2.68e+02  -1.4 8.13e+01  -1.7 2.81e-01 6.26e-02f  1
#  382r 1.1570498e+08 6.68e+02 2.09e+02  -1.4 3.05e+01  -1.3 3.69e-01 2.65e-01f  1
#  383r 1.1739724e+08 6.68e+02 7.76e+01  -1.4 1.14e+01  -0.8 4.82e-01 1.00e+00f  1
#  384r 1.1761128e+08 6.68e+02 7.46e+01  -1.4 4.29e+00  -0.4 6.89e-01 3.34e-01f  1
#  385r 1.1786675e+08 6.68e+02 8.17e+01  -1.4 1.29e+01  -0.9 5.52e-01 1.33e-01f  1
#  386r 1.2079916e+08 6.68e+02 9.71e+01  -1.4 3.86e+01  -1.4 1.31e-01 5.03e-01f  1
#  387r 1.2386710e+08 6.68e+02 1.13e+02  -1.4 1.16e+02  -1.8 9.66e-02 1.67e-01f  1
#  388r 1.2453912e+08 6.68e+02 1.22e+02  -1.4 4.34e+01  -1.4 7.53e-03 9.02e-02f  1
#  389r 1.2594470e+08 6.68e+02 1.13e+02  -1.4 1.63e+01  -1.0 2.49e-01 5.18e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  390r 1.2770064e+08 6.68e+02 8.91e+01  -1.4 4.88e+01  -1.5 1.96e-01 1.89e-01f  1
#  391r 1.2772747e+08 6.68e+02 4.24e+01  -1.4 1.68e+01  -1.0 3.93e-01 8.27e-03f  1
#  392r 1.2887626e+08 6.68e+02 9.65e+01  -1.4 4.29e+01  -1.5 3.21e-01 1.05e-01f  1
#  393r 1.2889973e+08 6.68e+02 2.69e+02  -1.4 1.61e+01  -1.1 6.19e-01 7.36e-03f  1
#  394r 1.3124891e+08 6.68e+02 9.56e+01  -1.4 4.83e+01  -1.6 6.40e-02 3.00e-01f  1
#  395r 1.3190606e+08 6.68e+02 4.58e+02  -1.4 1.81e+01  -1.1 8.48e-01 2.51e-01f  1
#  396r 1.3282019e+08 6.68e+02 1.30e+00  -1.4 6.79e+00  -0.7 1.00e+00 1.00e+00f  1
#  397r 1.3363398e+08 6.68e+02 6.25e+00  -2.2 2.03e+01  -1.2 2.83e-01 3.15e-01f  1
#  398r 1.3380967e+08 6.68e+02 5.55e+01  -2.2 7.62e+00  -0.8 1.00e+00 1.86e-01f  1
#  399r 1.3401518e+08 6.68e+02 5.91e+01  -2.2 2.20e+01  -1.2 1.92e-01 7.35e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  400r 1.3414027e+08 6.68e+02 1.91e+02  -2.2 7.08e+00  -0.8 1.00e+00 1.20e-01f  1
#  401r 1.3477413e+08 6.68e+02 1.53e+02  -2.2 2.14e+01  -1.3 1.95e-01 1.99e-01f  1
#  402r 1.3482304e+08 6.68e+02 1.53e+02  -2.2 7.70e+02  -1.8 2.88e-03 1.02e-03f  1
#  403r 1.3524105e+08 6.68e+02 1.36e+02  -2.2 2.40e+01  -1.3 4.58e-01 1.14e-01f  1
#  404r 1.3580045e+08 6.68e+02 1.32e+02  -2.2 9.02e+00  -0.9 8.63e-01 4.13e-01f  1
#  405r 1.3628937e+08 6.68e+02 1.29e+02  -2.2 2.70e+01  -1.4 1.71e-01 1.14e-01f  1
#  406r 1.3732138e+08 6.68e+02 1.06e+02  -2.2 1.01e+01  -1.0 1.00e+00 6.63e-01f  1
#  407r 1.3857305e+08 6.68e+02 8.67e+01  -2.2 3.04e+01  -1.5 6.01e-01 2.47e-01f  1
#  408r 1.4015210e+08 6.68e+02 1.08e+00  -2.2 1.14e+01  -1.0 1.00e+00 1.00e+00f  1
#  409r 1.4021069e+08 6.68e+02 7.41e+01  -2.2 3.40e+01  -1.5 5.19e-01 1.05e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  410r 1.4065056e+08 6.68e+02 6.44e+01  -2.2 1.27e+01  -1.1 1.00e+00 2.33e-01f  1
#  411r 1.4170952e+08 6.68e+02 7.39e+01  -2.2 3.76e+01  -1.6 4.67e-01 1.64e-01f  1
#  412r 1.4237058e+08 6.68e+02 4.57e+01  -2.2 1.41e+01  -1.1 1.00e+00 3.33e-01f  1
#  413r 1.4242109e+08 6.68e+02 1.54e+02  -2.2 4.23e+01  -1.6 8.24e-01 1.03e-02f  1
#  414r 1.4236430e+08 6.68e+02 1.11e+02  -2.2 3.90e+03  -2.1 8.55e-04 4.85e-03f  1
#  415r 1.4239594e+08 6.68e+02 2.40e+02  -2.2 4.75e+01  -1.7 7.93e-01 5.82e-03f  1
#  416r 1.4250453e+08 6.68e+02 7.06e+02  -2.2 1.78e+01  -1.2 1.00e+00 5.30e-02f  1
#  417r 1.4440886e+08 6.68e+02 4.55e+02  -2.2 5.35e+01  -1.7 1.84e-01 2.97e-01f  1
#  418r 1.4543006e+08 6.68e+02 4.25e+02  -2.2 1.60e+02  -2.2 3.22e-02 4.77e-02f  1
#  419r 1.4548343e+08 6.68e+02 4.86e+02  -2.2 6.00e+01  -1.8 1.70e-01 7.29e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  420r 1.4558893e+08 6.68e+02 4.81e+02  -2.2 5.92e+03  -2.2 2.65e-04 4.94e-03f  1
#  421r 1.4578284e+08 6.68e+02 3.98e+02  -2.2 1.15e+01  -0.9 1.08e-01 1.93e-01f  1
#  422r 1.4594177e+08 6.68e+02 1.96e+02  -2.2 8.86e+00  -0.5 5.81e-01 4.08e-01f  1
#  423r 1.4627143e+08 6.68e+02 2.16e+02  -2.2 9.45e+00  -1.0 8.28e-01 2.99e-01f  1
#  424r 1.4731349e+08 6.67e+02 6.53e+01  -2.2 2.83e+01  -1.4 1.01e-01 3.59e-01f  1
#  425r 1.4736491e+08 6.67e+02 7.91e+01  -2.2 8.50e+01  -1.9 3.77e-02 5.66e-03f  1
#  426r 1.4762535e+08 6.67e+02 7.62e+01  -2.2 2.55e+02  -2.4 3.36e-03 8.41e-03f  1
#  427r 1.4910774e+08 6.67e+02 8.50e+01  -2.2 9.56e+01  -2.0 2.50e-01 1.57e-01f  1
#  428r 1.4965061e+08 6.67e+02 8.25e+01  -2.2 2.87e+02  -2.4 1.69e-02 1.98e-02f  1
#  429r 1.5305340e+08 6.67e+02 4.06e+01  -2.2 1.08e+02  -2.0 9.14e-02 3.79e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  430r 1.5324997e+08 6.67e+02 3.59e+01  -2.2 3.22e+02  -2.5 3.28e-02 7.49e-03f  1
#  431r 1.5431195e+08 6.67e+02 3.16e+01  -2.2 1.21e+02  -2.1 1.24e-01 1.30e-01f  1
#  432r 1.5473075e+08 6.67e+02 8.44e+01  -2.2 1.06e+03  -2.5 1.62e-02 3.97e-02f  1
#  433r 1.5523703e+08 6.67e+02 8.42e+01  -2.2 1.36e+02  -2.1 3.98e-02 5.22e-02f  1
#  434r 1.5547870e+08 6.67e+02 8.29e+01  -2.2 5.10e+01  -1.7 4.82e-02 9.53e-02f  1
#  435r 1.5569673e+08 6.67e+02 7.29e+01  -2.2 1.53e+02  -2.2 4.82e-02 2.65e-02f  1
#  436r 1.5615967e+08 6.67e+02 6.01e+01  -2.2 5.74e+01  -1.7 1.63e-01 1.50e-01f  1
#  437r 1.5619885e+08 6.67e+02 3.51e+01  -2.2 1.72e+02  -2.2 5.60e-02 4.29e-03f  1
#  438r 1.5670147e+08 6.67e+02 9.72e+01  -2.2 6.46e+01  -1.8 4.16e-01 1.45e-01f  1
#  439r 1.5713878e+08 6.67e+02 9.74e+01  -2.2 1.94e+02  -2.3 4.53e-02 4.13e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  440r 1.5769620e+08 6.67e+02 1.29e+02  -2.2 7.27e+01  -1.8 3.30e-01 1.38e-01f  1
#  441r 1.5796237e+08 6.67e+02 9.58e+01  -2.2 3.00e+02  -2.3 3.41e-03 2.37e-02f  1
#  442r 1.5883551e+08 6.67e+02 2.04e+02  -2.2 8.10e+01  -1.9 6.23e-01 1.87e-01f  1
#  443r 1.5918991e+08 6.67e+02 9.83e+01  -2.2 8.30e+02  -2.4 6.11e-04 5.65e-02f  1
#  444r 1.5921027e+08 6.67e+02 1.44e+02  -2.2 9.97e+01  -1.9 2.38e-01 5.17e-03f  1
#  445r 1.5954107e+08 6.67e+02 2.16e+02  -2.2 3.42e+01  -1.5 1.00e+00 2.21e-01f  1
#  446r 1.6064865e+08 6.67e+02 1.25e+02  -2.2 1.21e+02  -2.0 1.86e-01 2.45e-01f  1
#  447r 1.6065811e+08 6.67e+02 1.80e+02  -2.2 3.85e+01  -1.6 2.94e-01 5.55e-03f  1
#  448r 1.6111511e+08 6.67e+02 1.24e+02  -2.2 2.21e+02  -2.0 2.25e-04 1.01e-01f  1
#  449r 1.6119960e+08 6.67e+02 8.07e+01  -2.2 7.78e+00  -0.7 4.02e-01 3.88e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  450r 1.6138320e+08 6.67e+02 5.69e+01  -2.2 1.91e+01  -1.2 2.61e-01 2.76e-01f  1
#  451r 1.6139217e+08 6.67e+02 9.07e+01  -2.2 6.98e+02  -1.7 6.87e-03 1.96e-02f  1
#  452r 1.6139669e+08 6.67e+02 2.09e+02  -2.2 2.06e+01  -1.2 6.09e-01 9.10e-03f  1
#  453r 1.6185599e+08 6.68e+02 1.65e+02  -2.2 5.47e+01  -1.7 1.48e-02 2.70e-01f  1
#  454r 1.6194629e+08 6.68e+02 1.62e+02  -2.2 1.64e+02  -2.2 4.98e-02 1.66e-02f  1
#  455r 1.6217530e+08 6.68e+02 1.43e+02  -2.2 6.16e+01  -1.8 1.03e-01 1.15e-01f  1
#  456r 1.6243195e+08 6.68e+02 1.01e+02  -2.2 2.31e+01  -1.3 6.22e-01 3.50e-01f  1
#  457r 1.6315360e+08 6.68e+02 7.61e+01  -2.2 6.93e+01  -1.8 3.16e-03 3.04e-01f  1
#  458r 1.6318721e+08 6.68e+02 8.58e+01  -2.2 2.60e+01  -1.4 2.71e-01 3.76e-02f  1
#  459r 1.6321656e+08 6.68e+02 1.60e+02  -2.2 9.74e+00  -1.0 9.05e-01 8.85e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  460r 1.6367753e+08 6.68e+02 9.36e+01  -2.2 2.92e+01  -1.5 1.22e-01 4.48e-01f  1
#  461r 1.6368329e+08 6.68e+02 1.73e+02  -2.2 1.10e+01  -1.0 1.00e+00 1.47e-02f  1
#  462r 1.6393082e+08 6.68e+02 7.78e+01  -2.2 4.89e+01  -1.5 1.66e-02 2.02e-01f  1
#  463r 1.6400753e+08 6.68e+02 2.15e+02  -2.2 1.23e+01  -1.1 8.30e-01 1.58e-01f  1
#  464r 1.6416879e+08 6.68e+02 2.45e+02  -2.2 1.01e+02  -1.6 1.16e-01 8.54e-02f  1
#  465r 1.6417931e+08 6.68e+02 3.92e+02  -2.2 1.39e+01  -1.1 1.00e+00 1.68e-02f  1
#  466r 1.6432874e+08 6.68e+02 3.11e+02  -2.2 1.21e+02  -1.6 2.20e-02 5.07e-02f  1
#  467r 1.6433098e+08 6.68e+02 3.08e+02  -2.2 1.56e+01  -1.2 1.00e+00 3.10e-03f  1
#  468r 1.6434332e+08 6.68e+02 2.32e+02  -2.2 4.68e+01  -1.7 2.56e-01 5.65e-03f  1
#  469r 1.6506624e+08 6.68e+02 5.53e+01  -2.2 1.76e+01  -1.2 1.00e+00 8.45e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  470r 1.6507751e+08 6.68e+02 9.15e+01  -2.2 5.26e+01  -1.7 8.10e-02 5.39e-03f  1
#  471r 1.6532108e+08 6.68e+02 3.12e+01  -2.2 1.97e+01  -1.3 1.43e-01 2.94e-01f  1
#  472r 1.6581326e+08 6.68e+02 8.93e+01  -2.2 5.92e+01  -1.8 4.40e-03 2.56e-01f  1
#  473r 1.6582984e+08 6.68e+02 8.27e+02  -2.2 2.21e+01  -1.3 1.77e-01 2.02e-02f  1
#  474r 1.6591336e+08 6.68e+02 7.91e+02  -2.2 6.66e+01  -1.8 2.82e-01 3.74e-02f  1
#  475r 1.6596159e+08 6.68e+02 7.92e+02  -2.2 2.00e+02  -2.3 1.96e-02 7.88e-03f  1
#  476r 1.6609864e+08 6.68e+02 7.31e+02  -2.2 7.49e+01  -1.9 2.45e-01 5.36e-02f  1
#  477r 1.6633016e+08 6.68e+02 7.13e+02  -2.2 2.24e+02  -2.3 4.21e-02 3.23e-02f  1
#  478r 1.6745040e+08 6.68e+02 4.49e+02  -2.2 8.42e+01  -1.9 2.32e-01 3.76e-01f  1
#  479r 1.6746392e+08 6.68e+02 4.48e+02  -2.2 2.53e+02  -2.4 6.66e-03 1.56e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  480r 1.6748982e+08 6.68e+02 4.45e+02  -2.2 9.52e+01  -2.0 3.31e-02 7.74e-03f  1
#  481r 1.6754481e+08 6.68e+02 4.43e+02  -2.2 2.85e+02  -2.4 2.33e-02 5.64e-03f  1
#  482r 1.6782310e+08 6.68e+02 4.13e+02  -2.2 1.07e+02  -2.0 3.55e-01 7.34e-02f  1
#  483r 1.6787173e+08 6.68e+02 4.11e+02  -2.2 2.85e+02  -2.5 1.57e-03 4.35e-03f  1
#  484r 1.6787252e+08 6.68e+02 5.15e+02  -2.2 7.28e+00  -1.2 1.00e+00 1.37e-03f  1
#  485r 1.6857080e+08 6.68e+02 2.57e+02  -2.2 1.84e+01  -1.6 3.07e-01 4.07e-01f  1
#  486r 1.6901617e+08 6.68e+02 1.83e+02  -2.2 7.02e+00  -1.2 8.90e-01 6.28e-01f  1
#  487r 1.6965627e+08 6.68e+02 1.59e+02  -2.2 4.39e+01  -1.7 2.05e-02 1.47e-01f  1
#  488r 1.6979625e+08 6.68e+02 1.77e+02  -2.2 8.10e+00  -1.3 1.00e+00 1.34e-01f  1
#  489r 1.7008884e+08 6.68e+02 3.08e+02  -2.2 1.29e+02  -1.7 6.39e-02 2.65e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  490r 1.7009237e+08 6.68e+02 3.08e+02  -2.2 9.22e+00  -1.3 4.44e-01 5.59e-03f  1
#  491r 1.7015263e+08 6.68e+02 6.90e+01  -2.2 3.46e+00  -0.9 1.00e+00 5.75e-01f  1
#  492r 1.7021520e+08 6.68e+02 1.60e+02  -2.2 1.03e+01  -1.4 6.55e-01 1.85e-01f  1
#  493r 1.7030830e+08 6.68e+02 4.35e+01  -2.2 3.89e+00  -0.9 1.00e+00 7.27e-01f  1
#  494r 1.7040426e+08 6.68e+02 1.00e+02  -2.2 1.14e+01  -1.4 1.00e+00 2.38e-01f  1
#  495r 1.7043491e+08 6.68e+02 1.43e+02  -2.2 3.13e+01  -1.9 1.77e-01 2.47e-02f  1
#  496r 1.7062370e+08 6.68e+02 1.09e+02  -2.2 8.75e+01  -2.4 4.12e-03 4.58e-02f  1
#  497r 1.7098563e+08 6.68e+02 7.44e+01  -2.2 3.49e+01  -1.9 2.28e-01 2.51e-01f  1
#  498r 1.7114960e+08 6.68e+02 9.73e+01  -2.2 9.86e+01  -2.4 6.92e-02 3.33e-02f  1
#  499r 1.7129850e+08 6.68e+02 9.35e+01  -2.2 8.38e+02  -2.9 2.34e-03 7.21e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  500r 1.7140948e+08 6.68e+02 9.05e+01  -2.2 1.34e+02  -2.5 1.77e-02 1.94e-02f  1
#  501r 1.7145823e+08 6.68e+02 1.33e+02  -2.2 4.37e+01  -2.0 1.47e-01 2.59e-02f  1
#  502r 1.7151717e+08 6.68e+02 1.27e+02  -2.2 1.23e+02  -2.5 4.07e-04 9.10e-03f  1
#  503r 1.7177362e+08 6.68e+02 5.24e+00  -2.2 6.47e+00  -1.2 9.37e-01 9.69e-01f  1
#  504r 1.7207446e+08 6.68e+02 3.82e+01  -2.2 1.89e+01  -1.7 2.67e-02 3.77e-01f  1
#  505r 1.7211341e+08 6.68e+02 4.83e+01  -2.2 7.20e+00  -1.2 6.47e-01 1.31e-01f  1
#  506r 1.7221177e+08 6.68e+02 4.22e+01  -2.2 2.72e+01  -1.7 1.13e-01 1.14e-01f  1
#  507r 1.7247633e+08 6.68e+02 3.61e+01  -2.2 8.18e+00  -1.3 2.80e-01 7.84e-01f  1
#  508r 1.7265578e+08 6.68e+02 5.34e+01  -2.2 3.34e+01  -1.8 2.99e-01 1.81e-01f  1
#  509r 1.7290927e+08 6.68e+02 7.32e+01  -2.2 9.33e+00  -1.4 9.73e-03 6.54e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  510r 1.7291034e+08 6.68e+02 1.27e+02  -2.2 4.81e+00  -0.9 1.00e+00 7.31e-03f  1
#  511r 1.7318283e+08 6.68e+02 3.61e+01  -2.2 1.03e+01  -1.4 7.55e-01 6.01e-01f  1
#  512r 1.7319361e+08 6.68e+02 1.37e+02  -2.2 2.97e+01  -1.9 4.58e-01 7.37e-03f  1
#  513r 1.7343686e+08 6.68e+02 1.43e+02  -2.2 8.29e+01  -2.4 7.32e-02 5.09e-02f  1
#  514r 1.7348639e+08 6.68e+02 2.22e+02  -2.2 3.21e+01  -1.9 3.01e-01 3.02e-02f  1
#  515r 1.7487430e+08 6.68e+02 6.86e+01  -2.2 9.01e+01  -2.4 5.03e-02 2.43e-01f  1
#  516r 1.7531019e+08 6.68e+02 8.75e+01  -2.2 3.52e+01  -2.0 3.12e-01 2.12e-01f  1
#  517r 1.7537397e+08 6.68e+02 8.28e+01  -2.2 9.97e+01  -2.5 2.45e-03 9.43e-03f  1
#  518r 1.7549232e+08 6.68e+02 1.34e+02  -2.2 3.90e+01  -2.0 2.21e-01 5.07e-02f  1
#  519r 1.7556309e+08 6.68e+02 1.31e+02  -2.2 1.55e+02  -2.5 7.88e-03 1.00e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  520r 1.7565625e+08 6.68e+02 2.07e+02  -2.2 4.37e+01  -2.1 3.07e-01 3.69e-02f  1
#  521r 1.7596119e+08 6.68e+02 1.98e+02  -2.2 1.27e+02  -2.6 5.35e-02 5.06e-02f  1
#  522r 1.7598387e+08 6.68e+02 2.73e+02  -2.2 4.82e+01  -2.1 3.40e-01 1.22e-02f  1
#  523r 1.7625082e+08 6.68e+02 2.67e+02  -2.2 1.38e+02  -2.6 7.62e-02 5.34e-02f  1
# ...
# 1556  1.1714734e+08 1.06e+01 1.04e+06  -1.0 3.48e+04    -  1.21e-05 3.65e-06f  1
# 1557  1.1714715e+08 1.06e+01 1.04e+06  -1.0 1.21e+04    -  8.61e-06 8.20e-07f  1
# 1558  1.1714709e+08 1.06e+01 1.04e+06  -1.0 1.66e+05    -  6.23e-06 2.75e-07f  1
# 1559  1.1714673e+08 1.06e+01 1.04e+06  -1.0 2.45e+05    -  3.27e-06 1.69e-06f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1560  1.1714596e+08 1.06e+01 1.04e+06  -1.0 1.99e+05    -  3.34e-06 3.59e-06f  1
# 1561  1.1714413e+08 1.06e+01 1.04e+06  -1.0 1.11e+05    -  1.90e-05 8.67e-06f  1
# 1562  1.1713923e+08 1.06e+01 1.04e+06  -1.0 5.19e+04    -  1.56e-05 2.33e-05f  1
# 1563  1.1713704e+08 1.06e+01 1.04e+06  -1.0 8.41e+04    -  3.43e-05 1.07e-05f  1
# 1564  1.1713672e+08 1.06e+01 1.04e+06  -1.0 1.55e+05    -  4.34e-05 1.70e-06f  1
# 1565  1.1713578e+08 1.06e+01 1.04e+06  -1.0 2.46e+05    -  4.54e-05 5.16e-06f  1
# 1566  1.1713559e+08 1.06e+01 1.04e+06  -1.0 1.79e+06    -  5.59e-06 2.19e-06f  1
# 1567  1.1713538e+08 1.06e+01 1.04e+06  -1.0 2.10e+06    -  1.82e-05 2.62e-06f  1
# 1568  1.1713538e+08 1.06e+01 1.04e+06  -1.0 2.41e+06    -  2.05e-05 4.77e-08f  1
# 1569  1.1713432e+08 1.06e+01 1.04e+06  -1.0 2.45e+06    -  3.39e-05 1.66e-05f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1570r 1.1713432e+08 1.06e+01 1.00e+03   0.5 0.00e+00    -  0.00e+00 3.88e-07R  7
# 1571r 1.1713556e+08 1.06e+01 1.23e+03   0.5 6.29e+04    -  3.95e-03 3.24e-05f  1
# 1572r 1.1712679e+08 9.88e+00 1.26e+03   0.5 5.96e+03    -  1.49e-02 4.09e-03f  1
# 1573  1.1712165e+08 9.88e+00 1.08e+06  -1.0 9.22e+03    -  3.13e-05 2.20e-05f  1
# 1574  1.1712119e+08 9.88e+00 1.08e+06  -1.0 4.27e+03    -  9.66e-06 1.96e-06f  1
# 1575  1.1712037e+08 9.88e+00 1.08e+06  -1.0 2.39e+04    -  3.02e-06 3.52e-06f  1
# 1576  1.1712001e+08 9.88e+00 1.08e+06  -1.0 5.86e+04    -  7.45e-06 1.54e-06f  1
# 1577  1.1711938e+08 9.88e+00 1.08e+06  -1.0 1.41e+05    -  2.62e-06 2.79e-06f  1
# 1578  1.1711894e+08 9.88e+00 1.08e+06  -1.0 2.31e+05    -  5.88e-06 1.97e-06f  1
# 1579  1.1711749e+08 9.88e+00 1.08e+06  -1.0 2.81e+05    -  2.59e-05 6.62e-06f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1580  1.1711121e+08 9.88e+00 1.08e+06  -1.0 2.67e+05    -  9.48e-06 2.89e-05f  1
# 1581  1.1710831e+08 9.88e+00 1.08e+06  -1.0 1.12e+05    -  6.64e-05 1.33e-05f  1
# 1582  1.1710292e+08 9.88e+00 1.08e+06  -1.0 2.56e+04    -  1.27e-04 2.49e-05f  1
# 1583  1.1707769e+08 9.88e+00 1.08e+06  -1.0 2.60e+04    -  4.47e-04 1.16e-04f  1
# 1584  1.1705362e+08 9.88e+00 1.08e+06  -1.0 2.78e+04    -  2.88e-04 1.11e-04f  1
# 1585  1.1701392e+08 9.87e+00 1.08e+06  -1.0 2.88e+04    -  6.41e-04 1.83e-04f  1
# 1586  1.1700774e+08 9.87e+00 1.08e+06  -1.0 2.98e+04    -  1.01e-03 2.85e-05f  1
# 1587  1.1697514e+08 9.87e+00 1.08e+06  -1.0 3.00e+04    -  7.99e-04 1.51e-04f  1
# 1588  1.1695129e+08 9.87e+00 1.08e+06  -1.0 3.11e+04    -  9.24e-04 1.10e-04f  1
# 1589  1.1695107e+08 9.87e+00 1.08e+06  -1.0 5.93e+05    -  2.12e-05 1.47e-06f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1590r 1.1695107e+08 9.87e+00 1.00e+03   0.2 0.00e+00    -  0.00e+00 4.16e-07R  4
# 1591r 1.1695115e+08 9.86e+00 1.01e+03   0.2 9.73e+03    -  3.02e-03 1.91e-05f  1
# 1592r 1.1695515e+08 9.60e+00 1.03e+03   0.2 3.75e+03    -  2.25e-02 8.29e-04f  1
# 1593r 1.1699667e+08 7.53e+00 1.04e+03   0.2 3.20e+03    -  3.52e-02 1.14e-02f  1
# 1594r 1.1707809e+08 1.01e+01 9.82e+02   0.2 3.23e+03    -  2.11e-03 3.30e-02f  1
# 1595r 1.1721650e+08 1.27e+01 9.46e+02   0.2 2.93e+03    -  3.62e-02 3.71e-02f  1
# 1596r 1.1736593e+08 1.43e+01 9.06e+02   0.2 2.84e+03    -  3.78e-02 4.28e-02f  1
# 1597r 1.1743392e+08 1.39e+01 9.05e+02   0.2 2.84e+03    -  5.96e-02 2.53e-02f  1
# 1598r 1.1755464e+08 1.45e+01 8.31e+02   0.2 3.11e+03    -  3.74e-02 6.60e-02f  1
# 1599r 1.1754873e+08 1.43e+01 8.00e+02   0.2 3.15e+03    -  7.54e-02 3.26e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1600r 1.1844684e+08 1.14e+01 5.65e+02   0.2 4.48e+01  -2.0 2.66e-01 2.99e-01f  1
# 1601r 1.1841046e+08 7.79e+00 3.85e+02   0.2 7.70e+01  -2.5 6.50e-01 3.56e-01f  1
# 1602r 1.1585516e+08 4.97e+00 2.49e+02   0.2 1.83e+02  -3.0 4.39e-01 3.65e-01f  1
# 1603r 1.1255351e+08 1.28e+00 1.21e+02   0.2 6.99e+01  -2.5 3.73e-01 8.64e-01f  1
# 1604  1.1217160e+08 1.28e+00 4.96e+06  -1.0 1.23e+03    -  1.29e-03 1.70e-03f  1
# 1605  1.1188533e+08 1.28e+00 4.95e+06  -1.0 2.43e+03    -  3.71e-03 1.28e-03f  1
# 1606  1.1174596e+08 1.28e+00 4.95e+06  -1.0 2.92e+03    -  5.33e-03 6.23e-04f  1
# 1607  1.1172555e+08 1.28e+00 4.95e+06  -1.0 3.95e+03    -  2.58e-04 9.14e-05f  1
# 1608  1.1170696e+08 1.28e+00 4.95e+06  -1.0 4.63e+03    -  5.96e-05 8.34e-05f  1
# 1609  1.1169323e+08 1.28e+00 4.95e+06  -1.0 5.84e+03    -  3.38e-05 6.16e-05f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1610  1.1168339e+08 1.28e+00 4.95e+06  -1.0 8.36e+03    -  2.75e-05 4.42e-05f  1
# 1611  1.1167406e+08 1.28e+00 4.95e+06  -1.0 9.23e+03    -  1.99e-05 4.19e-05f  1
# 1612  1.1166643e+08 1.28e+00 4.95e+06  -1.0 1.30e+04    -  1.66e-05 3.43e-05f  1
# 1613  1.1166050e+08 1.28e+00 4.95e+06  -1.0 1.18e+04    -  3.02e-05 2.67e-05f  1
# 1614  1.1165083e+08 1.28e+00 4.95e+06  -1.0 1.04e+04    -  6.47e-06 4.35e-05f  1
# 1615  1.1164804e+08 1.28e+00 4.95e+06  -1.0 2.25e+04    -  2.11e-05 1.26e-05f  1
# 1616  1.1163684e+08 1.28e+00 4.95e+06  -1.0 1.17e+04    -  3.81e-06 5.04e-05f  1
# 1617  1.1163471e+08 1.28e+00 4.95e+06  -1.0 2.37e+04    -  2.73e-05 9.62e-06f  1
# 1618  1.1162054e+08 1.28e+00 4.94e+06  -1.0 1.40e+04    -  2.07e-06 6.38e-05f  1
# 1619  1.1161877e+08 1.28e+00 4.94e+06  -1.0 2.58e+04    -  3.56e-05 7.99e-06f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1620  1.1160009e+08 1.28e+00 4.94e+06  -1.0 1.71e+04    -  1.46e-06 8.42e-05f  1
# 1621  1.1159864e+08 1.28e+00 4.94e+06  -1.0 2.73e+04    -  4.11e-05 6.54e-06f  1
# 1622  1.1158100e+08 1.28e+00 4.94e+06  -1.0 2.05e+04    -  1.26e-06 7.96e-05f  1
# 1623  1.1157575e+08 1.28e+00 4.94e+06  -1.0 1.85e+04    -  6.94e-05 2.37e-05f  1
# 1624  1.1157189e+08 1.28e+00 4.94e+06  -1.0 2.99e+04    -  2.41e-05 1.75e-05f  1
# 1625  1.1154940e+08 1.28e+00 4.94e+06  -1.0 2.09e+04    -  1.61e-06 1.01e-04f  1
# 1626  1.1154838e+08 1.28e+00 4.94e+06  -1.0 2.66e+04    -  2.92e-05 4.63e-06f  1
# 1627  1.1153086e+08 1.28e+00 4.94e+06  -1.0 2.62e+04    -  8.62e-06 7.92e-05f  1
# 1628  1.1151484e+08 1.27e+00 4.94e+06  -1.0 2.78e+04    -  4.66e-05 7.24e-05f  1
# 1629  1.1150041e+08 1.27e+00 4.94e+06  -1.0 3.08e+04    -  1.33e-04 6.53e-05f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1630  1.1148129e+08 1.27e+00 4.94e+06  -1.0 3.47e+04    -  8.80e-05 8.65e-05f  1
# 1631  1.1143271e+08 1.27e+00 4.94e+06  -1.0 3.66e+04    -  6.04e-05 2.20e-04f  1
# 1632  1.1140094e+08 1.27e+00 4.94e+06  -1.0 3.87e+04    -  1.46e-04 1.44e-04f  1
# 1633  1.1136220e+08 1.27e+00 4.94e+06  -1.0 3.90e+04    -  1.70e-04 1.75e-04f  1
# 1634  1.1127186e+08 1.26e+00 4.94e+06  -1.0 3.91e+04    -  1.04e-04 4.09e-04f  1
# 1635  1.1123656e+08 1.26e+00 4.94e+06  -1.0 3.84e+04    -  2.09e-04 1.60e-04f  1
# 1636  1.1112721e+08 1.26e+00 4.93e+06  -1.0 3.82e+04    -  2.17e-04 4.96e-04f  1
# 1637  1.1088651e+08 1.25e+00 4.93e+06  -1.0 3.77e+04    -  5.58e-05 1.09e-03f  1
# 1638  1.1077086e+08 1.24e+00 4.93e+06  -1.0 3.64e+04    -  1.51e-03 5.25e-04f  1
# 1639  1.1059319e+08 1.24e+00 4.92e+06  -1.0 3.58e+04    -  3.09e-05 8.07e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1640  1.0963533e+08 1.20e+00 4.90e+06  -1.0 3.51e+04    -  3.85e-04 4.36e-03f  1
# 1641  1.0908802e+08 1.19e+00 4.89e+06  -1.0 3.16e+04    -  3.11e-04 2.51e-03f  1
# 1642  1.0908080e+08 1.19e+00 4.89e+06  -1.0 3.03e+04    -  2.74e-03 3.32e-05f  1
# 1643  1.0734310e+08 1.14e+00 4.85e+06  -1.0 3.04e+04    -  2.18e-05 8.03e-03f  1
# 1644  1.0464602e+08 1.29e+00 4.79e+06  -1.0 2.75e+04    -  1.57e-04 1.27e-02f  1
# 1645  1.0334155e+08 1.33e+00 4.76e+06  -1.0 2.50e+04    -  1.05e-02 6.27e-03f  1
# 1646  1.0191638e+08 1.36e+00 4.72e+06  -1.0 2.44e+04    -  1.56e-04 6.93e-03f  1
# 1647  1.0086337e+08 1.38e+00 4.70e+06  -1.0 2.38e+04    -  2.36e-03 5.19e-03f  1
# 1648  1.0005163e+08 1.38e+00 4.68e+06  -1.0 2.35e+04    -  1.59e-02 4.04e-03f  1
# 1649  9.8697660e+07 1.40e+00 4.65e+06  -1.0 2.33e+04    -  7.34e-03 6.80e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1650  9.7875866e+07 1.40e+00 4.63e+06  -1.0 2.29e+04    -  1.33e-02 4.18e-03f  1
# 1651  9.7867388e+07 1.40e+00 4.63e+06  -1.0 2.27e+04    -  6.80e-02 4.34e-05f  1
# 1652  9.7754820e+07 1.40e+00 4.63e+06  -1.0 4.43e+04    -  1.14e-02 5.66e-04f  1
# 1653  9.7207301e+07 1.40e+00 4.61e+06  -1.0 3.38e+04    -  1.55e-04 2.76e-03f  1
# 1654  9.6619383e+07 1.40e+00 4.60e+06  -1.0 3.55e+04    -  5.42e-04 3.00e-03f  1
# 1655  9.6233120e+07 1.40e+00 4.59e+06  -1.0 3.55e+04    -  9.83e-04 1.99e-03f  1
# 1656  9.6208490e+07 1.40e+00 4.59e+06  -1.0 3.56e+04    -  9.92e-04 1.28e-04f  1
# 1657  9.6048440e+07 1.40e+00 4.59e+06  -1.0 3.80e+04    -  8.02e-04 8.31e-04f  1
# 1658  9.5924395e+07 1.39e+00 4.58e+06  -1.0 3.83e+04    -  6.36e-04 6.45e-04f  1
# 1659  9.5758796e+07 1.39e+00 4.58e+06  -1.0 3.80e+04    -  1.34e-03 8.63e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1660  9.5141467e+07 1.39e+00 4.56e+06  -1.0 3.73e+04    -  2.10e-03 3.23e-03f  1
# 1661  9.4541069e+07 1.39e+00 4.55e+06  -1.0 3.58e+04    -  8.76e-04 3.16e-03f  1
# 1662  9.4505881e+07 1.39e+00 4.55e+06  -1.0 3.59e+04    -  5.15e-03 1.86e-04f  1
# 1663  9.3978460e+07 1.39e+00 4.54e+06  -1.0 3.60e+04    -  1.19e-02 2.80e-03f  1
# 1664  9.3675641e+07 1.39e+00 4.53e+06  -1.0 3.63e+04    -  1.06e-02 1.61e-03f  1
# 1665  9.3050491e+07 1.39e+00 4.51e+06  -1.0 3.64e+04    -  1.47e-02 3.35e-03f  1
# 1666  9.2306793e+07 1.39e+00 4.50e+06  -1.0 3.68e+04    -  1.81e-02 4.01e-03f  1
# 1667  9.0804736e+07 1.40e+00 4.46e+06  -1.0 3.68e+04    -  1.12e-01 8.18e-03f  1
# 1668  8.5907446e+07 1.66e+00 4.34e+06  -1.0 3.60e+04    -  8.68e-04 2.74e-02f  1
# 1669  8.5174917e+07 1.66e+00 4.32e+06  -1.0 3.50e+04    -  7.06e-04 4.28e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1670  8.4530060e+07 1.66e+00 4.30e+06  -1.0 3.49e+04    -  2.16e-03 3.80e-03f  1
# 1671  7.2615292e+07 5.70e+00 3.99e+06  -1.0 3.47e+04    -  7.46e-04 7.32e-02f  1
# 1672  7.0899275e+07 5.67e+00 3.94e+06  -1.0 3.21e+04    -  1.03e-03 1.19e-02f  1
# 1673  5.6708229e+07 8.03e+00 3.52e+06  -1.0 3.18e+04    -  2.00e-01 1.06e-01f  1
# 1674  5.3285924e+07 7.99e+00 3.41e+06  -1.0 2.83e+04    -  1.45e-01 3.07e-02f  1
# 1675  4.5880080e+07 8.54e+00 3.17e+06  -1.0 2.74e+04    -  1.53e-02 7.22e-02f  1
# 1676  4.5532782e+07 8.51e+00 3.16e+06  -1.0 2.54e+04    -  3.50e-01 3.80e-03f  1
# 1677  4.4115694e+07 8.42e+00 3.11e+06  -1.0 2.56e+04    -  4.00e-02 1.57e-02f  1
# 1678  3.8483762e+07 8.66e+00 2.90e+06  -1.0 2.60e+04    -  1.96e-01 6.61e-02f  1
# 1679  3.7813761e+07 8.60e+00 2.88e+06  -1.0 2.78e+04    -  3.56e-03 8.75e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1680  3.6443003e+07 8.49e+00 2.82e+06  -1.0 2.81e+04    -  1.04e-01 1.83e-02f  1
# 1681  1.7989245e+07 2.20e+01 1.98e+06  -1.0 2.85e+04    -  2.14e-02 2.98e-01f  1
# 1682  1.4328687e+07 2.24e+01 1.77e+06  -1.0 4.15e+04    -  4.30e-02 1.08e-01f  1
# 1683  9.0354452e+06 2.92e+01 1.40e+06  -1.0 4.80e+04    -  1.80e-01 2.06e-01f  1
# 1684  4.2832780e+06 4.36e+01 9.66e+05  -1.0 1.33e+05    -  3.26e-02 3.12e-01f  1
# 1685  3.9911649e+06 4.22e+01 9.32e+05  -1.0 1.48e+05    -  3.57e-02 3.47e-02f  1
# 1686  3.4756669e+06 3.98e+01 8.70e+05  -1.0 1.10e+05    -  6.13e-02 6.68e-02f  1
# 1687  3.4649370e+06 3.97e+01 8.69e+05  -1.0 7.75e+04    -  7.72e-02 1.55e-03f  1
# 1688  1.4995665e+05 3.68e+01 3.07e+05  -1.0 7.08e+04    -  4.84e-02 7.94e-01f  1
# 1689  1.2123701e+05 3.29e+01 2.65e+05  -1.0 3.25e+04    -  1.33e-01 1.04e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1690  7.0135911e+04 2.44e+01 2.76e+05  -1.0 2.55e+04    -  2.14e-03 2.50e-01f  1
# 1691  6.9969680e+04 2.43e+01 1.41e+05  -1.0 1.67e+04    -  4.31e-01 1.27e-03f  1
# 1692  2.7104262e+04 1.41e+01 8.29e+04  -1.0 1.65e+04    -  4.11e-01 4.13e-01f  1
# 1693  2.2644622e+04 1.26e+01 6.94e+04  -1.0 8.99e+03    -  1.49e-01 1.05e-01f  1
# 1694  2.1107566e+04 1.21e+01 6.03e+04  -1.0 8.02e+03    -  7.70e-01 4.36e-02f  1
# 1695  4.6227534e+03 2.41e+00 1.64e+04  -1.0 8.42e+03    -  2.51e-01 9.90e-01f  1
# 1696  4.6030338e+03 7.89e-01 9.03e+04  -1.0 4.13e+03    -  6.45e-01 1.00e+00f  1
# 1697  4.5680975e+03 2.65e+00 6.62e+06  -1.0 7.25e+03    -  3.27e-01 1.00e+00f  1
# 1698  4.5282769e+03 4.00e+00 4.13e+06  -1.0 8.02e+03    -  3.76e-01 1.00e+00f  1
# 1699  4.4905675e+03 4.27e+00 1.27e+06  -1.0 7.10e+03    -  6.92e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1700  4.4409632e+03 7.62e+00 9.79e+05  -1.0 1.05e+04    -  2.31e-01 1.00e+00f  1
# 1701  4.4159686e+03 2.99e+00 6.01e+05  -1.0 9.01e+03    -  3.86e-01 1.00e+00f  1
# 1702  4.3954063e+03 2.27e+00 2.41e+05  -1.0 8.88e+03    -  6.00e-01 1.00e+00f  1
# 1703  4.3794068e+03 1.99e+00 1.20e+05  -1.0 1.11e+04    -  5.03e-01 1.00e+00f  1
# 1704  4.3721709e+03 8.44e-01 7.79e+02  -1.0 1.06e+04    -  9.93e-01 1.00e+00f  1
# 1705  4.3674805e+03 9.44e-01 5.43e-01  -1.0 1.95e+04    -  1.00e+00 1.00e+00f  1
# 1706  4.3353186e+03 2.76e+00 1.83e+06  -1.7 1.25e+04    -  7.71e-01 1.00e+00f  1
# 1707  4.3333432e+03 1.32e-01 2.68e-02  -1.7 2.13e+04    -  1.00e+00 1.00e+00h  1
# 1708  4.3290687e+03 1.27e-01 4.60e+05  -2.5 7.26e+03    -  8.42e-01 5.74e-01f  1
# 1709  4.3265016e+03 9.36e-02 1.32e+05  -2.5 1.91e+04    -  1.00e+00 8.20e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1710  4.3261195e+03 3.61e-03 1.89e-03  -2.5 7.47e+03    -  1.00e+00 1.00e+00h  1
# 1711  4.3255445e+03 5.96e-03 8.95e+04  -3.8 4.06e+03    -  9.28e-01 5.94e-01f  1
# 1712  4.3251551e+03 3.03e-03 9.07e-04  -3.8 1.66e+03    -  1.00e+00 1.00e+00f  1
# 1713  4.3251038e+03 1.16e-04 2.32e+02  -5.7 1.81e+02    -  1.00e+00 9.84e-01h  1
# 1714  4.3251029e+03 4.46e-08 2.12e-08  -5.7 1.24e+02    -  1.00e+00 1.00e+00h  1
# 1715  4.3251029e+03 1.16e-10 1.85e-11  -5.7 4.10e+00    -  1.00e+00 1.00e+00h  1
# 1716  4.3251023e+03 8.11e-09 2.45e-09  -7.0 2.60e+00    -  1.00e+00 1.00e+00f  1
# 1717  4.3251023e+03 2.33e-10 9.09e-13  -7.0 8.92e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1717
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.3251023049374435e+03    4.3251023049374435e+03
# Dual infeasibility......:   9.0949470177292824e-13    9.0949470177292824e-13
# Constraint violation....:   2.3283064365386963e-10    2.3283064365386963e-10
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   5.0981541695739688e-07    5.0981541695739688e-07
# Overall NLP error.......:   5.0981541695739688e-07    5.0981541695739688e-07
#
#
# Number of objective function evaluations             = 1801
# Number of objective gradient evaluations             = 837
# Number of equality constraint evaluations            = 1801
# Number of inequality constraint evaluations          = 1801
# Number of equality constraint Jacobian evaluations   = 1733
# Number of inequality constraint Jacobian evaluations = 1733
# Number of Lagrangian Hessian evaluations             = 1717
# Total seconds in IPOPT                               = 55.140
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  20.00ms ( 11.10us)  16.30ms (  9.05us)      1801
#        nlp_g  | 146.00ms ( 81.07us) 161.37ms ( 89.60us)      1801
#   nlp_grad_f  |  20.00ms ( 23.87us)  17.73ms ( 21.15us)       838
#   nlp_hess_l  | 587.00ms (344.89us) 576.35ms (338.63us)      1702
#    nlp_jac_g  | 299.00ms (172.43us) 326.40ms (188.24us)      1734
#        total  |  55.14 s ( 55.14 s)  55.14 s ( 55.14 s)         1

# %%
for i, phase in enumerate(phases):
        # print(f"\nPhase: {phase['name']}")
        X_debug = sol.value(X_list[i])
        U_debug = sol.value(U_list[i])
        T_debug = sol.value(T_list[i])

        # print("  States (X) [v, fpa, h, s, m]:")
        # print(X_debug)
        # print("  Controls (U) [thrust, fpa, spdbrk]:")
        # print(U_debug)
        print(f"  Duration (T): {T_debug}")

        # if "Infeasible_Problem_Detected" in str(e):
            # print("Solver detected infeasibility. Analyzing...")
            # opti.debug.show_infeasibilities()  # Show summary


        # Plot the states
        #from state_plot import plot_states, plot_states_ext
        #plot_states(X_debug[0], X_debug[1], X_debug[2], X_debug[3], X_debug[4], U_debug[0], U_debug[1], U_debug[2])
# Out:
#   Duration (T): 137.921632070803
#   Duration (T): 245.70957891750257
#   Duration (T): 3493.2882419720136
#   Duration (T): 448.1816031441702

# %%
from state_plot import plot_states_with_phases
plot_states_with_phases(sol.value(X_list[0]), sol.value(X_list[1]), sol.value(X_list[2]), sol.value(X_list[3]),
                        sol.value(U_list[0]), sol.value(U_list[1]), sol.value(U_list[2]), sol.value(U_list[3]),
                        [sol.value(T_list[i]) for i in range(len(T_list))])

# %%
for i, phase in enumerate(phases):
    # print(f"\nPhase: {phase['name']}")
    X_debug = opti.debug.value(X_list[i])
    U_debug = opti.debug.value(U_list[i])
    T_debug = opti.debug.value(T_list[i])

    # print("  States (X) [v, fpa, h, s, m]:")
    # print(X_debug)
    # print("  Controls (U) [thrust, fpa, spdbrk]:")
    # print(U_debug)
    print(f"Phase {phase['name']}, Duration {T_debug}")

    # if "Infeasible_Problem_Detected" in str(e):
        # print("Solver detected infeasibility. Analyzing...")
        # opti.debug.show_infeasibilities()  # Show summary


    # Plot the states
    from state_plot import plot_states, plot_states_ext
    plot_states(X_debug[0], X_debug[1], X_debug[2], X_debug[3], X_debug[4], U_debug[0], U_debug[1], U_debug[2])

    X_ext = np.empty((7, phase['N']))

    # Compute the additional variables
    for k in range(phase['N']):
        xk = X_debug[:,k]
        uk = U_debug[:,k]
        dyn_func = aircraft_dynamics(xk, uk, opti.debug.value(wind_s), opti.debug.value(phi), phase['name'], fiche_engine, fiche_ac, fiche_control)
        dyn_values = opti.debug.value(dyn_func)

        #Further break down
        g = 9.81
        k_gamma = fiche_control['k_gamma']
        v, gamma, h, s, m = xk[0], xk[1], xk[2], xk[3], xk[4]
        T, gamma_ref, beta = uk[0], uk[1], uk[2]
        rho0 = 1.225
        H = 8500.0
        rho = rho0 * np.exp(-h / H)  # Use numpy for scalar calculations during debugging
        nz = (-v * k_gamma * (gamma - gamma_ref) + g * np.cos(gamma))/(g * np.cos(0))
        L = nz * m * g
        epsilon = 1e-6
        v_sq = v**2 + epsilon
        S_area = fiche_ac['wing']['area']
        Cl = L / (0.5 * rho * v_sq * S_area)
        k_drag = fiche_ac['drag']['k']
        Cd = fiche_ac['drag']['cd0'] + beta + k_drag * Cl**2
        D = 0.5 * rho * v**2 * S_area * Cd

        # Fuel flow model (different for each phase)
        if phase['name'] == 'cruise':
            cruise_sfc = fiche_engine['cruise_sfc'] / 3600.0  # [kg/(N·s)]
            fuel_coef = fiche_ac['fuel']['fuel_coef']
            fuel_flow = fuel_coef * cruise_sfc * T
        elif phase['name'] == 'takeoff':
            fuel_flow = fiche_engine['ff_to'] * 2
        elif phase['name'] in ['climb1', 'climb2', 'climb3']:
            fuel_flow = fiche_engine['ff_co'] * 2
        elif phase['name'] in ['descent1', 'descent2', 'descent3']:
            fuel_flow = fiche_engine['ff_app'] * 2
        elif phase['name'] == 'landing':
            fuel_flow = fiche_engine['ff_idl'] * 2
        else:
            fuel_flow = 0.0

        X_ext[:,k] = np.array([L, D, nz, Cl, Cd, rho, fuel_flow])

        if np.isnan(X_ext[:,k]).any():
            print(f"NaN detected at index {k}")
            print(f"X_ext[:,k]: {X_ext[:,k]}")
            print(f"X_ext: {X_ext}")
            print(f"X_ext[0]: {X_ext[0]}")
            print(f"X_ext[1]: {X_ext[1]}")
        
    plot_states_ext(X_ext[0], X_ext[1], X_ext[2], X_ext[3], X_ext[4], X_ext[5], X_ext[6])
# Out:
# Phase climb1, Duration 137.921632070803
# Phase climb2, Duration 245.70957891750257
# Phase cruise, Duration 3493.2882419720136
# Phase descent1, Duration 448.1816031441702
